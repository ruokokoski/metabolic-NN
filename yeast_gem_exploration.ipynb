# %% [markdown]
# # Yeast GEM Exploration
#
# **Author: T. Ruokokoski**
#
# This notebook loads and inspects genome-scale metabolic model (GEM) of *Saccharomyces Cerevisiae*. It prints basic model statistics, simulates flux distributions using Flux Balance Analysis (FBA), and sets up a framework for building a multi-strain community model for bioreactor simulation.
#
# Model: [yeast9](https://github.com/SysBioChalmers/yeast-GEM)
#
# - Run FBA to determine default maximum biomass production
# - Display all exhange reactions
# - Display default medium
# - Test which individual carbon sources (e.g. glucose, lactate, acetate) support growth
# - Inspect specific reactions and metabolites
# - Display all reactions
# - Identify NADH and ATP reactions

# %%
import os
import cobra
from cobra.io import read_sbml_model
from cobra import Model, Reaction, Metabolite
from cobra.medium import minimal_medium
from cobra.flux_analysis import pfba
import pandas as pd
from IPython.display import display
import warnings
warnings.filterwarnings("ignore", message="Solver status is 'infeasible'")

# Set paths
model_dir = "./models"

# %% [markdown]
# ## Load GEMs
#
# Load genome-scale models (e.g., **yeast9**, <i>(other possibilities: Y. lipolytica, C. intermedia, ...)</i>) from SBML files.

# %%
model_paths = {
    "yeast9": os.path.join(model_dir, "yeast-GEM.xml"), # Saccharomyces Cerevisiae
    # Add more as needed
}

models = {name: read_sbml_model(path) for name, path in model_paths.items()}

pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Basic Model Summary
#
# Print statistics: number of reactions, metabolites, and genes for each model.

# %%
for name, model in models.items():
    print(f"--- {name.upper()} ---")
    print(f"Reactions: {len(model.reactions)}")
    print(f"Metabolites: {len(model.metabolites)}")
    print(f"Genes: {len(model.genes)}")
    print(f"Exchange reactions: {len(model.exchanges)}")
    display(model.summary())

model
# Out:
# --- YEAST9 ---
# Reactions: 4131
# Metabolites: 2806
# Genes: 1161
# Exchange reactions: 271
# <h3>Objective</h3><p>1.0 r_2111 = 0.08584396972646902</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>s_0420</td>
#       <td>r_1654</td>
#       <td>0.5493</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_0565</td>
#       <td>r_1714</td>
#       <td>1</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>s_0796</td>
#       <td>r_1832</td>
#       <td>0.02443</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_0925</td>
#       <td>r_1861</td>
#       <td>2.696E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_1277</td>
#       <td>r_1992</td>
#       <td>2.326</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_1324</td>
#       <td>r_2005</td>
#       <td>0.4297</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_1374</td>
#       <td>r_2020</td>
#       <td>0.0003116</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_1438</td>
#       <td>r_2049</td>
#       <td>0.0003408</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_1468</td>
#       <td>r_2060</td>
#       <td>0.007383</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4200</td>
#       <td>r_4593</td>
#       <td>0.0001107</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4201</td>
#       <td>r_4594</td>
#       <td>5.657E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4202</td>
#       <td>r_4595</td>
#       <td>0.0002344</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4203</td>
#       <td>r_4596</td>
#       <td>6.421E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4204</td>
#       <td>r_4597</td>
#       <td>0.0001067</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4199</td>
#       <td>r_4600</td>
#       <td>1.863E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>s_0458</td>
#       <td>r_1672</td>
#       <td>-2.498</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>s_0776</td>
#       <td>r_1814</td>
#       <td>-5.443E-06</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_0805</td>
#       <td>r_2100</td>
#       <td>-4.207</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_0450</td>
#       <td>r_2111</td>
#       <td>-0.08584</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>s_4157</td>
#       <td>r_4527</td>
#       <td>-0.2029</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
# <Model yeastGEM_v9__46__0__46__2 at 0x7d3aa800ae40>

# %% [markdown]
# ## Run Flux Balance Analysis (FBA)
#
# Perform FBA to compute the maximum biomass production rate under default model constraints. This simulates optimal growth conditions and reveals the most active reactions in the metabolic network.

# %%
# Run Flux Balance Analysis (FBA)
default_solution = model.optimize()

# Default objective function is biomass production reaction
print(f"\nMax biomass growth rate: {default_solution.objective_value:.4f} mmol/gDW/hour")

# Get top 10 flux-carrying reactions
top_fluxes = default_solution.fluxes.sort_values(ascending=False).head(10)

top_reactions = []

for rxn_id, flux in top_fluxes.items():
    rxn = model.reactions.get_by_id(rxn_id)
    top_reactions.append({
        "Reaction ID": rxn.id,
        "Name": rxn.name,
        "Equation": rxn.reaction,
        "Flux": round(flux, 4)
    })

df_top = pd.DataFrame(top_reactions)
print("\nTop flux-carrying reactions:")
display(df_top)
# Out:
# Max biomass growth rate: 0.0858 mmol/gDW/hour
#
# Top flux-carrying reactions:
#   Reaction ID                                     Name  \
# 0      r_0438  ferrocytochrome-c:oxygen oxidoreductase
# 1      r_1110                      ADP/ATP transporter
# 2      r_0226                             ATP synthase
# 3      r_1245                      phosphate transport
# 4      r_0439    ubiquinol:ferricytochrome c reductase
# 5      r_2100                           water exchange
# 6      r_1021   succinate dehydrogenase (ubiquinone-6)
# 7      r_1672                  carbon dioxide exchange
# 8      r_1697                            CO2 transport
# 9      r_4264            succinate:NAD+ oxidoreductase
#
#                                             Equation    Flux
# 0  s_0710 + 1.266 s_0799 + 0.25 s_1278 --> s_0709...  9.1160
# 1                s_0394 + s_0437 <=> s_0397 + s_0434  6.3695
# 2  s_0397 + 3.0 s_0794 + s_1326 --> s_0437 + 2.0 ...  5.7315
# 3                s_0794 + s_1322 --> s_0799 + s_1326  5.1250
# 4  2.0 s_0709 + 1.266 s_0799 + s_1535 --> 2.0 s_0...  4.5580
# 5                                        s_0805 <=>   4.2071
# 6                s_1460 + s_1537 <=> s_0727 + s_1535  3.0661
# 7                                        s_0458 -->   2.4980
# 8                                  s_0456 <=> s_0458  2.4980
# 9       s_0727 + s_0799 + s_1205 --> s_1200 + s_1460  2.3867

# %% [markdown]
# ## Exchange Reactions Overview
#
# List and inspect all exchange reactions, which represent metabolite uptake and secretion between the cell and its environment. Useful for understanding how the model interfaces with external nutrients and byproducts.

# %%
print(f"Number of exchange reactions: {len(model.exchanges)}")
exchange_data = []

for rxn in model.exchanges:
    exchange_data.append({
        "Reaction ID": rxn.id,
        "Name": rxn.name,
        "Bounds": rxn.bounds,
        "Equation": rxn.reaction,
        "Flux": round(default_solution.fluxes[rxn.id], 4)
    })

df = pd.DataFrame(exchange_data)
display(df)
# Out:
# Number of exchange reactions: 271
#     Reaction ID                                               Name  \
# 0        r_1542                      (1->3)-beta-D-glucan exchange
# 1        r_1545                             (R)-carnitine exchange
# 2        r_1546                               (R)-lactate exchange
# 3        r_1547                            (R)-mevalonate exchange
# 4        r_1548                          (R)-pantothenate exchange
# 5        r_1549                      (R,R)-2,3-butanediol exchange
# 6        r_1550              (S)-3-methyl-2-oxopentanoate exchange
# 7        r_1551                               (S)-lactate exchange
# 8        r_1552                                (S)-malate exchange
# 9        r_1553  1-(sn-glycero-3-phospho)-1D-myo-inositol exchange
# 10       r_1554               1-acylglycerophosphocholine exchange
# 11       r_1563                         2'-deoxyadenosine exchange
# 12       r_1564                         2'-deoxyguanosine exchange
# 13       r_1565                           2'-deoxyinosine exchange
# 14       r_1566                           2'-deoxyuridine exchange
# 15       r_1572                         2-isopropylmalate exchange
# 16       r_1577                           2-methylbutanal exchange
# 17       r_1580                           2-methylbutanol exchange
# 18       r_1581                     2-methylbutyl acetate exchange
# 19       r_1586                            2-oxoglutarate exchange
# 20       r_1589                           2-phenylethanol exchange
# 21       r_1598                           3-methylbutanal exchange
# 22       r_1604                           4-aminobenzoate exchange
# 23       r_1621                         5-aminolevulinate exchange
# 24       r_1625              5-formyltetrahydrofolic acid exchange
# 25       r_1627                      7,8-diaminononanoate exchange
# 26       r_1629                    8-amino-7-oxononanoate exchange
# 27       r_1630                               9H-xanthine exchange
# 28       r_1631                              acetaldehyde exchange
# 29       r_1634                                   acetate exchange
# 30       r_1639                                   adenine exchange
# 31       r_1641          adenosine 3',5'-bismonophosphate exchange
# 32       r_1643                                 adenosine exchange
# 33       r_1648                                allantoate exchange
# 34       r_1649                                 allantoin exchange
# 35       r_1650                                 trehalose exchange
# 36       r_1651           alpha-D-glucosamine 6-phosphate exchange
# 37       r_1654                                  ammonium exchange
# 38       r_1663                               bicarbonate exchange
# 39       r_1671                                    biotin exchange
# 40       r_1672                            carbon dioxide exchange
# 41       r_1683                                   choline exchange
# 42       r_1687                                   citrate exchange
# 43       r_1702                                  cytidine exchange
# 44       r_1705                                  cytosine exchange
# 45       r_1706                               D-arabinose exchange
# 46       r_1709                                D-fructose exchange
# 47       r_1710                               D-galactose exchange
# 48       r_1711                           D-galacturonate exchange
# 49       r_1712                                D-glucitol exchange
# 50       r_1714                                 D-glucose exchange
# 51       r_1715                                 D-mannose exchange
# 52       r_1716                                  D-ribose exchange
# 53       r_1718                                  D-xylose exchange
# 54       r_1727                                 decanoate exchange
# 55       r_1730                             deoxycytidine exchange
# 56       r_1749                                      dTTP exchange
# 57       r_1753                                 episterol exchange
# 58       r_1757                                ergosterol exchange
# 59       r_1761                                   ethanol exchange
# 60       r_1764                              ethanolamine exchange
# 61       r_1765                             ethyl acetate exchange
# 62       r_1788                                fecosterol exchange
# 63       r_1791                                       FMN exchange
# 64       r_1792                                folic acid exchange
# 65       r_1793                                   formate exchange
# 66       r_1798                                  fumarate exchange
# 67       r_1800                       gamma-aminobutyrate exchange
# 68       r_1806                     glutathione disulfide exchange
# 69       r_1807                               glutathione exchange
# 70       r_1808                                  glycerol exchange
# 71       r_1810                                 L-glycine exchange
# 72       r_1814                            glycolaldehyde exchange
# 73       r_1815                                glyoxylate exchange
# 74       r_1818                                   guanine exchange
# 75       r_1820                                 guanosine exchange
# 76       r_1832                                        H+ exchange
# 77       r_1834                               hexadecanal exchange
# 78       r_1841                              hypoxanthine exchange
# 79       r_1843                    indol-3-ylacetaldehyde exchange
# 80       r_1847                                   inosine exchange
# 81       r_1861                                  iron(2+) exchange
# 82       r_1862                           isoamyl acetate exchange
# 83       r_1865                                 isoamylol exchange
# 84       r_1866                                isobutanol exchange
# 85       r_1867                          isobutyl acetate exchange
# 86       r_1870                          isobutyraldehyde exchange
# 87       r_1873                                 L-alanine exchange
# 88       r_1875                              L-arabinitol exchange
# 89       r_1878                               L-arabinose exchange
# 90       r_1879                                L-arginine exchange
# 91       r_1880                              L-asparagine exchange
# 92       r_1881                               L-aspartate exchange
# 93       r_1883                                L-cysteine exchange
# 94       r_1886                                L-glucitol exchange
# 95       r_1889                               L-glutamate exchange
# 96       r_1891                               L-glutamine exchange
# 97       r_1893                               L-histidine exchange
# 98       r_1896                              L-homoserine exchange
# 99       r_1897                              L-isoleucine exchange
# 100      r_1899                                 L-leucine exchange
# 101      r_1900                                  L-lysine exchange
# 102      r_1902                              L-methionine exchange
# 103      r_1903                           L-phenylalanine exchange
# 104      r_1904                                 L-proline exchange
# 105      r_1906                                  L-serine exchange
# 106      r_1909                                 L-sorbose exchange
# 107      r_1911                               L-threonine exchange
# 108      r_1912                              L-tryptophan exchange
# 109      r_1913                                L-tyrosine exchange
# 110      r_1914                                  L-valine exchange
# 111      r_1915                                lanosterol exchange
# 112      r_1916                                   laurate exchange
# 113      r_1931                                   maltose exchange
# 114      r_1947                              myo-inositol exchange
# 115      r_1952                   N,N'-diformyldityrosine exchange
# 116      r_1967                                nicotinate exchange
# 117      r_1968                                       NMN exchange
# 118      r_1984                                 octanoate exchange
# 119      r_1987                                 ornithine exchange
# 120      r_1989                          oxaloacetate(2-) exchange
# 121      r_1992                                    oxygen exchange
# 122      r_1993                                 palmitate exchange
# 123      r_1994                              palmitoleate exchange
# 124      r_1999                                    pectin exchange
# 125      r_2000                         phenethyl acetate exchange
# 126      r_2001                        phenylacetaldehyde exchange
# 127      r_2005                                 phosphate exchange
# 128      r_2020                                 potassium exchange
# 129      r_2024                                putrescine exchange
# 130      r_2028                                pyridoxine exchange
# 131      r_2033                                  pyruvate exchange
# 132      r_2038                                riboflavin exchange
# 133      r_2043                   S-adenosyl-L-methionine exchange
# 134      r_2044                     S-methyl-L-methionine exchange
# 135      r_2046               sn-glycero-3-phosphocholine exchange
# 136      r_2049                                    sodium exchange
# 137      r_2051                                spermidine exchange
# 138      r_2052                                  spermine exchange
# 139      r_2055                                  stearate exchange
# 140      r_2056                                 succinate exchange
# 141      r_2058                                   sucrose exchange
# 142      r_2060                                  sulphate exchange
# 143      r_2061                                  sulphite exchange
# 144      r_2062                                   taurine exchange
# 145      r_2066              thiamine(1+) diphosphate(1-) exchange
# 146      r_2067                              thiamine(1+) exchange
# 147      r_2068                thiamine(1+) monophosphate exchange
# 148      r_2073                                 thymidine exchange
# 149      r_2083                                tryptophol exchange
# 150      r_2090                                    uracil exchange
# 151      r_2091                                      urea exchange
# 152      r_2092                                   uridine exchange
# 153      r_2100                                     water exchange
# 154      r_2102                                xanthosine exchange
# 155      r_2104                                   xylitol exchange
# 156      r_2106                                zymosterol exchange
# 157      r_2134                     14-demethyllanosterol exchange
# 158      r_2137    ergosta-5,7,22,24(28)-tetraen-3beta-ol exchange
# 159      r_2187                                  butyrate exchange
# 160      r_2188                                 hexanoate exchange
# 161      r_2189                                    oleate exchange
# 162      r_2193                                 myristate exchange
# 163      r_4043                                 raffinose exchange
# 164      r_4044                                 melibiose exchange
# 165      r_4442                                cysteamine exchange
# 166      r_4494                                  methanol exchange
# 167      r_4496                                   Ala-Gly exchange
# 168      r_4497                         3-oxalomalate(3-) exchange
# 169      r_4498  6-O-alpha-D-glucopyranosyl-D-fructofuranose ex...
# 170      r_4499                     5-dehydro-D-gluconate exchange
# 171      r_4500                                D-tagatose exchange
# 172      r_4501                                  turanose exchange
# 173      r_4502                     D-glucose 6-phosphate exchange
# 174      r_4503                         alpha-maltotriose exchange
# 175      r_4504                     D-glucose 1-phosphate exchange
# 176      r_4505            methyl alpha-D-glucopyranoside exchange
# 177      r_4506                             D-Glucosamine exchange
# 178      r_4507                                 glycerone exchange
# 179      r_4508                                   Ala-Gln exchange
# 180      r_4509                                   Ala-Leu exchange
# 181      r_4510                                   Gly-Gln exchange
# 182      r_4511                                   Ala-His exchange
# 183      r_4512                                   Gly-Asn exchange
# 184      r_4513                                   Ala-Glu exchange
# 185      r_4514                                   Gly-Met exchange
# 186      r_4515                                   Ala-Asp exchange
# 187      r_4516                                   Gly-Glu exchange
# 188      r_4517                                   Ala-Thr exchange
# 189      r_4518                                   Met-Ala exchange
# 190      r_4519                              L-citrulline exchange
# 191      r_4520                          2-aminobutanoate exchange
# 192      r_4521                         choline phosphate exchange
# 193      r_4522                      glycerol 1-phosphate exchange
# 194      r_4523                 2-phospho-D-glyceric acid exchange
# 195      r_4524                                       GMP exchange
# 196      r_4525                          3-phospho-serine exchange
# 197      r_4526             O-phosphonatooxy-D-serine(2-) exchange
# 198      r_4527                               diphosphate exchange
# 199      r_4528                              triphosphate exchange
# 200      r_4529                       phosphoenolpyruvate exchange
# 201      r_4530               N(omega)-phospho-L-arginine exchange
# 202      r_4531                       carbamoyl phosphate exchange
# 203      r_4532                     O-phosphoethanolamine exchange
# 204      r_4533                    cysteamine S-phosphate exchange
# 205      r_4534                guanosine 2'-monophosphate exchange
# 206      r_4535                  glycerol 2-phosphate(2-) exchange
# 207      r_4536                                    3'-GMP exchange
# 208      r_4537                        2-phosphoglycolate exchange
# 209      r_4538                     6-phospho-D-gluconate exchange
# 210      r_4539                     D-mannose 6-phosphate exchange
# 211      r_4540                          2',3'-cyclic GMP exchange
# 212      r_4541                   O(4)-phospho-L-tyrosine exchange
# 213      r_4542                     O-phospho-L-threonine exchange
# 214      r_4543             3-phosphonato-D-glycerate(3-) exchange
# 215      r_4544                    adenosine 2'-phosphate exchange
# 216      r_4545                                    3'-AMP exchange
# 217      r_4546                          2',3'-cyclic AMP exchange
# 218      r_4547                     D-mannose 1-phosphate exchange
# 219      r_4548                                       AMP exchange
# 220      r_4549              N(alpha)-acetyl-L-methionine exchange
# 221      r_4550                      L-Methionine S-oxide exchange
# 222      r_4551                       3-sulfino-L-alanine exchange
# 223      r_4552                       N-acetyl-L-cysteine exchange
# 224      r_4553                                L-cysteate exchange
# 225      r_4554               2-hydroxyethane-1-sulfonate exchange
# 226      r_4555                              acetoacetate exchange
# 227      r_4556                      N-acetyl-L-glutamate exchange
# 228      r_4557                                       UMP exchange
# 229      r_4558                                       CMP exchange
# 230      r_4559                thymidine 5'-monophosphate exchange
# 231      r_4560                thymidine 3'-monophosphate exchange
# 232      r_4561                     cytidine 2'-phosphate exchange
# 233      r_4562                      uridine 2'-phosphate exchange
# 234      r_4563                                    3'-UMP exchange
# 235      r_4564                          2',3'-cyclic CMP exchange
# 236      r_4565                          2',3'-cyclic UMP exchange
# 237      r_4593                                  chloride exchange
# 238      r_4594                                    Cu2(+) exchange
# 239      r_4595                                    Mn(2+) exchange
# 240      r_4596                                    Zn(2+) exchange
# 241      r_4597                                    Mg(2+) exchange
# 242      r_4600                                    Ca(2+) exchange
# 243      r_4644                           ethyl hexanoate exchange
# 244      r_4645                           ethyl octanoate exchange
# 245      r_4646                           ethyl butanoate exchange
# 246      r_4647                             hexyl acetate exchange
# 247      r_4648                           ethyl decanoate exchange
# 248      r_4658                                  propanal exchange
# 249      r_4659                                  propanol exchange
# 250      r_4667                                 methional exchange
# 251      r_4668                                 methionol exchange
# 252      r_4676             (4-hydroxyphenyl)acetaldehyde exchange
# 253      r_4677                                   tyrosol exchange
# 254      r_4689                           tyrosyl acetate exchange
# 255      r_4692                         methionyl acetate exchange
# 256      r_4695                            propyl acetate exchange
# 257      r_4699                          ethyl propionate exchange
# 258      r_4708                          hydrogen sulfide exchange
# 259      r_4709                           alkanesulfonate exchange
# 260      r_4710                              taurocholate exchange
# 261      r_4727                        ethyl-(2S)-lactate exchange
# 262      r_4729                        ethyl-(2R)-lactate exchange
# 263      r_4731                         diethyl-succinate exchange
# 264      r_4733                       monoethyl-succinate exchange
# 265      r_4735                            ethyl-benzoate exchange
# 266      r_4737                            ethyl-pyruvate exchange
# 267      r_4739                            benzyl-acetate exchange
# 268      r_4741                         ethyl-isobutyrate exchange
# 269      r_4743                    ethyl-2-methylbutyrate exchange
# 270      r_4780                                    heme a exchange
#
#                 Bounds     Equation    Flux
# 0        (0.0, 1000.0)  s_0003 -->   0.0000
# 1        (0.0, 1000.0)  s_0022 -->   0.0000
# 2        (0.0, 1000.0)  s_0026 -->   0.0000
# 3        (0.0, 1000.0)  s_0029 -->   0.0000
# 4        (0.0, 1000.0)  s_0032 -->   0.0000
# 5        (0.0, 1000.0)  s_0036 -->   0.0000
# 6        (0.0, 1000.0)  s_0058 -->   0.0000
# 7        (0.0, 1000.0)  s_0064 -->   0.0000
# 8        (0.0, 1000.0)  s_0067 -->   0.0000
# 9        (0.0, 1000.0)  s_0080 -->   0.0000
# 10       (0.0, 1000.0)  s_0084 -->   0.0000
# 11       (0.0, 1000.0)  s_0133 -->   0.0000
# 12       (0.0, 1000.0)  s_0135 -->   0.0000
# 13       (0.0, 1000.0)  s_0137 -->   0.0000
# 14       (0.0, 1000.0)  s_0139 -->   0.0000
# 15       (0.0, 1000.0)  s_0163 -->   0.0000
# 16       (0.0, 1000.0)  s_0167 -->   0.0000
# 17       (0.0, 1000.0)  s_0170 -->   0.0000
# 18       (0.0, 1000.0)  s_0173 -->   0.0000
# 19       (0.0, 1000.0)  s_0181 -->   0.0000
# 20       (0.0, 1000.0)  s_0186 -->   0.0000
# 21       (0.0, 1000.0)  s_0235 -->   0.0000
# 22       (0.0, 1000.0)  s_0272 -->   0.0000
# 23       (0.0, 1000.0)  s_0316 -->   0.0000
# 24       (0.0, 1000.0)  s_0320 -->   0.0000
# 25       (0.0, 1000.0)  s_0342 -->   0.0000
# 26       (0.0, 1000.0)  s_0354 -->   0.0000
# 27       (0.0, 1000.0)  s_0358 -->   0.0000
# 28       (0.0, 1000.0)  s_0360 -->   0.0000
# 29       (0.0, 1000.0)  s_0364 -->   0.0000
# 30       (0.0, 1000.0)  s_0384 -->   0.0000
# 31       (0.0, 1000.0)  s_0391 -->   0.0000
# 32       (0.0, 1000.0)  s_0387 -->   0.0000
# 33       (0.0, 1000.0)  s_0406 -->   0.0000
# 34       (0.0, 1000.0)  s_0408 -->   0.0000
# 35       (0.0, 1000.0)  s_1521 -->   0.0000
# 36       (0.0, 1000.0)  s_0413 -->   0.0000
# 37   (-1000.0, 1000.0)  s_0420 <=>  -0.5493
# 38          (0.0, 0.0)  s_0446 -->   0.0000
# 39       (0.0, 1000.0)  s_0452 -->   0.0000
# 40       (0.0, 1000.0)  s_0458 -->   2.4980
# 41       (0.0, 1000.0)  s_0513 -->   0.0000
# 42       (0.0, 1000.0)  s_0523 -->   0.0000
# 43       (0.0, 1000.0)  s_0544 -->   0.0000
# 44       (0.0, 1000.0)  s_0546 -->   0.0000
# 45       (0.0, 1000.0)  s_0549 -->   0.0000
# 46       (0.0, 1000.0)  s_0554 -->   0.0000
# 47       (0.0, 1000.0)  s_0559 -->   0.0000
# 48       (0.0, 1000.0)  s_0560 -->   0.0000
# 49       (0.0, 1000.0)  s_0562 -->   0.0000
# 50      (-1.0, 1000.0)  s_0565 <=>  -1.0000
# 51       (0.0, 1000.0)  s_0572 -->   0.0000
# 52       (0.0, 1000.0)  s_0576 -->   0.0000
# 53       (0.0, 1000.0)  s_0579 -->   0.0000
# 54       (0.0, 1000.0)  s_0597 -->   0.0000
# 55       (0.0, 1000.0)  s_0611 -->   0.0000
# 56       (0.0, 1000.0)  s_0651 -->   0.0000
# 57       (0.0, 1000.0)  s_0659 -->   0.0000
# 58       (0.0, 1000.0)  s_0668 -->   0.0000
# 59       (0.0, 1000.0)  s_0681 -->   0.0000
# 60       (0.0, 1000.0)  s_0684 -->   0.0000
# 61       (0.0, 1000.0)  s_0686 -->   0.0000
# 62       (0.0, 1000.0)  s_0702 -->   0.0000
# 63       (0.0, 1000.0)  s_0715 -->   0.0000
# 64       (0.0, 1000.0)  s_0720 -->   0.0000
# 65       (0.0, 1000.0)  s_0723 -->   0.0000
# 66       (0.0, 1000.0)  s_0726 -->   0.0000
# 67       (0.0, 1000.0)  s_0736 -->   0.0000
# 68       (0.0, 1000.0)  s_0755 -->   0.0000
# 69       (0.0, 1000.0)  s_0751 -->   0.0000
# 70       (0.0, 1000.0)  s_0766 -->   0.0000
# 71       (0.0, 1000.0)  s_1004 -->   0.0000
# 72       (0.0, 1000.0)  s_0776 -->   0.0000
# 73       (0.0, 1000.0)  s_0780 -->   0.0000
# 74       (0.0, 1000.0)  s_0788 -->   0.0000
# 75       (0.0, 1000.0)  s_0791 -->   0.0000
# 76   (-1000.0, 1000.0)  s_0796 <=>  -0.0244
# 77       (0.0, 1000.0)  s_0826 -->   0.0000
# 78       (0.0, 1000.0)  s_0844 -->   0.0000
# 79       (0.0, 1000.0)  s_0851 -->   0.0000
# 80       (0.0, 1000.0)  s_0857 -->   0.0000
# 81   (-1000.0, 1000.0)  s_0925 <=>  -0.0000
# 82       (0.0, 1000.0)  s_0928 -->   0.0000
# 83       (0.0, 1000.0)  s_0930 -->   0.0000
# 84       (0.0, 1000.0)  s_0933 -->   0.0000
# 85       (0.0, 1000.0)  s_0936 -->   0.0000
# 86       (0.0, 1000.0)  s_0938 -->   0.0000
# 87       (0.0, 1000.0)  s_0956 -->   0.0000
# 88       (0.0, 1000.0)  s_0962 -->   0.0000
# 89       (0.0, 1000.0)  s_0964 -->   0.0000
# 90       (0.0, 1000.0)  s_0966 -->   0.0000
# 91       (0.0, 1000.0)  s_0970 -->   0.0000
# 92       (0.0, 1000.0)  s_0974 -->   0.0000
# 93       (0.0, 1000.0)  s_0982 -->   0.0000
# 94       (0.0, 1000.0)  s_0990 -->   0.0000
# 95       (0.0, 1000.0)  s_0992 -->   0.0000
# 96       (0.0, 1000.0)  s_1000 -->   0.0000
# 97       (0.0, 1000.0)  s_1007 -->   0.0000
# 98       (0.0, 1000.0)  s_1015 -->   0.0000
# 99       (0.0, 1000.0)  s_1017 -->   0.0000
# 100      (0.0, 1000.0)  s_1022 -->   0.0000
# 101      (0.0, 1000.0)  s_1026 -->   0.0000
# 102      (0.0, 1000.0)  s_1030 -->   0.0000
# 103      (0.0, 1000.0)  s_1033 -->   0.0000
# 104      (0.0, 1000.0)  s_1036 -->   0.0000
# 105      (0.0, 1000.0)  s_1041 -->   0.0000
# 106      (0.0, 1000.0)  s_1044 -->   0.0000
# 107      (0.0, 1000.0)  s_1046 -->   0.0000
# 108      (0.0, 1000.0)  s_1049 -->   0.0000
# 109      (0.0, 1000.0)  s_1052 -->   0.0000
# 110      (0.0, 1000.0)  s_1057 -->   0.0000
# 111      (0.0, 1000.0)  s_1061 -->   0.0000
# 112      (0.0, 1000.0)  s_1067 -->   0.0000
# 113      (0.0, 1000.0)  s_1106 -->   0.0000
# 114      (0.0, 1000.0)  s_1154 -->   0.0000
# 115      (0.0, 1000.0)  s_1186 -->   0.0000
# 116      (0.0, 1000.0)  s_1220 -->   0.0000
# 117      (0.0, 1000.0)  s_1225 -->   0.0000
# 118      (0.0, 1000.0)  s_1250 -->   0.0000
# 119      (0.0, 1000.0)  s_1267 -->   0.0000
# 120      (0.0, 1000.0)  s_1272 -->   0.0000
# 121  (-1000.0, 1000.0)  s_1277 <=>  -2.3261
# 122      (0.0, 1000.0)  s_1288 -->   0.0000
# 123      (0.0, 1000.0)  s_1295 -->   0.0000
# 124      (0.0, 1000.0)  s_1309 -->   0.0000
# 125      (0.0, 1000.0)  s_1317 -->   0.0000
# 126      (0.0, 1000.0)  s_1319 -->   0.0000
# 127  (-1000.0, 1000.0)  s_1324 <=>  -0.4297
# 128  (-1000.0, 1000.0)  s_1374 <=>  -0.0003
# 129      (0.0, 1000.0)  s_1390 -->   0.0000
# 130      (0.0, 1000.0)  s_1397 -->   0.0000
# 131      (0.0, 1000.0)  s_1400 -->   0.0000
# 132      (0.0, 1000.0)  s_1406 -->   0.0000
# 133      (0.0, 1000.0)  s_1418 -->   0.0000
# 134      (0.0, 1000.0)  s_1425 -->   0.0000
# 135      (0.0, 1000.0)  s_1435 -->   0.0000
# 136  (-1000.0, 1000.0)  s_1438 <=>  -0.0003
# 137      (0.0, 1000.0)  s_1440 -->   0.0000
# 138      (0.0, 1000.0)  s_1443 -->   0.0000
# 139      (0.0, 1000.0)  s_1450 -->   0.0000
# 140      (0.0, 1000.0)  s_1459 -->   0.0000
# 141      (0.0, 1000.0)  s_1466 -->   0.0000
# 142  (-1000.0, 1000.0)  s_1468 <=>  -0.0074
# 143      (0.0, 1000.0)  s_1470 -->   0.0000
# 144      (0.0, 1000.0)  s_1472 -->   0.0000
# 145      (0.0, 1000.0)  s_1476 -->   0.0000
# 146      (0.0, 1000.0)  s_1490 -->   0.0000
# 147      (0.0, 1000.0)  s_1498 -->   0.0000
# 148      (0.0, 1000.0)  s_1494 -->   0.0000
# 149      (0.0, 1000.0)  s_1530 -->   0.0000
# 150      (0.0, 1000.0)  s_1551 -->   0.0000
# 151      (0.0, 1000.0)  s_1553 -->   0.0000
# 152      (0.0, 1000.0)  s_1557 -->   0.0000
# 153  (-1000.0, 1000.0)  s_0805 <=>   4.2071
# 154      (0.0, 1000.0)  s_1564 -->   0.0000
# 155      (0.0, 1000.0)  s_1567 -->   0.0000
# 156      (0.0, 1000.0)  s_1571 -->   0.0000
# 157      (0.0, 1000.0)  s_2766 -->   0.0000
# 158      (0.0, 1000.0)  s_2768 -->   0.0000
# 159      (0.0, 1000.0)  s_2822 -->   0.0000
# 160      (0.0, 1000.0)  s_2824 -->   0.0000
# 161      (0.0, 1000.0)  s_2826 -->   0.0000
# 162      (0.0, 1000.0)  s_1163 -->   0.0000
# 163      (0.0, 1000.0)  s_3715 -->   0.0000
# 164      (0.0, 1000.0)  s_3716 -->   0.0000
# 165      (0.0, 1000.0)  s_4074 -->   0.0000
# 166      (0.0, 1000.0)  s_4124 -->   0.0000
# 167      (0.0, 1000.0)  s_4170 -->   0.0000
# 168      (0.0, 1000.0)  s_4137 -->   0.0000
# 169      (0.0, 1000.0)  s_4109 -->   0.0000
# 170      (0.0, 1000.0)  s_4118 -->   0.0000
# 171      (0.0, 1000.0)  s_4130 -->   0.0000
# 172      (0.0, 1000.0)  s_4131 -->   0.0000
# 173      (0.0, 1000.0)  s_4150 -->   0.0000
# 174      (0.0, 1000.0)  s_4140 -->   0.0000
# 175      (0.0, 1000.0)  s_4145 -->   0.0000
# 176      (0.0, 1000.0)  s_4125 -->   0.0000
# 177      (0.0, 1000.0)  s_4164 -->   0.0000
# 178      (0.0, 1000.0)  s_4167 -->   0.0000
# 179      (0.0, 1000.0)  s_4034 -->   0.0000
# 180      (0.0, 1000.0)  s_4168 -->   0.0000
# 181      (0.0, 1000.0)  s_4056 -->   0.0000
# 182      (0.0, 1000.0)  s_4050 -->   0.0000
# 183      (0.0, 1000.0)  s_4053 -->   0.0000
# 184      (0.0, 1000.0)  s_4037 -->   0.0000
# 185      (0.0, 1000.0)  s_4085 -->   0.0000
# 186      (0.0, 1000.0)  s_4119 -->   0.0000
# 187      (0.0, 1000.0)  s_4059 -->   0.0000
# 188      (0.0, 1000.0)  s_4040 -->   0.0000
# 189      (0.0, 1000.0)  s_4143 -->   0.0000
# 190      (0.0, 1000.0)  s_4166 -->   0.0000
# 191      (0.0, 1000.0)  s_4080 -->   0.0000
# 192      (0.0, 1000.0)  s_4158 -->   0.0000
# 193      (0.0, 1000.0)  s_4049 -->   0.0000
# 194      (0.0, 1000.0)  s_4141 -->   0.0000
# 195      (0.0, 1000.0)  s_4148 -->   0.0000
# 196      (0.0, 1000.0)  s_4147 -->   0.0000
# 197      (0.0, 1000.0)  s_4078 -->   0.0000
# 198      (0.0, 1000.0)  s_4157 -->   0.2029
# 199      (0.0, 1000.0)  s_4099 -->   0.0000
# 200      (0.0, 1000.0)  s_4152 -->   0.0000
# 201      (0.0, 1000.0)  s_4093 -->   0.0000
# 202      (0.0, 1000.0)  s_4146 -->   0.0000
# 203      (0.0, 1000.0)  s_4154 -->   0.0000
# 204      (0.0, 1000.0)  s_4075 -->   0.0000
# 205      (0.0, 1000.0)  s_4067 -->   0.0000
# 206      (0.0, 1000.0)  s_4063 -->   0.0000
# 207      (0.0, 1000.0)  s_4069 -->   0.0000
# 208      (0.0, 1000.0)  s_4070 -->   0.0000
# 209      (0.0, 1000.0)  s_4155 -->   0.0000
# 210      (0.0, 1000.0)  s_4153 -->   0.0000
# 211      (0.0, 1000.0)  s_4095 -->   0.0000
# 212      (0.0, 1000.0)  s_4097 -->   0.0000
# 213      (0.0, 1000.0)  s_4065 -->   0.0000
# 214      (0.0, 1000.0)  s_4142 -->   0.0000
# 215      (0.0, 1000.0)  s_4162 -->   0.0000
# 216      (0.0, 1000.0)  s_4107 -->   0.0000
# 217      (0.0, 1000.0)  s_4161 -->   0.0000
# 218      (0.0, 1000.0)  s_4156 -->   0.0000
# 219      (0.0, 1000.0)  s_4160 -->   0.0000
# 220      (0.0, 1000.0)  s_4135 -->   0.0000
# 221      (0.0, 1000.0)  s_4176 -->   0.0000
# 222      (0.0, 1000.0)  s_4105 -->   0.0000
# 223      (0.0, 1000.0)  s_4111 -->   0.0000
# 224      (0.0, 1000.0)  s_4139 -->   0.0000
# 225      (0.0, 1000.0)  s_4116 -->   0.0000
# 226      (0.0, 1000.0)  s_4133 -->   0.0000
# 227      (0.0, 1000.0)  s_4172 -->   0.0000
# 228      (0.0, 1000.0)  s_4151 -->   0.0000
# 229      (0.0, 1000.0)  s_4163 -->   0.0000
# 230      (0.0, 1000.0)  s_4047 -->   0.0000
# 231      (0.0, 1000.0)  s_4045 -->   0.0000
# 232      (0.0, 1000.0)  s_4101 -->   0.0000
# 233      (0.0, 1000.0)  s_4082 -->   0.0000
# 234      (0.0, 1000.0)  s_4084 -->   0.0000
# 235      (0.0, 1000.0)  s_4127 -->   0.0000
# 236      (0.0, 1000.0)  s_4103 -->   0.0000
# 237  (-1000.0, 1000.0)  s_4200 <=>  -0.0001
# 238  (-1000.0, 1000.0)  s_4201 <=>  -0.0001
# 239  (-1000.0, 1000.0)  s_4202 <=>  -0.0002
# 240  (-1000.0, 1000.0)  s_4203 <=>  -0.0001
# 241  (-1000.0, 1000.0)  s_4204 <=>  -0.0001
# 242  (-1000.0, 1000.0)  s_4199 <=>  -0.0000
# 243      (0.0, 1000.0)  s_4226 -->   0.0000
# 244      (0.0, 1000.0)  s_4227 -->   0.0000
# 245      (0.0, 1000.0)  s_4228 -->   0.0000
# 246      (0.0, 1000.0)  s_4229 -->   0.0000
# 247      (0.0, 1000.0)  s_4230 -->   0.0000
# 248      (0.0, 1000.0)  s_4236 -->   0.0000
# 249      (0.0, 1000.0)  s_4237 -->   0.0000
# 250      (0.0, 1000.0)  s_4242 -->   0.0000
# 251      (0.0, 1000.0)  s_4243 -->   0.0000
# 252      (0.0, 1000.0)  s_4248 -->   0.0000
# 253      (0.0, 1000.0)  s_4249 -->   0.0000
# 254      (0.0, 1000.0)  s_4255 -->   0.0000
# 255      (0.0, 1000.0)  s_4257 -->   0.0000
# 256      (0.0, 1000.0)  s_4259 -->   0.0000
# 257      (0.0, 1000.0)  s_4262 -->   0.0000
# 258      (0.0, 1000.0)  s_4263 -->   0.0000
# 259      (0.0, 1000.0)  s_4266 -->   0.0000
# 260      (0.0, 1000.0)  s_4268 -->   0.0000
# 261      (0.0, 1000.0)  s_4270 -->   0.0000
# 262      (0.0, 1000.0)  s_4272 -->   0.0000
# 263      (0.0, 1000.0)  s_4275 -->   0.0000
# 264      (0.0, 1000.0)  s_4277 -->   0.0000
# 265      (0.0, 1000.0)  s_4279 -->   0.0000
# 266      (0.0, 1000.0)  s_4281 -->   0.0000
# 267      (0.0, 1000.0)  s_4289 -->   0.0000
# 268      (0.0, 1000.0)  s_4287 -->   0.0000
# 269      (0.0, 1000.0)  s_4284 -->   0.0000
# 270      (0.0, 1000.0)  s_4332 -->   0.0000

# %% [markdown]
# ## Default medium

# %%
medium_rxns = list(model.medium.keys())
print(medium_rxns)
print()
for rxn_id in medium_rxns:
    rxn = model.reactions.get_by_id(rxn_id)
    print(f"{rxn.id}: {rxn.name}")

model.medium
# Out:
# ['r_1654', 'r_1714', 'r_1832', 'r_1861', 'r_1992', 'r_2005', 'r_2020', 'r_2049', 'r_2060', 'r_2100', 'r_4593', 'r_4594', 'r_4595', 'r_4596', 'r_4597', 'r_4600']
#
# r_1654: ammonium exchange
# r_1714: D-glucose exchange
# r_1832: H+ exchange
# r_1861: iron(2+) exchange
# r_1992: oxygen exchange
# r_2005: phosphate exchange
# r_2020: potassium exchange
# r_2049: sodium exchange
# r_2060: sulphate exchange
# r_2100: water exchange
# r_4593: chloride exchange
# r_4594: Cu2(+) exchange
# r_4595: Mn(2+) exchange
# r_4596: Zn(2+) exchange
# r_4597: Mg(2+) exchange
# r_4600: Ca(2+) exchange
# {'r_1654': 1000.0,
#  'r_1714': 1.0,
#  'r_1832': 1000.0,
#  'r_1861': 1000.0,
#  'r_1992': 1000.0,
#  'r_2005': 1000.0,
#  'r_2020': 1000.0,
#  'r_2049': 1000.0,
#  'r_2060': 1000.0,
#  'r_2100': 1000.0,
#  'r_4593': 1000.0,
#  'r_4594': 1000.0,
#  'r_4595': 1000.0,
#  'r_4596': 1000.0,
#  'r_4597': 1000.0,
#  'r_4600': 1000.0}

# %% [markdown]
# ## Find carbon sources

# %%
base_medium = {
    'r_1654': 1000.0, # ammonium
    'r_1832': 1000.0,
    'r_1861': 1000.0,
    'r_1992': 1000.0, # oxygen
    'r_2005': 1000.0,
    'r_2020': 1000.0,
    'r_2049': 1000.0,
    'r_2060': 1000.0,
    'r_2100': 1000.0,
    'r_4593': 1000.0,
    'r_4594': 1000.0,
    'r_4595': 1000.0,
    'r_4596': 1000.0,
    'r_4597': 1000.0,
    'r_4600': 1000.0
}

carbon_exchanges = []
for rxn in model.exchanges:
    if rxn.id in base_medium:
        continue
    for met in rxn.metabolites:
        if met.formula and 'C' in met.formula:
            carbon_exchanges.append(rxn.id)
            break

growth_threshold = 0.05
carbon_sources = []
results = []
for rxn_id in carbon_exchanges:
    m = model.copy()
    m.medium = base_medium.copy()

    for r in carbon_exchanges:
        m.reactions.get_by_id(r).bounds = (0.0, 1000.0)
    
    test_rxn = m.reactions.get_by_id(rxn_id)
    test_rxn.bounds = (-10.0, 1000.0)
    
    sol = m.optimize()
    if sol is not None and sol.status == "optimal":
        growth = float(sol.objective_value)
    else:
        growth = 0.0

    if growth > growth_threshold:
        carbon_sources.append((rxn_id, sol.objective_value))
        results.append({
            "Carbon source": rxn_id,
            "Name": test_rxn.name,
            "Growth": round(growth, 4)
        })

print(f"Carbon sources found: {len(carbon_sources)}\n")

df_carbons = pd.DataFrame(results)
display(df_carbons)
# Out:
# Carbon sources found: 130
#     Carbon source                                               Name  Growth
# 0          r_1542                      (1->3)-beta-D-glucan exchange  0.8877
# 1          r_1546                               (R)-lactate exchange  0.3616
# 2          r_1551                               (S)-lactate exchange  0.3616
# 3          r_1552                                (S)-malate exchange  0.4145
# 4          r_1586                            2-oxoglutarate exchange  0.5692
# 5          r_1631                              acetaldehyde exchange  0.2652
# 6          r_1634                                   acetate exchange  0.1911
# 7          r_1641          adenosine 3',5'-bismonophosphate exchange  0.7961
# 8          r_1643                                 adenosine exchange  0.7926
# 9          r_1648                                allantoate exchange  0.1122
# 10         r_1649                                 allantoin exchange  0.1122
# 11         r_1650                                 trehalose exchange  1.7661
# 12         r_1651           alpha-D-glucosamine 6-phosphate exchange  0.9376
# 13         r_1687                                   citrate exchange  0.6459
# 14         r_1706                               D-arabinose exchange  0.7237
# 15         r_1709                                D-fructose exchange  0.8877
# 16         r_1710                               D-galactose exchange  0.8601
# 17         r_1712                                D-glucitol exchange  0.9465
# 18         r_1714                                 D-glucose exchange  0.8877
# 19         r_1715                                 D-mannose exchange  0.8601
# 20         r_1716                                  D-ribose exchange  0.7392
# 21         r_1718                                  D-xylose exchange  0.7237
# 22         r_1727                                 decanoate exchange  1.5014
# 23         r_1761                                   ethanol exchange  0.3188
# 24         r_1798                                  fumarate exchange  0.4145
# 25         r_1800                       gamma-aminobutyrate exchange  0.6043
# 26         r_1806                     glutathione disulfide exchange  2.3033
# 27         r_1807                               glutathione exchange  1.1872
# 28         r_1808                                  glycerol exchange  0.4746
# 29         r_1810                                 L-glycine exchange  0.1971
# 30         r_1815                                glyoxylate exchange  0.1122
# 31         r_1820                                 guanosine exchange  0.7916
# 32         r_1847                                   inosine exchange  0.7921
# 33         r_1873                                 L-alanine exchange  0.3826
# 34         r_1875                              L-arabinitol exchange  0.7825
# 35         r_1878                               L-arabinose exchange  0.7082
# 36         r_1879                                L-arginine exchange  0.6781
# 37         r_1880                              L-asparagine exchange  0.4190
# 38         r_1881                               L-aspartate exchange  0.4184
# 39         r_1883                                L-cysteine exchange  0.2850
# 40         r_1889                               L-glutamate exchange  0.6345
# 41         r_1891                               L-glutamine exchange  0.6371
# 42         r_1896                              L-homoserine exchange  0.4415
# 43         r_1904                                 L-proline exchange  0.7124
# 44         r_1906                                  L-serine exchange  0.3256
# 45         r_1911                               L-threonine exchange  0.4826
# 46         r_1913                                L-tyrosine exchange  0.9665
# 47         r_1916                                   laurate exchange  1.8621
# 48         r_1931                                   maltose exchange  1.7631
# 49         r_1984                                 octanoate exchange  1.1778
# 50         r_1987                                 ornithine exchange  0.6736
# 51         r_1989                          oxaloacetate(2-) exchange  0.3574
# 52         r_1993                                 palmitate exchange  2.5421
# 53         r_1994                              palmitoleate exchange  2.5127
# 54         r_2028                                pyridoxine exchange  1.3222
# 55         r_2033                                  pyruvate exchange  0.3228
# 56         r_2043                   S-adenosyl-L-methionine exchange  0.9420
# 57         r_2046               sn-glycero-3-phosphocholine exchange  0.5409
# 58         r_2052                                  spermine exchange  0.3779
# 59         r_2055                                  stearate exchange  2.8774
# 60         r_2056                                 succinate exchange  0.4705
# 61         r_2058                                   sucrose exchange  1.7786
# 62         r_2104                                   xylitol exchange  0.7980
# 63         r_2189                                    oleate exchange  2.8559
# 64         r_2193                                 myristate exchange  2.2008
# 65         r_4043                                 raffinose exchange  0.8877
# 66         r_4496                                   Ala-Gly exchange  0.5888
# 67         r_4497                         3-oxalomalate(3-) exchange  0.4832
# 68         r_4498  6-O-alpha-D-glucopyranosyl-D-fructofuranose ex...  1.7631
# 69         r_4499                     5-dehydro-D-gluconate exchange  0.7392
# 70         r_4500                                D-tagatose exchange  0.8877
# 71         r_4501                                  turanose exchange  1.7786
# 72         r_4502                     D-glucose 6-phosphate exchange  0.9375
# 73         r_4503                         alpha-maltotriose exchange  2.6541
# 74         r_4504                     D-glucose 1-phosphate exchange  0.9375
# 75         r_4505            methyl alpha-D-glucopyranoside exchange  0.8601
# 76         r_4506                             D-Glucosamine exchange  0.8878
# 77         r_4507                                 glycerone exchange  0.4365
# 78         r_4508                                   Ala-Gln exchange  1.0353
# 79         r_4509                                   Ala-Leu exchange  0.4559
# 80         r_4510                                   Gly-Gln exchange  0.8511
# 81         r_4511                                   Ala-His exchange  0.3873
# 82         r_4512                                   Gly-Asn exchange  0.6284
# 83         r_4513                                   Ala-Glu exchange  1.0310
# 84         r_4514                                   Gly-Met exchange  0.2338
# 85         r_4515                                   Ala-Asp exchange  0.8120
# 86         r_4516                                   Gly-Glu exchange  0.8476
# 87         r_4517                                   Ala-Thr exchange  0.8865
# 88         r_4518                                   Met-Ala exchange  0.3949
# 89         r_4519                              L-citrulline exchange  0.6111
# 90         r_4520                          2-aminobutanoate exchange  0.3153
# 91         r_4522                      glycerol 1-phosphate exchange  0.5120
# 92         r_4523                 2-phospho-D-glyceric acid exchange  0.3801
# 93         r_4524                                       GMP exchange  0.7918
# 94         r_4525                          3-phospho-serine exchange  0.3268
# 95         r_4526             O-phosphonatooxy-D-serine(2-) exchange  0.3239
# 96         r_4529                       phosphoenolpyruvate exchange  0.3801
# 97         r_4530               N(omega)-phospho-L-arginine exchange  0.7183
# 98         r_4534                guanosine 2'-monophosphate exchange  0.7916
# 99         r_4535                  glycerol 2-phosphate(2-) exchange  0.5120
# 100        r_4536                                    3'-GMP exchange  0.7916
# 101        r_4537                        2-phosphoglycolate exchange  0.1670
# 102        r_4538                     6-phospho-D-gluconate exchange  0.8630
# 103        r_4539                     D-mannose 6-phosphate exchange  0.9375
# 104        r_4540                          2',3'-cyclic GMP exchange  0.7916
# 105        r_4541                   O(4)-phospho-L-tyrosine exchange  0.9700
# 106        r_4542                     O-phospho-L-threonine exchange  0.4843
# 107        r_4543             3-phosphonato-D-glycerate(3-) exchange  0.3801
# 108        r_4544                    adenosine 2'-phosphate exchange  0.7950
# 109        r_4545                                    3'-AMP exchange  0.7950
# 110        r_4546                          2',3'-cyclic AMP exchange  0.7950
# 111        r_4547                     D-mannose 1-phosphate exchange  0.9341
# 112        r_4548                                       AMP exchange  0.7961
# 113        r_4549              N(alpha)-acetyl-L-methionine exchange  0.1969
# 114        r_4551                       3-sulfino-L-alanine exchange  0.3454
# 115        r_4552                       N-acetyl-L-cysteine exchange  0.5989
# 116        r_4553                                L-cysteate exchange  0.2846
# 117        r_4555                              acetoacetate exchange  0.4590
# 118        r_4556                      N-acetyl-L-glutamate exchange  0.9063
# 119        r_4644                           ethyl hexanoate exchange  1.1377
# 120        r_4645                           ethyl octanoate exchange  1.5960
# 121        r_4646                           ethyl butanoate exchange  0.8013
# 122        r_4658                                  propanal exchange  0.2500
# 123        r_4727                        ethyl-(2S)-lactate exchange  0.7042
# 124        r_4729                        ethyl-(2R)-lactate exchange  0.7042
# 125        r_4731                         diethyl-succinate exchange  1.1430
# 126        r_4733                       monoethyl-succinate exchange  0.8190
# 127        r_4737                            ethyl-pyruvate exchange  0.6645
# 128        r_4741                         ethyl-isobutyrate exchange  0.2652
# 129        r_4743                    ethyl-2-methylbutyrate exchange  0.2652

# %% [markdown]
# ## Extract and Display Selected Metabolites and Reactions
#
# This section displays detailed information for selected metabolites and reactions involved in the model.

# %%
metabolite_ids = [
    "s_0420", "s_0565", "s_0796", "s_0925", "s_1277",
    "s_1324", "s_1374", "s_1438", "s_1468",
    "s_4200", "s_4201", "s_4202", "s_4203", "s_4204", "s_4199",
    "s_0458", "s_0776", "s_0805", "s_0450", "s_4157"
]
reaction_ids = [
    "r_1654", "r_1714", "r_1832", "r_1861", "r_1992", "r_2005", "r_2020",
    "r_2049", "r_2060", "r_4593", "r_4594", "r_4595", "r_4596", "r_4597",
    "r_4600", "r_1672", "r_1814", "r_2100", "r_2111", "r_4527"
]

# Extract data
metabolite_info = [
    (m.id, m.name, m.formula, m.compartment) 
    for m in model.metabolites if m.id in metabolite_ids
]
reaction_info = [
    (r.id, r.name, r.reaction) 
    for r in model.reactions if r.id in reaction_ids
]

# Convert to dataframes
metabolite_df = pd.DataFrame(metabolite_info, columns=["ID", "Name", "Formula", "Compartment"])
reaction_df = pd.DataFrame(reaction_info, columns=["ID", "Name", "Equation"])

display(metabolite_df.style.set_caption("Metabolites Involved"))
display(reaction_df.style.set_caption("Reactions Involved"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_40f1d">
#   <caption>Metabolites Involved</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40f1d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_40f1d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_40f1d_level0_col2" class="col_heading level0 col2" >Formula</th>
#       <th id="T_40f1d_level0_col3" class="col_heading level0 col3" >Compartment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40f1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40f1d_row0_col0" class="data row0 col0" >s_0420</td>
#       <td id="T_40f1d_row0_col1" class="data row0 col1" >ammonium</td>
#       <td id="T_40f1d_row0_col2" class="data row0 col2" >H4N</td>
#       <td id="T_40f1d_row0_col3" class="data row0 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40f1d_row1_col0" class="data row1 col0" >s_0450</td>
#       <td id="T_40f1d_row1_col1" class="data row1 col1" >biomass</td>
#       <td id="T_40f1d_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_40f1d_row1_col3" class="data row1 col3" >c</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40f1d_row2_col0" class="data row2 col0" >s_0458</td>
#       <td id="T_40f1d_row2_col1" class="data row2 col1" >carbon dioxide</td>
#       <td id="T_40f1d_row2_col2" class="data row2 col2" >CO2</td>
#       <td id="T_40f1d_row2_col3" class="data row2 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40f1d_row3_col0" class="data row3 col0" >s_0565</td>
#       <td id="T_40f1d_row3_col1" class="data row3 col1" >D-glucose</td>
#       <td id="T_40f1d_row3_col2" class="data row3 col2" >C6H12O6</td>
#       <td id="T_40f1d_row3_col3" class="data row3 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40f1d_row4_col0" class="data row4 col0" >s_0776</td>
#       <td id="T_40f1d_row4_col1" class="data row4 col1" >glycolaldehyde</td>
#       <td id="T_40f1d_row4_col2" class="data row4 col2" >C2H4O2</td>
#       <td id="T_40f1d_row4_col3" class="data row4 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40f1d_row5_col0" class="data row5 col0" >s_0796</td>
#       <td id="T_40f1d_row5_col1" class="data row5 col1" >H+</td>
#       <td id="T_40f1d_row5_col2" class="data row5 col2" >H</td>
#       <td id="T_40f1d_row5_col3" class="data row5 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40f1d_row6_col0" class="data row6 col0" >s_0805</td>
#       <td id="T_40f1d_row6_col1" class="data row6 col1" >H2O</td>
#       <td id="T_40f1d_row6_col2" class="data row6 col2" >H2O</td>
#       <td id="T_40f1d_row6_col3" class="data row6 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40f1d_row7_col0" class="data row7 col0" >s_0925</td>
#       <td id="T_40f1d_row7_col1" class="data row7 col1" >iron(2+)</td>
#       <td id="T_40f1d_row7_col2" class="data row7 col2" >Fe</td>
#       <td id="T_40f1d_row7_col3" class="data row7 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40f1d_row8_col0" class="data row8 col0" >s_1277</td>
#       <td id="T_40f1d_row8_col1" class="data row8 col1" >oxygen</td>
#       <td id="T_40f1d_row8_col2" class="data row8 col2" >O2</td>
#       <td id="T_40f1d_row8_col3" class="data row8 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40f1d_row9_col0" class="data row9 col0" >s_1324</td>
#       <td id="T_40f1d_row9_col1" class="data row9 col1" >phosphate</td>
#       <td id="T_40f1d_row9_col2" class="data row9 col2" >HO4P</td>
#       <td id="T_40f1d_row9_col3" class="data row9 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_40f1d_row10_col0" class="data row10 col0" >s_1374</td>
#       <td id="T_40f1d_row10_col1" class="data row10 col1" >potassium</td>
#       <td id="T_40f1d_row10_col2" class="data row10 col2" >K</td>
#       <td id="T_40f1d_row10_col3" class="data row10 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_40f1d_row11_col0" class="data row11 col0" >s_1438</td>
#       <td id="T_40f1d_row11_col1" class="data row11 col1" >sodium</td>
#       <td id="T_40f1d_row11_col2" class="data row11 col2" >Na</td>
#       <td id="T_40f1d_row11_col3" class="data row11 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_40f1d_row12_col0" class="data row12 col0" >s_1468</td>
#       <td id="T_40f1d_row12_col1" class="data row12 col1" >sulphate</td>
#       <td id="T_40f1d_row12_col2" class="data row12 col2" >O4S</td>
#       <td id="T_40f1d_row12_col3" class="data row12 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_40f1d_row13_col0" class="data row13 col0" >s_4157</td>
#       <td id="T_40f1d_row13_col1" class="data row13 col1" >diphosphate</td>
#       <td id="T_40f1d_row13_col2" class="data row13 col2" >HO7P2</td>
#       <td id="T_40f1d_row13_col3" class="data row13 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_40f1d_row14_col0" class="data row14 col0" >s_4199</td>
#       <td id="T_40f1d_row14_col1" class="data row14 col1" >Ca(2+)</td>
#       <td id="T_40f1d_row14_col2" class="data row14 col2" >Ca</td>
#       <td id="T_40f1d_row14_col3" class="data row14 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_40f1d_row15_col0" class="data row15 col0" >s_4200</td>
#       <td id="T_40f1d_row15_col1" class="data row15 col1" >chloride</td>
#       <td id="T_40f1d_row15_col2" class="data row15 col2" >Cl</td>
#       <td id="T_40f1d_row15_col3" class="data row15 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_40f1d_row16_col0" class="data row16 col0" >s_4201</td>
#       <td id="T_40f1d_row16_col1" class="data row16 col1" >Cu2(+)</td>
#       <td id="T_40f1d_row16_col2" class="data row16 col2" >Cu</td>
#       <td id="T_40f1d_row16_col3" class="data row16 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_40f1d_row17_col0" class="data row17 col0" >s_4202</td>
#       <td id="T_40f1d_row17_col1" class="data row17 col1" >Mn(2+)</td>
#       <td id="T_40f1d_row17_col2" class="data row17 col2" >Mn</td>
#       <td id="T_40f1d_row17_col3" class="data row17 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_40f1d_row18_col0" class="data row18 col0" >s_4203</td>
#       <td id="T_40f1d_row18_col1" class="data row18 col1" >Zn(2+)</td>
#       <td id="T_40f1d_row18_col2" class="data row18 col2" >Zn</td>
#       <td id="T_40f1d_row18_col3" class="data row18 col3" >e</td>
#     </tr>
#     <tr>
#       <th id="T_40f1d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_40f1d_row19_col0" class="data row19 col0" >s_4204</td>
#       <td id="T_40f1d_row19_col1" class="data row19 col1" >Mg(2+)</td>
#       <td id="T_40f1d_row19_col2" class="data row19 col2" >Mg</td>
#       <td id="T_40f1d_row19_col3" class="data row19 col3" >e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a2c18">
#   <caption>Reactions Involved</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2c18_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a2c18_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a2c18_level0_col2" class="col_heading level0 col2" >Equation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2c18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2c18_row0_col0" class="data row0 col0" >r_1654</td>
#       <td id="T_a2c18_row0_col1" class="data row0 col1" >ammonium exchange</td>
#       <td id="T_a2c18_row0_col2" class="data row0 col2" >s_0420 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2c18_row1_col0" class="data row1 col0" >r_1672</td>
#       <td id="T_a2c18_row1_col1" class="data row1 col1" >carbon dioxide exchange</td>
#       <td id="T_a2c18_row1_col2" class="data row1 col2" >s_0458 --> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2c18_row2_col0" class="data row2 col0" >r_1714</td>
#       <td id="T_a2c18_row2_col1" class="data row2 col1" >D-glucose exchange</td>
#       <td id="T_a2c18_row2_col2" class="data row2 col2" >s_0565 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a2c18_row3_col0" class="data row3 col0" >r_1814</td>
#       <td id="T_a2c18_row3_col1" class="data row3 col1" >glycolaldehyde exchange</td>
#       <td id="T_a2c18_row3_col2" class="data row3 col2" >s_0776 --> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a2c18_row4_col0" class="data row4 col0" >r_1832</td>
#       <td id="T_a2c18_row4_col1" class="data row4 col1" >H+ exchange</td>
#       <td id="T_a2c18_row4_col2" class="data row4 col2" >s_0796 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a2c18_row5_col0" class="data row5 col0" >r_1861</td>
#       <td id="T_a2c18_row5_col1" class="data row5 col1" >iron(2+) exchange</td>
#       <td id="T_a2c18_row5_col2" class="data row5 col2" >s_0925 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a2c18_row6_col0" class="data row6 col0" >r_1992</td>
#       <td id="T_a2c18_row6_col1" class="data row6 col1" >oxygen exchange</td>
#       <td id="T_a2c18_row6_col2" class="data row6 col2" >s_1277 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a2c18_row7_col0" class="data row7 col0" >r_2005</td>
#       <td id="T_a2c18_row7_col1" class="data row7 col1" >phosphate exchange</td>
#       <td id="T_a2c18_row7_col2" class="data row7 col2" >s_1324 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a2c18_row8_col0" class="data row8 col0" >r_2020</td>
#       <td id="T_a2c18_row8_col1" class="data row8 col1" >potassium exchange</td>
#       <td id="T_a2c18_row8_col2" class="data row8 col2" >s_1374 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a2c18_row9_col0" class="data row9 col0" >r_2049</td>
#       <td id="T_a2c18_row9_col1" class="data row9 col1" >sodium exchange</td>
#       <td id="T_a2c18_row9_col2" class="data row9 col2" >s_1438 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a2c18_row10_col0" class="data row10 col0" >r_2060</td>
#       <td id="T_a2c18_row10_col1" class="data row10 col1" >sulphate exchange</td>
#       <td id="T_a2c18_row10_col2" class="data row10 col2" >s_1468 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a2c18_row11_col0" class="data row11 col0" >r_2100</td>
#       <td id="T_a2c18_row11_col1" class="data row11 col1" >water exchange</td>
#       <td id="T_a2c18_row11_col2" class="data row11 col2" >s_0805 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a2c18_row12_col0" class="data row12 col0" >r_2111</td>
#       <td id="T_a2c18_row12_col1" class="data row12 col1" >growth</td>
#       <td id="T_a2c18_row12_col2" class="data row12 col2" >s_0450 --> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a2c18_row13_col0" class="data row13 col0" >r_4527</td>
#       <td id="T_a2c18_row13_col1" class="data row13 col1" >diphosphate exchange</td>
#       <td id="T_a2c18_row13_col2" class="data row13 col2" >s_4157 --> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a2c18_row14_col0" class="data row14 col0" >r_4593</td>
#       <td id="T_a2c18_row14_col1" class="data row14 col1" >chloride exchange</td>
#       <td id="T_a2c18_row14_col2" class="data row14 col2" >s_4200 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a2c18_row15_col0" class="data row15 col0" >r_4594</td>
#       <td id="T_a2c18_row15_col1" class="data row15 col1" >Cu2(+) exchange</td>
#       <td id="T_a2c18_row15_col2" class="data row15 col2" >s_4201 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a2c18_row16_col0" class="data row16 col0" >r_4595</td>
#       <td id="T_a2c18_row16_col1" class="data row16 col1" >Mn(2+) exchange</td>
#       <td id="T_a2c18_row16_col2" class="data row16 col2" >s_4202 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a2c18_row17_col0" class="data row17 col0" >r_4596</td>
#       <td id="T_a2c18_row17_col1" class="data row17 col1" >Zn(2+) exchange</td>
#       <td id="T_a2c18_row17_col2" class="data row17 col2" >s_4203 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a2c18_row18_col0" class="data row18 col0" >r_4597</td>
#       <td id="T_a2c18_row18_col1" class="data row18 col1" >Mg(2+) exchange</td>
#       <td id="T_a2c18_row18_col2" class="data row18 col2" >s_4204 <=> </td>
#     </tr>
#     <tr>
#       <th id="T_a2c18_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a2c18_row19_col0" class="data row19 col0" >r_4600</td>
#       <td id="T_a2c18_row19_col1" class="data row19 col1" >Ca(2+) exchange</td>
#       <td id="T_a2c18_row19_col2" class="data row19 col2" >s_4199 <=> </td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inspect Specific Reaction and Metabolite
#
# Helper function for detailed inspection of a specific reaction and metabolite within the model.

# %%
def inspect_reaction_and_metabolite(model, reaction_id, metabolite_id):
    # Inspect the reaction
    reaction = model.reactions.get_by_id(reaction_id)
    print("=== Reaction Details ===")
    print(f"ID        : {reaction.id}")
    print(f"Name      : {reaction.name}")
    print(f"Equation  : {reaction.reaction}")
    print(f"GPR       : {reaction.gene_reaction_rule}")

    # Inspect the metabolite
    metabolite = model.metabolites.get_by_id(metabolite_id)
    print("\n=== Metabolite Details ===")
    print(f"ID         : {metabolite.id}")
    print(f"Name       : {metabolite.name}")
    print(f"Formula    : {metabolite.formula}")
    print(f"Compartment: {metabolite.compartment}")
    print("Annotations:")
    for key, value in metabolite.annotation.items():
        print(f"  {key}: {value}")

    # List reactions involving this metabolite
    print("\nReactions involving this metabolite:")
    for r in metabolite.reactions:
        print(f"{r.id}: {r.reaction}")

# %%
inspect_reaction_and_metabolite(models["yeast9"], "r_1714", "s_0565")
# Out:
# === Reaction Details ===
# ID        : r_1714
# Name      : D-glucose exchange
# Equation  : s_0565 <=>
# GPR       :
#
# === Metabolite Details ===
# ID         : s_0565
# Name       : D-glucose
# Formula    : C6H12O6
# Compartment: e
# Annotations:
#   sbo: SBO:0000247
#   bigg.metabolite: glc__D
#   chebi: CHEBI:4167
#   kegg.compound: C00031
#   metanetx.chemical: MNXM41
#
# Reactions involving this metabolite:
# r_1024: s_0805 + s_1466 --> s_0554 + s_0565
# r_1714: s_0565 <=>
# r_0370: s_0003 + s_0805 --> s_0565
# r_4400: s_0805 + s_4140 --> s_0565 + s_1106
# r_4420: s_0805 + s_4131 <=> s_0554 + s_0565
# r_1166: s_0565 --> s_0563

# %%
# Inspect biomass growth
inspect_reaction_and_metabolite(models["yeast9"], "r_2111", "s_0450")
# Out:
# === Reaction Details ===
# ID        : r_2111
# Name      : growth
# Equation  : s_0450 -->
# GPR       :
#
# === Metabolite Details ===
# ID         : s_0450
# Name       : biomass
# Formula    : None
# Compartment: c
# Annotations:
#   sbo: SBO:0000649
#   bigg.metabolite: biomass
#
# Reactions involving this metabolite:
# r_4041: 55.3 s_0434 + 55.3 s_0803 + s_1096 + s_3717 + s_3718 + s_3719 + s_3720 + s_4205 + s_4206 --> 55.3 s_0394 + s_0450 + 55.3 s_0794 + 55.3 s_1322
# r_2111: s_0450 -->

# %% [markdown]
# ## Full Reaction Overview
#
# All reactions in the model are collected into a DataFrame with basic metadata: reaction ID, name, equation, flux bounds, and associated genes. This provides a structured overview for further inspection or export.

# %%
reaction_data = []
reaction_ids = []

for rxn in model.reactions:
    reaction_ids.append(rxn.id)
    reaction_data.append({
        "Reaction ID": rxn.id,
        "Name": rxn.name,
        "Equation": rxn.reaction,
        "Bounds (mmol/gDW/h)": rxn.bounds,
        #"Subsystem": getattr(rxn, "subsystem", "N/A"),
        "Gene Associations": ", ".join(g.id for g in rxn.genes) if rxn.genes else "None"
    })

df_reactions = pd.DataFrame(reaction_data)
display(df_reactions)

# print all reactions as a list
print(reaction_ids)
# Out:
#      Reaction ID                                               Name  \
# 0         r_0001     (R)-lactate:ferricytochrome-c 2-oxidoreductase
# 1         r_0002     (R)-lactate:ferricytochrome-c 2-oxidoreductase
# 2         r_0003                     (R,R)-butanediol dehydrogenase
# 3         r_0004     (S)-lactate:ferricytochrome-c 2-oxidoreductase
# 4         r_0005                           1,3-beta-glucan synthase
# 5         r_0006                           1,6-beta-glucan synthase
# 6         r_0007  1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino...
# 7         r_0012            1-pyrroline-5-carboxylate dehydrogenase
# 8         r_0013  2,3-diketo-5-methylthio-1-phosphopentane degra...
# 9         r_0014  2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone ...
# 10        r_0015  2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone ...
# 11        r_0016                2-aceto-2-hydroxybutanoate synthase
# 12        r_0017  2-amino-4-hydroxy-6-hydroxymethyldihydropterid...
# 13        r_0018                        2-aminoadipate transaminase
# 14        r_0019                      2-dehydropantoate 2-reductase
# 15        r_0020  2-deoxy-D-arabino-heptulosonate 7-phosphate sy...
# 16        r_0021  2-hexaprenyl-6-methoxy-1,4-benzoquinone methyl...
# 17        r_0022         2-hexaprenyl-6-methoxyphenol monooxygenase
# 18        r_0023                        2-isopropylmalate hydratase
# 19        r_0024                         2-isopropylmalate synthase
# 20        r_0025                         2-isopropylmalate synthase
# 21        r_0026         2-keto-4-methylthiobutyrate transamination
# 22        r_0027                        2-methylcitrate dehydratase
# 23        r_0028                           2-methylcitrate synthase
# 24        r_0029  2-oxo-4-methyl-3-carboxypentanoate decarboxyla...
# 25        r_0030  2-oxo-4-methyl-3-carboxypentanoate decarboxyla...
# 26        r_0032                    3',5'-bisphosphate nucleotidase
# 27        r_0033          3',5'-cyclic-nucleotide phosphodiesterase
# 28        r_0034          3',5'-cyclic-nucleotide phosphodiesterase
# 29        r_0035          3',5'-cyclic-nucleotide phosphodiesterase
# 30        r_0036          3',5'-cyclic-nucleotide phosphodiesterase
# 31        r_0037          3',5'-cyclic-nucleotide phosphodiesterase
# 32        r_0038      3,4-dihydroxy-2-butanone-4-phosphate synthase
# 33        r_0039                       3-dehydroquinate dehydratase
# 34        r_0040                          3-dehydroquinate synthase
# 35        r_0041                     3-dehydrosphinganine reductase
# 36        r_0042  3-deoxy-D-arabino-heptulosonate 7-phosphate sy...
# 37        r_0043     3-hexaprenyl-4,5-dihydroxybenzoate hydroxylase
# 38        r_0044  3-hexaprenyl-4-hydroxy-5-methoxybenzoate decar...
# 39        r_0045                   3-hydroxy-L-kynurenine hydrolase
# 40        r_0057  3-hydroxyacyl-CoA dehydrogenase (3-oxotetradec...
# 41        r_0058              3-hydroxyanthranilate 3,4-dioxygenase
# 42        r_0059              3-isopropylmalate 3-methyltransferase
# 43        r_0060                      3-isopropylmalate dehydratase
# 44        r_0061                    3-isopropylmalate dehydrogenase
# 45        r_0062              3-methyl-2-oxobutanoate decarboxylase
# 46        r_0063   3-methyl-2-oxobutanoate hydroxymethyltransferase
# 47        r_0064             3-methyl-2-oxopentanoate decarboxylase
# 48        r_0065       3-phosphoshikimate 1-carboxyvinyltransferase
# 49        r_0066                 4-amino-4-deoxychorismate synthase
# 50        r_0067                           4-aminobenzoate synthase
# 51        r_0068                       4-aminobutyrate transaminase
# 52        r_0069                     4-hydroxy-L-threonine synthase
# 53        r_0070                        4-hydroxybenzoate formation
# 54        r_0072             4-methyl-2-oxopentanoate decarboxylase
# 55        r_0073               4PP-IP5 depyrophosphorylation to IP6
# 56        r_0074         4PP-IP5 pyrophosphorylation to 4,5-PP2-IP4
# 57        r_0075               5'-methylthioadenosine phosphorylase
# 58        r_0076                              5'-nucleotidase (CMP)
# 59        r_0077                              5'-nucleotidase (IMP)
# 60        r_0078                              5'-nucleotidase (UMP)
# 61        r_0079   5'-phosphoribosylformyl glycinamidine synthetase
# 62        r_0080   5,10-methylenetetrahydrofolate reductase (NADPH)
# 63        r_0081                         5-aminolevulinate synthase
# 64        r_0082  5-diphosphoinositol-1,2,3,4,6-pentakisphosphat...
# 65        r_0083  5-diphosphoinositol-1,2,3,4,6-pentakisphosphat...
# 66        r_0084           5-formethyltetrahydrofolate cyclo-ligase
# 67        r_0085  5-methyltetrahydropteroyltriglutamate-homocyst...
# 68        r_0086  5-methylthio-5-deoxy-D-ribulose 1-phosphate de...
# 69        r_0087           5-methylthioribose-1-phosphate isomerase
# 70        r_0088         5PP-IP5 pyrophosphorylation to 4,5-PP2-IP4
# 71        r_0089         5PP-IP5 pyrophosphorylation to 5,6-PP2-IP4
# 72        r_0090                           6-phosphofructo-2-kinase
# 73        r_0091                          6-phosphogluconolactonase
# 74        r_0092               6PP-IP5 depyrophosphorylation to IP6
# 75        r_0093         6PP-IP5 pyrophosphorylation to 5,6-PP2-IP4
# 76        r_0094                    8-amino-7-oxononanoate synthase
# 77        r_0095                          acetaldehyde condensation
# 78        r_0096                 acetohydroxy acid isomeroreductase
# 79        r_0097                              acetolactate synthase
# 80        r_0099                        acetyl-CoA ACP transacylase
# 81        r_0100       acetyl-CoA C-acyltransferase (palmitoyl-CoA)
# 82        r_0101   acetyl-CoA C-acyltransferase (tetracosanoyl-CoA)
# 83        r_0102       acetyl-CoA C-acyltransferase (myristoyl-CoA)
# 84        r_0103                     acetyl-CoA C-acetyltransferase
# 85        r_0104                     acetyl-CoA C-acetyltransferase
# 86        r_0105         acetyl-CoA C-acyltransferase (lauroyl-CoA)
# 87        r_0106        acetyl-CoA C-acyltransferase (octanoyl-CoA)
# 88        r_0107        acetyl-CoA C-acyltransferase (decanoyl-CoA)
# 89        r_0108                             acetyl-Coa carboxylase
# 90        r_0109                   acetyl-CoA carboxylase, reaction
# 91        r_0111                               acetyl-CoA hydrolase
# 92        r_0112                              acetyl-CoA synthetase
# 93        r_0113                              acetyl-CoA synthetase
# 94        r_0114                      acetyl-CoA synthetase nuclear
# 95        r_0115                             acetylglutamate kinase
# 96        r_0116                        acid phosphatase (secreted)
# 97        r_0117                                          aconitase
# 98        r_0118                       acteylornithine transaminase
# 99        r_0119                      acyl carrier protein synthase
# 100       r_0120                    acyl-CoA oxidase (decanoyl-CoA)
# 101       r_0121                  acyl-CoA oxidase (dodecanoyl-CoA)
# 102       r_0122                acyl-CoA oxidase (hexacosanoyl-CoA)
# 103       r_0123                acyl-CoA oxidase (hexadecanoyl-CoA)
# 104       r_0124                acyl-CoA oxidase (octadecanoyl-CoA)
# 105       r_0125               acyl-CoA oxidase (tetradecanoyl-CoA)
# 106       r_0126  acyl-CoA:sterol acyltransferase (oleoyl-CoA:ep...
# 107       r_0127  acyl-CoA:sterol acyltransferase (oleoyl-CoA:er...
# 108       r_0128  acyl-CoA:sterol acyltransferase (oleoyl-CoA:fe...
# 109       r_0129  acyl-CoA:sterol acyltransferase (oleoyl-CoA:la...
# 110       r_0130  acyl-CoA:sterol acyltransferase (oleoyl-CoA:zy...
# 111       r_0131  acyl-CoA:sterol acyltransferase (palmitoleoyl-...
# 112       r_0132  acyl-CoA:sterol acyltransferase (palmitoleoyl-...
# 113       r_0133  acyl-CoA:sterol acyltransferase (palmitoleoyl-...
# 114       r_0134  acyl-CoA:sterol acyltransferase (palmitoleoyl-...
# 115       r_0135  acyl-CoA:sterol acyltransferase (palmitoleoyl-...
# 116       r_0137  acylation of GPI inositol at 2 position, GPI-a...
# 117       r_0138                                  adenine deaminase
# 118       r_0139                  adenine phosphoribosyltransferase
# 119       r_0140                                adenosine deaminase
# 120       r_0142                                   adenosine kinase
# 121       r_0143                  adenosine monophosphate deaminase
# 122       r_0144                             adenosylhomocysteinase
# 123       r_0145                   adenosylmethionine decarboxylase
# 124       r_0146  adenosylmethionine-8-amino-7-oxononanoate tran...
# 125       r_0147                                  adenylate cyclase
# 126       r_0148                                   adenylate kinase
# 127       r_0149                                   adenylate kinase
# 128       r_0150                             adenylate kinase (GTP)
# 129       r_0151                     adenylosuccinate lyase (AICAR)
# 130       r_0152                             adenylosuccinate lyase
# 131       r_0153                          adenylosuccinate synthase
# 132       r_0154                            adenylyl-sulfate kinase
# 133       r_0155            ADP-ribose 2,3-cyclic phosphodiesterase
# 134       r_0156                alanine glyoxylate aminotransferase
# 135       r_0157                             alanyl-tRNA synthetase
# 136       r_0158        alcohol acetyltransferase (2-methylbutanol)
# 137       r_0159                alcohol acetyltransferase (ethanol)
# 138       r_0160        alcohol acetyltransferase (isoamyl alcohol)
# 139       r_0161       alcohol acetyltransferase (isobutyl alcohol)
# 140       r_0162  alcohol acetyltransferase (phenylethanol alcohol)
# 141       r_0163    alcohol dehydrogenase (ethanol to acetaldehyde)
# 142       r_0164             alcohol dehydrogenase (glycerol, NADP)
# 143       r_0165                mitochondrial alcohol dehydrogenase
# 144       r_0166      aldehyde dehydrogenase (2-methylbutanol, NAD)
# 145       r_0167      aldehyde dehydrogenase (2-methylbutanol, NAD)
# 146       r_0168     aldehyde dehydrogenase (2-methylbutanol, NADP)
# 147       r_0169      aldehyde dehydrogenase (2-phenylethanol, NAD)
# 148       r_0170      aldehyde dehydrogenase (2-phenylethanol, NAD)
# 149       r_0171     aldehyde dehydrogenase (2-phenylethanol, NADP)
# 150       r_0172      aldehyde dehydrogenase (3-aminopropanal, NAD)
# 151       r_0173        aldehyde dehydrogenase (acetaldehyde, NADP)
# 152       r_0174       aldehyde dehydrogenase (acetylaldehyde, NAD)
# 153       r_0175      aldehyde dehydrogenase (acetylaldehyde, NADP)
# 154       r_0176  aldehyde dehydrogenase (indole-3-acetaldehyde,...
# 155       r_0177  aldehyde dehydrogenase (indole-3-acetaldehyde,...
# 156       r_0178  aldehyde dehydrogenase (indole-3-acetaldehyde,...
# 157       r_0179      aldehyde dehydrogenase (isoamyl alcohol, NAD)
# 158       r_0180      aldehyde dehydrogenase (isoamyl alcohol, NAD)
# 159       r_0181     aldehyde dehydrogenase (isoamyl alcohol, NADP)
# 160       r_0182     aldehyde dehydrogenase (isobutyl alcohol, NAD)
# 161       r_0183     aldehyde dehydrogenase (isobutyl alcohol, NAD)
# 162       r_0184    aldehyde dehydrogenase (isobutyl alcohol, NADP)
# 163       r_0185   aldehyde dehydrogenase (phenylacetaldehyde, NAD)
# 164       r_0186           aldehyde dehydrogenase (tryptophol, NAD)
# 165       r_0187           aldehyde dehydrogenase (tryptophol, NAD)
# 166       r_0188            alkaline phosphatase (dihydroneopterin)
# 167       r_0189                        allantoate amidinohydrolase
# 168       r_0190                             allantoinase, reaction
# 169       r_0191                              allophanate hydrolase
# 170       r_0192                      alpha 1,2-mannosyltransferase
# 171       r_0193                              alpha,alpha-trehalase
# 172       r_0194                              alpha,alpha-trehalase
# 173       r_0195  alpha,alpha-trehalose-phosphate synthase (UDP-...
# 174       r_0198                                  alpha-glucosidase
# 175       r_0199                                            amidase
# 176       r_0200  Aminoacetone:oxygen oxidoreductase(deaminating...
# 177       r_0201                   Aminobutyraldehyde dehydrogenase
# 178       r_0202             anthranilate phosphoribosyltransferase
# 179       r_0203                              anthranilate synthase
# 180       r_0204                                     Ap4A hydrolase
# 181       r_0205                                arabinose reductase
# 182       r_0206                                           arginase
# 183       r_0207                            argininosuccinate lyase
# 184       r_0208                         argininosuccinate synthase
# 185       r_0209                            arginyl-tRNA synthetase
# 186       r_0210                            arginyl-tRNA synthetase
# 187       r_0211        asparagine synthase (glutamine-hydrolysing)
# 188       r_0212                        Asparaginyl-tRNA synthetase
# 189       r_0213         asparaginyl-tRNA synthetase, miotchondrial
# 190       r_0214                     aspartate carbamoyltransferase
# 191       r_0215                                   aspartate kinase
# 192       r_0216                             aspartate transaminase
# 193       r_0217                             aspartate transaminase
# 194       r_0218                             aspartate transaminase
# 195       r_0219               aspartate-semialdehyde dehydrogenase
# 196       r_0220                           Aspartyl-tRNA synthetase
# 197       r_0221                           Aspartyl-tRNA synthetase
# 198       r_0222                            ATP adenylyltransferase
# 199       r_0223                            ATP adenylyltransferase
# 200       r_0224                            ATP adenylyltransferase
# 201       r_0225                      ATP phosphoribosyltransferase
# 202       r_0226                                       ATP synthase
# 203       r_0227                                  ATPase, cytosolic
# 204       r_0228                       beta-1,4 mannosyltransferase
# 205       r_0229                                    biotin synthase
# 206       r_0230             biotin-[acetyl-CoA-carboxylase] ligase
# 207       r_0231                              C-14 sterol reductase
# 208       r_0233                      C-22 sterol desaturase (NADP)
# 209       r_0234                           C-3 sterol dehydrogenase
# 210       r_0235      C-3 sterol dehydrogenase (4-methylzymosterol)
# 211       r_0236     C-3 sterol keto reductase (4-methylzymosterol)
# 212       r_0237             C-3 sterol keto reductase (zymosterol)
# 213       r_0238                          C-4 methyl sterol oxidase
# 214       r_0239                          C-4 methyl sterol oxidase
# 215       r_0240                          C-4 methyl sterol oxidase
# 216       r_0241  C-4 sterol methyl oxidase (4,4-dimethylzymoste...
# 217       r_0242                              C-5 sterol desaturase
# 218       r_0243                               C-8 sterol isomerase
# 219       r_0244                             C-s24 sterol reductase
# 220       r_0249                           CAAX farnesyltransferase
# 221       r_0250  carbamoyl-phosphate synthase (glutamine-hydrol...
# 222       r_0252                      carnitine O-acetyltransferase
# 223       r_0253                      carnitine O-acetyltransferase
# 224       r_0254                      carnitine O-acetyltransferase
# 225       r_0255                                           catalase
# 226       r_0256                                           catalase
# 227       r_0259                       ceramide-1 hydroxylase (24C)
# 228       r_0260                       ceramide-1 hydroxylase (24C)
# 229       r_0261                       ceramide-1 hydroxylase (26C)
# 230       r_0262                       ceramide-1 hydroxylase (26C)
# 231       r_0263                          ceramide-1 synthase (24C)
# 232       r_0264                          ceramide-1 synthase (26C)
# 233       r_0265                          ceramide-2 synthase (24C)
# 234       r_0266                          ceramide-2 synthase (26C)
# 235       r_0267                          ceramide-3 synthase (24C)
# 236       r_0268                          ceramide-3 synthase (26C)
# 237       r_0269                          ceramide-4 synthase (24C)
# 238       r_0270                          ceramide-4 synthase (26C)
# 239       r_0271                                 chitin deacetylase
# 240       r_0272                                    chitin synthase
# 241       r_0273                                     choline kinase
# 242       r_0274             choline phosphate cytididyltransferase
# 243       r_0278                                  chorismate mutase
# 244       r_0279                                chorismate synthase
# 245       r_0280                    cis-aconitate(3-) to isocitrate
# 246       r_0281                      cis-prenyltransferase step 01
# 247       r_0282                      cis-prenyltransferase step 02
# 248       r_0283                      cis-prenyltransferase step 03
# 249       r_0284                      cis-prenyltransferase step 04
# 250       r_0285                      cis-prenyltransferase step 05
# 251       r_0286                      cis-prenyltransferase step 06
# 252       r_0287                      cis-prenyltransferase step 07
# 253       r_0288                      cis-prenyltransferase step 08
# 254       r_0289                      cis-prenyltransferase step 09
# 255       r_0290                      cis-prenyltransferase step 10
# 256       r_0291                      cis-prenyltransferase step 11
# 257       r_0292                      cis-prenyltransferase step 12
# 258       r_0293                      cis-prenyltransferase step 13
# 259       r_0294                      cis-prenyltransferase step 14
# 260       r_0295                      cis-prenyltransferase step 15
# 261       r_0296                      cis-prenyltransferase step 16
# 262       r_0297                      cis-prenyltransferase step 17
# 263       r_0298                      cis-prenyltransferase step 18
# 264       r_0299                      cis-prenyltransferase step 19
# 265       r_0300                                   citrate synthase
# 266       r_0301                      citrate synthase, peroxisomal
# 267       r_0302                       citrate to cis-aconitate(3-)
# 268       r_0303          citrate to cis-aconitate(3-), cytoplasmic
# 269       r_0304           coproporphyrinogen oxidase (O2 required)
# 270       r_0306                           CTP synthase (glutamine)
# 271       r_0307                                 CTP synthase (NH3)
# 272       r_0308                              cystathionine b-lyase
# 273       r_0309                        cystathionine beta-synthase
# 274       r_0310                              cystathionine g-lyase
# 275       r_0311                       cystathionine gamma-synthase
# 276       r_0312                                  cysteine synthase
# 277       r_0313                          cysteinyl-tRNA synthetase
# 278       r_0314                                 cytidine deaminase
# 279       r_0315                              cytidine kinase (GTP)
# 280       r_0317  cytochrome P450 lanosterol 14-alpha-demethylas...
# 281       r_0318                                 cytosine deaminase
# 282       r_0319                    D-arabinono-1,4-lactone oxidase
# 283       r_0320                  D-arabinose 1-dehydrogenase (NAD)
# 284       r_0321                 D-arabinose 1-dehydrogenase (NADP)
# 285       r_0322  D-fructose 1-phosphate D-glyceraldehyde-3-phos...
# 286       r_0323    D-sorbitol dehydrogenase (D-fructose producing)
# 287       r_0326                                     dCMP deaminase
# 288       r_0327                                     dCTP deaminase
# 289       r_0328                           deoxyadenosine deaminase
# 290       r_0329                            deoxycytidine deaminase
# 291       r_0330                   deoxyguanylate kinase (dGMP:ATP)
# 292       r_0331    deoxyhypusine synthase, cytosolic/mitochondrial
# 293       r_0332                                    deoxyribokinase
# 294       r_0334                               dephospho-CoA kinase
# 295       r_0335                              dethiobiotin synthase
# 296       r_0340                                  dihydroceramidase
# 297       r_0341                                  dihydroceramidase
# 298       r_0342                                  dihydroceramidase
# 299       r_0343                                  dihydroceramidase
# 300       r_0344                            dihydrofolate reductase
# 301       r_0345                            dihydrofolate reductase
# 302       r_0346                             dihydrofolate synthase
# 303       r_0347                          dihydroneopterin aldolase
# 304       r_0348     dihydroneopterin monophosphate dephosphorylase
# 305       r_0349                                     dihydroorotase
# 306       r_0350                           dihydropteroate synthase
# 307       r_0351                           dihydropteroate synthase
# 308       r_0352  dihydroxy-acid dehydratase (2,3-dihydroxy-3-me...
# 309       r_0353  dihydroxy-acid dehydratase (2,3-dihydroxy-3-me...
# 310       r_0354                            dihydroxyacetone kinase
# 311       r_0355                      dimethylallyltranstransferase
# 312       r_0356                             diphosphoglyceromutase
# 313       r_0357  diphosphoinositol-1,3,4,6-tetrakisphosphate di...
# 314       r_0358  diphosphoinositol-1,3,4,6-tetrakisphosphate sy...
# 315       r_0359                                 diphthine synthase
# 316       r_0360                                    dolichol kinase
# 317       r_0361           dolichyl-phosphate D-mannosyltransferase
# 318       r_0362  dolichyl-phosphate-mannose--protein mannosyltr...
# 319       r_0363                                        dTMP kinase
# 320       r_0364                                 dUTP diphosphatase
# 321       r_0365                              endopolygalacturonase
# 322       r_0366                                            enolase
# 323       r_0368                                ethanolamine kinase
# 324       r_0369                 ethyl acetate-hydrolyzing esterase
# 325       r_0370                   exo-1,3-beta-glucan glucohydrase
# 326       r_0373                           farnesyltranstransferase
# 327       r_0399                 fatty-acid--CoA ligase (decanoate)
# 328       r_0400               fatty-acid--CoA ligase (dodecanoate)
# 329       r_0402             fatty-acid--CoA ligase (hexadecanoate)
# 330       r_0410                 fatty-acid--CoA ligase (octanoate)
# 331       r_0412            fatty-acid--CoA ligase (tetradecanoate)
# 332       r_0436                                     ferrochelatase
# 333       r_0437  ferrocytochrome-c:hydrogen-peroxide oxidoreduc...
# 334       r_0438            ferrocytochrome-c:oxygen oxidoreductase
# 335       r_0439              ubiquinol:ferricytochrome c reductase
# 336       r_0440                            FMN adenylyltransferase
# 337       r_0441                                      FMN reductase
# 338       r_0442                                      FMN reductase
# 339       r_0443                         formaldehyde dehydrogenase
# 340       r_0445                              formate dehydrogenase
# 341       r_0446                    formate-tetrahydrofolate ligase
# 342       r_0447                    formate-tetrahydrofolate ligase
# 343       r_0448            fructose-2,6-bisphosphate 2-phosphatase
# 344       r_0449                            fructose-bisphosphatase
# 345       r_0450                     fructose-bisphosphate aldolase
# 346       r_0451                                           fumarase
# 347       r_0452                              fumarase, cytoplasmic
# 348       r_0453                    dihydoorotic acid dehydrogenase
# 349       r_0454                                 fumarate reductase
# 350       r_0455                         soluble fumarate reductase
# 351       r_0457                              g-glutamyltransferase
# 352       r_0458                                      galactokinase
# 353       r_0459          galactose-1-phosphate uridylyltransferase
# 354       r_0460                  gamma-glutamylcysteine synthetase
# 355       r_0461                     geranylgeranyltranstransferase
# 356       r_0462                            geranyltranstransferase
# 357       r_0463                       glucan 1,4-alpha-glucosidase
# 358       r_0464              glucan 1,4-alpha-glucosidase, vacuole
# 359       r_0465                  glucosamine-6-phosphate deaminase
# 360       r_0466                  glucose 6-phosphate dehydrogenase
# 361       r_0467                      glucose-6-phosphate isomerase
# 362       r_0468                                 glutamate 5-kinase
# 363       r_0469                            glutamate decarboxylase
# 364       r_0470                      glutamate dehydrogenase (NAD)
# 365       r_0471                     glutamate dehydrogenase (NADP)
# 366       r_0472                         glutamate synthase (NADH2)
# 367       r_0473             glutamate-5-semialdehyde dehydrogenase
# 368       r_0475                                        glutaminase
# 369       r_0476                               glutamine synthetase
# 370       r_0477        glutamine-fructose-6-phosphate transaminase
# 371       r_0478                         glutaminyl-tRNA synthetase
# 372       r_0479                           glutamyl-tRNA synthetase
# 373       r_0480                           glutamyl-tRNA synthetase
# 374       r_0481                         glutathione oxidoreductase
# 375       r_0482                         glutathione oxidoreductase
# 376       r_0483                             glutathione peridoxase
# 377       r_0484               glutathione peroxidase, mitochondria
# 378       r_0485                             glutathione synthetase
# 379       r_0486           glyceraldehyde-3-phosphate dehydrogenase
# 380       r_0487            glycerol dehydrogenase (NADP-dependent)
# 381       r_0488                                    glycerol kinase
# 382       r_0489                             glycerol-3-phosphatase
# 383       r_0490           glycerol-3-phosphate dehydrogenase (fad)
# 384       r_0491           glycerol-3-phosphate dehydrogenase (NAD)
# 385       r_0492           glycerol-3-phosphate dehydrogenase (NAD)
# 386       r_0497  glycerophosphodiester phosphodiesterase (glyce...
# 387       r_0499                glycinamide ribotide transformylase
# 388       r_0500                        glycine C-acetyltransferase
# 389       r_0501                            glycine cleavage system
# 390       r_0502                   glycine hydroxymethyltransferase
# 391       r_0503                   glycine hydroxymethyltransferase
# 392       r_0504               glycine-cleavage complex (lipoamide)
# 393       r_0505               glycine-cleavage complex (lipoamide)
# 394       r_0506           glycine-cleavage complex (lipoylprotein)
# 395       r_0507           glycine-cleavage complex (lipoylprotein)
# 396       r_0508           glycine-cleavage complex (lipoylprotein)
# 397       r_0509                glycine-cleavage system (lipoamide)
# 398       r_0510                         glycogen (starch) synthase
# 399       r_0511                             glycogen phosphorylase
# 400       r_0512                             glycyl-tRNA synthetase
# 401       r_0514                                       GMP synthase
# 402       r_0518                        GPI-anchor assembly, step 2
# 403       r_0519                        GPI-anchor assembly, step 5
# 404       r_0520                        GPI-anchor assembly, step 6
# 405       r_0521                        GPI-anchor assembly, step 7
# 406       r_0522                        GPI-anchor assembly, step 8
# 407       r_0523                        GPI-anchor assembly, step 9
# 408       r_0524                               GTP cyclohydrolase I
# 409       r_0525                              GTP cyclohydrolase II
# 410       r_0526                                  guanine deaminase
# 411       r_0527                  guanine phosphoribosyltransferase
# 412       r_0528                                   guanylate kinase
# 413       r_0529                        guanylate kinase (GMP:dATP)
# 414       r_0530                               heme O monooxygenase
# 415       r_0531                                    Heme O synthase
# 416       r_0532      hexaprenyldihydroxybenzoate methyltransferase
# 417       r_0533                        hexokinase (D-fructose:ATP)
# 418       r_0534                         hexokinase (D-glucose:ATP)
# 419       r_0535                         hexokinase (D-mannose:ATP)
# 420       r_0536                           histidinol dehydrogenase
# 421       r_0537                             histidinol-phosphatase
# 422       r_0538                  histidinol-phosphate transaminase
# 423       r_0539                           histidyl-tRNA synthetase
# 424       r_0540                           histidyl-tRNA synthetase
# 425       r_0541                 hnRNP arginine N-methyltransferase
# 426       r_0542                           homoacontinate hydratase
# 427       r_0543                               homocitrate synthase
# 428       r_0544                   homocysteine S-methyltransferase
# 429       r_0545                       homoisocitrate dehydrogenase
# 430       r_0546                    homoserine dehydrogenase (NADH)
# 431       r_0547                    homoserine dehydrogenase (NADP)
# 432       r_0548                                  homoserine kinase
# 433       r_0549                       homoserine O-trans-acetylase
# 434       r_0550          hydrogen peroxide reductase (thioredoxin)
# 435       r_0551          hydrogen peroxide reductase (thioredoxin)
# 436       r_0552          hydrogen peroxide reductase (thioredoxin)
# 437       r_0553                   hydroxyacylglutathione hydrolase
# 438       r_0554                   hydroxyacylglutathione hydrolase
# 439       r_0555              hydroxybenzoate octaprenyltransferase
# 440       r_0556                        hydroxyethylthiazole kinase
# 441       r_0557                       hydroxymethylbilane synthase
# 442       r_0558                hydroxymethylglutaryl CoA reductase
# 443       r_0560                 hydroxymethylglutaryl CoA synthase
# 444       r_0561               hydroxymethylpyrimidine kinase (ATP)
# 445       r_0562  hypoxanthine phosphoribosyltransferase (Hypoxa...
# 446       r_0563            Imidazole-glycerol-3-phosphate synthase
# 447       r_0564            imidazoleglycerol-phosphate dehydratase
# 448       r_0565                                  IMP dehydrogenase
# 449       r_0566               indole-3-glycerol-phosphate synthase
# 450       r_0567                    indole-3-pyruvate decarboxylase
# 451       r_0568                            inorganic diphosphatase
# 452       r_0569                            inorganic diphosphatase
# 453       r_0570               inosine monophosphate cyclohydrolase
# 454       r_0571      inositol-1,3,4,5,6-pentakisphosphate 2-kinase
# 455       r_0572    inositol-1,3,4,5-triphosphate 6-kinase, nucleus
# 456       r_0573  inositol-1,4,5,6- tetrakisphosphate 3-kinase, ...
# 457       r_0574      inositol-1,4,5-triphosphate 6-kinase, nucleus
# 458       r_0575     inositol-1,4,5-trisphosphate 3-kinase, nucleus
# 459       r_0596                                IPS phospholipase C
# 460       r_0597                                IPS phospholipase C
# 461       r_0598                                IPS phospholipase C
# 462       r_0599                                IPS phospholipase C
# 463       r_0600                                IPS phospholipase C
# 464       r_0601                                IPS phospholipase C
# 465       r_0602                                IPS phospholipase C
# 466       r_0603                                IPS phospholipase C
# 467       r_0604                                IPS phospholipase C
# 468       r_0605                                IPS phospholipase C
# 469       r_0606                                IPS phospholipase C
# 470       r_0607                                IPS phospholipase C
# 471       r_0608                                IPS phospholipase C
# 472       r_0609                                IPS phospholipase C
# 473       r_0610                                IPS phospholipase C
# 474       r_0611                                IPS phospholipase C
# 475       r_0612                                IPS phospholipase C
# 476       r_0613                                IPS phospholipase C
# 477       r_0614                                IPS phospholipase C
# 478       r_0615                                IPS phospholipase C
# 479       r_0616                                IPS phospholipase C
# 480       r_0617                                IPS phospholipase C
# 481       r_0618                                IPS phospholipase C
# 482       r_0619                                IPS phospholipase C
# 483       r_0620                                IPS phospholipase C
# 484       r_0621                                IPS phospholipase C
# 485       r_0622                                IPS phospholipase C
# 486       r_0623                                IPS phospholipase C
# 487       r_0624                                IPS phospholipase C
# 488       r_0625                                IPS phospholipase C
# 489       r_0626                                IPS phospholipase C
# 490       r_0627                                IPS phospholipase C
# 491       r_0628                                IPS phospholipase C
# 492       r_0629                                IPS phospholipase C
# 493       r_0630                                IPS phospholipase C
# 494       r_0631                                IPS phospholipase C
# 495       r_0632                                IPS phospholipase C
# 496       r_0633                                IPS phospholipase C
# 497       r_0634                                IPS phospholipase C
# 498       r_0635                                IPS phospholipase C
# 499       r_0636                                IPS phospholipase C
# 500       r_0637                                IPS phospholipase C
# 501       r_0638                                IPS phospholipase C
# 502       r_0639                                IPS phospholipase C
# 503       r_0640                                IPS phospholipase C
# 504       r_0641                                IPS phospholipase C
# 505       r_0642                                IPS phospholipase C
# 506       r_0643                                IPS phospholipase C
# 507       r_0644                                IPS phospholipase C
# 508       r_0645                                IPS phospholipase C
# 509       r_0646                                IPS phospholipase C
# 510       r_0647                                IPS phospholipase C
# 511       r_0648                                IPS phospholipase C
# 512       r_0649                                IPS phospholipase C
# 513       r_0650                                IPS phospholipase C
# 514       r_0651                                IPS phospholipase C
# 515       r_0652                                IPS phospholipase C
# 516       r_0653                                IPS phospholipase C
# 517       r_0654                                IPS phospholipase C
# 518       r_0655                                IPS phospholipase C
# 519       r_0656               isoamyl acetate-hydrolyzing esterase
# 520       r_0657              isobutyl acetate-hydrolyzing esterase
# 521       r_0658                    isocitrate dehydrogenase (NAD+)
# 522       r_0659                    isocitrate dehydrogenase (NADP)
# 523       r_0661      isocitrate dehydrogenase (NADP+), peroxisomal
# 524       r_0662                                   isocitrate lyase
# 525       r_0663                            isoleucine transaminase
# 526       r_0664                            isoleucine transaminase
# 527       r_0665                          isoleucyl-tRNA synthetase
# 528       r_0666                          isoleucyl-tRNA synthetase
# 529       r_0667                isopentenyl-diphosphate D-isomerase
# 530       r_0668                 itaconate-CoA ligase (ADP-forming)
# 531       r_0669  ketol-acid reductoisomerase (2-aceto-2-hydroxy...
# 532       r_0670                                       kynureninase
# 533       r_0671                         kynurenine 3-monooxygenase
# 534       r_0672  L-1-pyrroline-3-hydroxy-5-carboxylate dehydrog...
# 535       r_0673    L-4-hydroxyglutamate semialdehyde dehydrogenase
# 536       r_0674                             L-alanine transaminase
# 537       r_0675                          L-allo-threonine aldolase
# 538       r_0676                     L-allo-threonine dehydrogenase
# 539       r_0678  L-aminoadipate-semialdehyde dehydrogenase (NADPH)
# 540       r_0679                                     L-asparaginase
# 541       r_0680                                     L-asparaginase
# 542       r_0681  L-erythro-4-hydroxyglutamate:2-oxoglutarate am...
# 543       r_0682  L-erythro-4-hydroxyglutamate:2-oxoglutarate am...
# 544       r_0683  L-erythro-4-hydroxyglutamate:2-oxoglutarate am...
# 545       r_0687                  L-hydroxyproline reductase (NADP)
# 546       r_0688              L-lactaldehyde:NADP+ 1-oxidoreductase
# 547       r_0689                                 L-serine deaminase
# 548       r_0690                             L-serine dehydrogenase
# 549       r_0691     L-sorbitol dehydrogenase (L-sorbose-producing)
# 550       r_0692                              L-threonine deaminase
# 551       r_0693                              L-threonine deaminase
# 552       r_0694  L-tryptophan:oxygen 2,3-oxidoreductase (decycl...
# 553       r_0695                     L-tyrosine N-formyltransferase
# 554       r_0696                         lactaldehyde dehydrogenase
# 555       r_0697                           lactoylglutathione lyase
# 556       r_0698                                lanosterol synthase
# 557       r_0699                               leucine transaminase
# 558       r_0700                               leucine transaminase
# 559       r_0701                             leucyl-tRNA synthetase
# 560       r_0702                             leucyl-tRNA synthetase
# 561       r_0703                           leukotriene A4 hydrolase
# 562       r_0704                           leukotriene A4 hydrolase
# 563       r_0705                           leukotriene A4 hydrolase
# 564       r_0706                           leukotriene A4 hydrolase
# 565       r_0707                           leukotriene A4 hydrolase
# 566       r_0708                           leukotriene A4 hydrolase
# 567       r_0711                              lysyl-tRNA synthetase
# 568       r_0712                              lysyl-tRNA synthetase
# 569       r_0713                               malate dehydrogenase
# 570       r_0714                  malate dehydrogenase, cytoplasmic
# 571       r_0715                  malate dehydrogenase, peroxisomal
# 572       r_0716                                    malate synthase
# 573       r_0717                                    malate synthase
# 574       r_0718                                 malic enzyme (NAD)
# 575       r_0719                                malic enzyme (NADP)
# 576       r_0721                       malonyl-CoA-ACP transacylase
# 577       r_0722            mannose-1-phosphate guanylyltransferase
# 578       r_0723                      mannose-6-phosphate isomerase
# 579       r_0724            methenyltetrahydrifikate cyclohydrolase
# 580       r_0725            methenyltetrahydrofolate cyclohydrolase
# 581       r_0726                     methionine adenosyltransferase
# 582       r_0727                                methionine synthase
# 583       r_0728                   methionyl-tRNA formyltransferase
# 584       r_0729                          methionyl-tRNA synthetase
# 585       r_0730                          methionyl-tRNA synthetase
# 586       r_0731      methylenetetrahydrofolate dehydrogenase (NAD)
# 587       r_0732     methylenetetrahydrofolate dehydrogenase (NADP)
# 588       r_0733     methylenetetrahydrofolate dehydrogenase (NADP)
# 589       r_0734                             methylisocitrate lyase
# 590       r_0735                            mevalonate kinase (atp)
# 591       r_0736                            mevalonate kinase (ctp)
# 592       r_0737                            mevalonate kinase (gtp)
# 593       r_0738                            mevalonate kinase (UTP)
# 594       r_0739              mevalonate pyrophoshate decarboxylase
# 595       r_0747                                      MIPC synthase
# 596       r_0748                                      MIPC synthase
# 597       r_0749                                      MIPC synthase
# 598       r_0750                                      MIPC synthase
# 599       r_0751                                      MIPC synthase
# 600       r_0752                                      MIPC synthase
# 601       r_0753                                      MIPC synthase
# 602       r_0754                                      MIPC synthase
# 603       r_0755                                      MIPC synthase
# 604       r_0756                                      MIPC synthase
# 605       r_0757                         myo-inositol 1-phosphatase
# 606       r_0758                  myo-inositol-1-phosphate synthase
# 607       r_0759            N-acetyl-g-glutamyl-phosphate reductase
# 608       r_0760           N-acetylglucosamine-6-phosphate synthase
# 609       r_0761                         N-acteylglutamate synthase
# 610       r_0762               N-formyl-L-kynurenine amidohydrolase
# 611       r_0763                           N-formyltyrosine oxidase
# 612       r_0764                                  NAD diphosphatase
# 613       r_0765                                         NAD kinase
# 614       r_0766                                         NAD kinase
# 615       r_0767                           NAD nucleosidase nuclear
# 616       r_0768                                       NAD synthase
# 617       r_0769                                       NAD synthase
# 618       r_0770        NADH dehydrogenase, cytosolic/mitochondrial
# 619       r_0771                                        NADH kinase
# 620       r_0772                          NADH kinase mitochondrial
# 621       r_0773                     NADH:ubiquinone oxidoreductase
# 622       r_0774                                           NAPRtase
# 623       r_0775                                           NAPRtase
# 624       r_0781                                     nicotinamidase
# 625       r_0782                   nicotinamide N-methyltransferase
# 626       r_0783        nicotinamide-nucleotide adenylyltransferase
# 627       r_0784        nicotinamide-nucleotide adenylyltransferase
# 628       r_0785          nicotinate-nucleotide adenylyltransferase
# 629       r_0786  nicotinate-nucleotide diphosphorylase (carboxy...
# 630       r_0787  nicotinate-nucleotide diphosphorylase (carboxy...
# 631       r_0788                           nucleoside diphosphatase
# 632       r_0789                           nucleoside diphosphatase
# 633       r_0790                           nucleoside diphosphatase
# 634       r_0791                           nucleoside diphosphatase
# 635       r_0792                           nucleoside diphosphatase
# 636       r_0793                           nucleoside diphosphatase
# 637       r_0795                      nucleoside diphosphate kinase
# 638       r_0796                      nucleoside diphosphate kinase
# 639       r_0797                      nucleoside diphosphate kinase
# 640       r_0798                      nucleoside diphosphate kinase
# 641       r_0799                      nucleoside diphosphate kinase
# 642       r_0800                      nucleoside diphosphate kinase
# 643       r_0801                      nucleoside diphosphate kinase
# 644       r_0802                      nucleoside diphosphate kinase
# 645       r_0803                      nucleoside diphosphate kinase
# 646       r_0804                          nucleoside triphosphatase
# 647       r_0805                          nucleoside triphosphatase
# 648       r_0806                          nucleoside triphosphatase
# 649       r_0807                          nucleoside triphosphatase
# 650       r_0810              nucleoside-diphosphatase (GDP), Golgi
# 651       r_0811            nucleoside-diphosphate kinase (ATP:UDP)
# 652       r_0812                   O-acetylhomoserine (thiol)-lyase
# 653       r_0813                   O-acetylhomoserine (thiol)-lyase
# 654       r_0815            O-succinylhomoserine lyase (L-cysteine)
# 655       r_0816                     ornithine carbamoyltransferase
# 656       r_0817                            ornithine decarboxylase
# 657       r_0818                           ornithine transacetylase
# 658       r_0819                             ornithine transaminase
# 659       r_0820                  orotate phosphoribosyltransferase
# 660       r_0821               orotidine-5'-phosphate decarboxylase
# 661       r_0831  oxoglutarate dehydrogenase (dihydrolipoamide S...
# 662       r_0832             oxoglutarate dehydrogenase (lipoamide)
# 663       r_0841          pantetheine-phosphate adenylyltransferase
# 664       r_0842                                pantothenate kinase
# 665       r_0843                              pantothenate synthase
# 666       r_0844                  peroxisomal acyl-CoA thioesterase
# 667       r_0845                  peroxisomal acyl-CoA thioesterase
# 668       r_0847                  peroxisomal acyl-CoA thioesterase
# 669       r_0848                  peroxisomal acyl-CoA thioesterase
# 670       r_0849                  peroxisomal acyl-CoA thioesterase
# 671       r_0850                  peroxisomal acyl-CoA thioesterase
# 672       r_0851                         phenylalanine transaminase
# 673       r_0852                       phenylalanyl-tRNA synthetase
# 674       r_0853                       phenylalanyl-tRNA synthetase
# ...
# 3925                                               None
# 3926                                               None
# 3927                                               None
# 3928                                               None
# 3929                                               None
# 3930                                               None
# 3931                                               None
# 3932                                               None
# 3933                 YOR317W, YIL009W, YMR246W, YER015W
# 3934                                               None
# 3935                                               None
# 3936                                            YOL122C
# 3937                                            YNL275W
# 3938                                            YOL122C
# 3939                                            YOL130W
# 3940                                   YGL255W, YLR130C
# 3941                                   YGR191W, YOL130W
# 3942                                               None
# 3943                                               None
# 3944                                               None
# 3945                                               None
# 3946                                               None
# 3947                                               None
# 3948                                               None
# 3949                                               None
# 3950                                               None
# 3951                                               None
# 3952                                               None
# 3953                                               None
# 3954                                               None
# 3955                                               None
# 3956                                               None
# 3957                                               None
# 3958                                               None
# 3959                                               None
# 3960                                               None
# 3961                                               None
# 3962                                               None
# 3963                                               None
# 3964                                               None
# 3965                                               None
# 3966                                               None
# 3967                                               None
# 3968                                               None
# 3969                                               None
# 3970                                               None
# 3971                                               None
# 3972                                               None
# 3973                                               None
# 3974                                               None
# 3975                                               None
# 3976                                               None
# 3977                                               None
# 3978                                   YPL095C, YBR177C
# 3979                                   YPL095C, YBR177C
# 3980                                   YPL095C, YBR177C
# 3981                          YGR177C, YOR377W, YGR015C
# 3982                                   YPL095C, YBR177C
# 3983                                               None
# 3984                                               None
# 3985                                               None
# 3986                                               None
# 3987                                               None
# 3988                                               None
# 3989                                               None
# 3990                                               None
# 3991                                               None
# 3992                                               None
# 3993                                               None
# 3994                                               None
# 3995                                               None
# 3996                                               None
# 3997                                               None
# 3998                                            YGR015C
# 3999                                               None
# 4000                          YGR087C, YLR134W, YLR044C
# 4001                          YBR145W, YDL168W, YOL086C
# 4002                                   YMR083W, YGL256W
# 4003                          YMR318C, YDR368W, YCR105W
# 4004                                               None
# 4005                                               None
# 4006                                               None
# 4007                                               None
# 4008                                               None
# 4009                                            YHR137W
# 4010                          YBR145W, YDL168W, YOL086C
# 4011                                   YMR083W, YGL256W
# 4012                          YMR318C, YDR368W, YCR105W
# 4013                                               None
# 4014                                               None
# 4015                                               None
# 4016                                               None
# 4017                                               None
# 4018                          YGR087C, YLR134W, YLR044C
# 4019                          YBR145W, YDL168W, YOL086C
# 4020                                   YMR083W, YGL256W
# 4021                          YMR318C, YDR368W, YCR105W
# 4022                                               None
# 4023                                               None
# 4024                                               None
# 4025                                               None
# 4026                                               None
# 4027                          YMR169C, YMR170C, YOR374W
# 4028                 YOR317W, YIL009W, YMR246W, YER015W
# 4029                                   YPL095C, YBR177C
# 4030                                               None
# 4031                                               None
# 4032                                               None
# 4033                                               None
# 4034                                               None
# 4035                                               None
# 4036                          YGR177C, YOR377W, YGR015C
# 4037                                               None
# 4038                                               None
# 4039                          YGR177C, YOR377W, YGR015C
# 4040                                               None
# 4041                                               None
# 4042                          YGR177C, YOR377W, YGR015C
# 4043                                               None
# 4044                                               None
# 4045                                               None
# 4046                                   YNL065W, YKL217W
# 4047                                               None
# 4048                                            YIL166C
# 4049                                            YFR055W
# 4050                                               None
# 4051                                            YOR251C
# 4052                                            YIL166C
# 4053                                            YIL166C
# 4054                                            YLL057C
# 4055                                               None
# 4056                                               None
# 4057                                               None
# 4058                                               None
# 4059                                            YOR126C
# 4060                                            YOR126C
# 4061                                            YOR126C
# 4062                                            YOR126C
# 4063                                            YOR126C
# 4064                                            YOR126C
# 4065                                            YOR126C
# 4066                                   YPL061W, YOR374W
# 4067                                   YPL061W, YOR374W
# 4068                                            YOR126C
# 4069                                            YOR126C
# 4070                                            YJL012C
# 4071                                   YHR201C, YDR452W
# 4072                                   YHR201C, YDR452W
# 4073                                   YHR201C, YDR452W
# 4074                                               None
# 4075                                               None
# 4076                                               None
# 4077                                               None
# 4078                                               None
# 4079                                               None
# 4080                                               None
# 4081                                               None
# 4082                                               None
# 4083                                               None
# 4084                                               None
# 4085                                               None
# 4086                                               None
# 4087                                               None
# 4088                                               None
# 4089                                               None
# 4090                                               None
# 4091                                               None
# 4092                                               None
# 4093                                               None
# 4094                                               None
# 4095                                   YDR020C, YNR012W
# 4096                                   YFL053W, YML070W
# 4097                                            YLR209C
# 4098                                            YBR019C
# 4099                                   YPR193C, YEL066W
# 4100                                   YLR146C, YPR069C
# 4101                                            YPL214C
# 4102                                            YDR538W
# 4103                                   YEL071W, YDL178W
# 4104                                            YDR400W
# 4105                                            YDR109C
# 4106                                            YLR209C
# 4107                                            YGL067W
# 4108                                            YER023W
# 4109                                            YJL060W
# 4110                                            YDR036C
# 4111                                   YAL061W, YAL060W
# 4112                                            YPR062W
# 4113                                            YIR032C
# 4114                                            YJL005W
# 4115                                            YJL060W
# 4116                                            YDR481C
# 4117                                            YDR305C
# 4118                                            YKL067W
# 4119                                            YKL067W
# 4120                                            YKL067W
# 4121                                            YKL067W
# 4122                                            YKL067W
# 4123                                            YKL067W
# 4124                                            YKL067W
# 4125                                            YKL067W
# 4126                                            YKL067W
# 4127                                               None
# 4128                                               None
# 4129                                            YGR144W
# 4130                                            YGR144W
# ['r_0001', 'r_0002', 'r_0003', 'r_0004', 'r_0005', 'r_0006', 'r_0007', 'r_0012', 'r_0013', 'r_0014', 'r_0015', 'r_0016', 'r_0017', 'r_0018', 'r_0019', 'r_0020', 'r_0021', 'r_0022', 'r_0023', 'r_0024', 'r_0025', 'r_0026', 'r_0027', 'r_0028', 'r_0029', 'r_0030', 'r_0032', 'r_0033', 'r_0034', 'r_0035', 'r_0036', 'r_0037', 'r_0038', 'r_0039', 'r_0040', 'r_0041', 'r_0042', 'r_0043', 'r_0044', 'r_0045', 'r_0057', 'r_0058', 'r_0059', 'r_0060', 'r_0061', 'r_0062', 'r_0063', 'r_0064', 'r_0065', 'r_0066', 'r_0067', 'r_0068', 'r_0069', 'r_0070', 'r_0072', 'r_0073', 'r_0074', 'r_0075', 'r_0076', 'r_0077', 'r_0078', 'r_0079', 'r_0080', 'r_0081', 'r_0082', 'r_0083', 'r_0084', 'r_0085', 'r_0086', 'r_0087', 'r_0088', 'r_0089', 'r_0090', 'r_0091', 'r_0092', 'r_0093', 'r_0094', 'r_0095', 'r_0096', 'r_0097', 'r_0099', 'r_0100', 'r_0101', 'r_0102', 'r_0103', 'r_0104', 'r_0105', 'r_0106', 'r_0107', 'r_0108', 'r_0109', 'r_0111', 'r_0112', 'r_0113', 'r_0114', 'r_0115', 'r_0116', 'r_0117', 'r_0118', 'r_0119', 'r_0120', 'r_0121', 'r_0122', 'r_0123', 'r_0124', 'r_0125', 'r_0126', 'r_0127', 'r_0128', 'r_0129', 'r_0130', 'r_0131', 'r_0132', 'r_0133', 'r_0134', 'r_0135', 'r_0137', 'r_0138', 'r_0139', 'r_0140', 'r_0142', 'r_0143', 'r_0144', 'r_0145', 'r_0146', 'r_0147', 'r_0148', 'r_0149', 'r_0150', 'r_0151', 'r_0152', 'r_0153', 'r_0154', 'r_0155', 'r_0156', 'r_0157', 'r_0158', 'r_0159', 'r_0160', 'r_0161', 'r_0162', 'r_0163', 'r_0164', 'r_0165', 'r_0166', 'r_0167', 'r_0168', 'r_0169', 'r_0170', 'r_0171', 'r_0172', 'r_0173', 'r_0174', 'r_0175', 'r_0176', 'r_0177', 'r_0178', 'r_0179', 'r_0180', 'r_0181', 'r_0182', 'r_0183', 'r_0184', 'r_0185', 'r_0186', 'r_0187', 'r_0188', 'r_0189', 'r_0190', 'r_0191', 'r_0192', 'r_0193', 'r_0194', 'r_0195', 'r_0198', 'r_0199', 'r_0200', 'r_0201', 'r_0202', 'r_0203', 'r_0204', 'r_0205', 'r_0206', 'r_0207', 'r_0208', 'r_0209', 'r_0210', 'r_0211', 'r_0212', 'r_0213', 'r_0214', 'r_0215', 'r_0216', 'r_0217', 'r_0218', 'r_0219', 'r_0220', 'r_0221', 'r_0222', 'r_0223', 'r_0224', 'r_0225', 'r_0226', 'r_0227', 'r_0228', 'r_0229', 'r_0230', 'r_0231', 'r_0233', 'r_0234', 'r_0235', 'r_0236', 'r_0237', 'r_0238', 'r_0239', 'r_0240', 'r_0241', 'r_0242', 'r_0243', 'r_0244', 'r_0249', 'r_0250', 'r_0252', 'r_0253', 'r_0254', 'r_0255', 'r_0256', 'r_0259', 'r_0260', 'r_0261', 'r_0262', 'r_0263', 'r_0264', 'r_0265', 'r_0266', 'r_0267', 'r_0268', 'r_0269', 'r_0270', 'r_0271', 'r_0272', 'r_0273', 'r_0274', 'r_0278', 'r_0279', 'r_0280', 'r_0281', 'r_0282', 'r_0283', 'r_0284', 'r_0285', 'r_0286', 'r_0287', 'r_0288', 'r_0289', 'r_0290', 'r_0291', 'r_0292', 'r_0293', 'r_0294', 'r_0295', 'r_0296', 'r_0297', 'r_0298', 'r_0299', 'r_0300', 'r_0301', 'r_0302', 'r_0303', 'r_0304', 'r_0306', 'r_0307', 'r_0308', 'r_0309', 'r_0310', 'r_0311', 'r_0312', 'r_0313', 'r_0314', 'r_0315', 'r_0317', 'r_0318', 'r_0319', 'r_0320', 'r_0321', 'r_0322', 'r_0323', 'r_0326', 'r_0327', 'r_0328', 'r_0329', 'r_0330', 'r_0331', 'r_0332', 'r_0334', 'r_0335', 'r_0340', 'r_0341', 'r_0342', 'r_0343', 'r_0344', 'r_0345', 'r_0346', 'r_0347', 'r_0348', 'r_0349', 'r_0350', 'r_0351', 'r_0352', 'r_0353', 'r_0354', 'r_0355', 'r_0356', 'r_0357', 'r_0358', 'r_0359', 'r_0360', 'r_0361', 'r_0362', 'r_0363', 'r_0364', 'r_0365', 'r_0366', 'r_0368', 'r_0369', 'r_0370', 'r_0373', 'r_0399', 'r_0400', 'r_0402', 'r_0410', 'r_0412', 'r_0436', 'r_0437', 'r_0438', 'r_0439', 'r_0440', 'r_0441', 'r_0442', 'r_0443', 'r_0445', 'r_0446', 'r_0447', 'r_0448', 'r_0449', 'r_0450', 'r_0451', 'r_0452', 'r_0453', 'r_0454', 'r_0455', 'r_0457', 'r_0458', 'r_0459', 'r_0460', 'r_0461', 'r_0462', 'r_0463', 'r_0464', 'r_0465', 'r_0466', 'r_0467', 'r_0468', 'r_0469', 'r_0470', 'r_0471', 'r_0472', 'r_0473', 'r_0475', 'r_0476', 'r_0477', 'r_0478', 'r_0479', 'r_0480', 'r_0481', 'r_0482', 'r_0483', 'r_0484', 'r_0485', 'r_0486', 'r_0487', 'r_0488', 'r_0489', 'r_0490', 'r_0491', 'r_0492', 'r_0497', 'r_0499', 'r_0500', 'r_0501', 'r_0502', 'r_0503', 'r_0504', 'r_0505', 'r_0506', 'r_0507', 'r_0508', 'r_0509', 'r_0510', 'r_0511', ...

# %% [markdown]
# ## Identify NADH Metabolites and Inspect Flux
#
# List all metabolites whose name includes "NADH" and then inspect the fluxes involving cytosolic NADH (s_1203) by printing summary. This can be used to examine the overall redox balance of the model.
#
# **Note:** NADH (Nicotinamide Adenine Dinucleotide, reduced form) is a key electron carrier in cellular metabolism.

# %%
# Find NADH metabolite IDs
for m in model.metabolites:
    if "nadh" in m.name.lower():
        print(m.id, m.name, m.compartment)

model.metabolites.s_1203.summary()
# Out:
# s_1203 NADH c
# s_1204 NADH er
# s_1205 NADH m
# s_1206 NADH p
# s_2818 NADH erm
# s_3753 NADH n
# <h3>s_1203</h3><p>C21H27N7O14P2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1.88%</td>
#       <td>0.02923</td>
#       <td>r_0061</td>
#       <td>s_0009 + s_1198 --&gt; s_0010 + s_0794 + s_1203</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>1.631E-05</td>
#       <td>r_0172</td>
#       <td>s_0208 + s_0803 + s_1198 --&gt; s_0441 + 2.0 s_0794 + s_1203</td>
#     </tr>
#     <tr>
#       <td>0.20%</td>
#       <td>0.003166</td>
#       <td>r_0235</td>
#       <td>s_0297 + s_1198 --&gt; s_0209 + s_0456 + s_1203</td>
#     </tr>
#     <tr>
#       <td>0.26%</td>
#       <td>0.003966</td>
#       <td>r_0445</td>
#       <td>s_0722 + s_1198 --&gt; s_0456 + s_1203</td>
#     </tr>
#     <tr>
#       <td>89.28%</td>
#       <td>1.386</td>
#       <td>r_0486</td>
#       <td>s_0764 + s_1198 + s_1322 &lt;=&gt; s_0075 + s_0794 + s_1203</td>
#     </tr>
#     <tr>
#       <td>0.84%</td>
#       <td>0.01308</td>
#       <td>r_0536</td>
#       <td>s_0803 + s_1010 + 2.0 s_1198 --&gt; 3.0 s_0794 + s_1006 + 2.0 s_1203</td>
#     </tr>
#     <tr>
#       <td>0.27%</td>
#       <td>0.00412</td>
#       <td>r_0565</td>
#       <td>s_0803 + s_0849 + s_1198 --&gt; s_0794 + s_1203 + s_1565</td>
#     </tr>
#     <tr>
#       <td>4.27%</td>
#       <td>0.06624</td>
#       <td>r_0891</td>
#       <td>s_0260 + s_1198 --&gt; s_0258 + s_0794 + s_1203</td>
#     </tr>
#     <tr>
#       <td>1.82%</td>
#       <td>0.02822</td>
#       <td>r_0988</td>
#       <td>s_0803 + s_1038 + s_1198 --&gt; s_0180 + s_0794 + s_1025 + s_1203</td>
#     </tr>
#     <tr>
#       <td>1.18%</td>
#       <td>0.01833</td>
#       <td>r_4581</td>
#       <td>s_1198 + s_4189 --&gt; s_0178 + s_0456 + s_1203</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.38%</td>
#       <td>-0.005963</td>
#       <td>r_0491</td>
#       <td>s_0629 + s_0794 + s_1203 --&gt; s_0767 + s_1198</td>
#     </tr>
#     <tr>
#       <td>1.58%</td>
#       <td>-0.02454</td>
#       <td>r_0546</td>
#       <td>s_0794 + s_0978 + s_1203 --&gt; s_1014 + s_1198</td>
#     </tr>
#     <tr>
#       <td>6.33%</td>
#       <td>-0.0983</td>
#       <td>r_0714</td>
#       <td>s_0066 + s_1198 &lt;=&gt; s_0794 + s_1203 + s_1271</td>
#     </tr>
#     <tr>
#       <td>89.21%</td>
#       <td>-1.385</td>
#       <td>r_0770</td>
#       <td>s_0794 + s_1203 + s_1537 --&gt; s_1198 + s_1535</td>
#     </tr>
#     <tr>
#       <td>0.02%</td>
#       <td>-0.0002807</td>
#       <td>r_0771</td>
#       <td>s_0434 + s_1203 --&gt; s_0394 + s_0794 + s_1212</td>
#     </tr>
#     <tr>
#       <td>1.30%</td>
#       <td>-0.02015</td>
#       <td>r_3532</td>
#       <td>s_1203 &lt;=&gt; s_2818</td>
#     </tr>
#     <tr>
#       <td>1.18%</td>
#       <td>-0.01833</td>
#       <td>r_4570</td>
#       <td>s_1198 + s_4182 &lt;=&gt; s_0180 + s_0794 + s_1203</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-1.288E-05</td>
#       <td>r_4598</td>
#       <td>0.000190000006114133 s_0529 + 9.99999974737875e-06 s_0687 + 1e-06 s_0750 + 0.00264999992214143 s_1198 + 0.000150000007124618 s_1203 + 0.000569999974686652 s_1207 + 0.00270000007003546 s_1212 + 0.000989999971352518 s_1405 + 1.20000004244503e-06 s_1475 + 6.34000025456771e-05 s_1487 + 9.99999997475243e-07 s_3714 --&gt; s_4205</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Identify ATP Metabolites and Inspect Flux
#
# Lists all metabolites with "ATP" in their name along with their compartments, helping identify the relevant ATP species in the model. We then focus on the cytosolic ATP (s_0434) to get an overview of the main reactions producing and consuming ATP.

# %%
# Find ATP metabolite IDs
for m in model.metabolites:
    if "atp" in m.name.lower():
        print(m.id, m.name, m.compartment)

model.metabolites.s_0434.summary()
# Out:
# s_0326 5-phosphoribosyl-ATP c
# s_0434 ATP c
# s_0435 ATP er
# s_0437 ATP m
# s_0438 ATP n
# s_0439 ATP p
# s_0586 dATP c
# s_2831 ATP erm
# s_2840 ATP lp
# s_2856 ATP ce
# s_3341 ATP vm
# s_3359 ATP gm
# s_3881 ATP v
# s_4196 ATP g
# s_4318 dATP m
# <h3>s_0434</h3><p>C10H12N5O13P3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.00%</td>
#       <td>0.000206</td>
#       <td>r_0330</td>
#       <td>s_0434 + s_0615 &lt;=&gt; s_0394 + s_0613</td>
#     </tr>
#     <tr>
#       <td>15.16%</td>
#       <td>1.386</td>
#       <td>r_0892</td>
#       <td>s_0075 + s_0394 &lt;=&gt; s_0260 + s_0434</td>
#     </tr>
#     <tr>
#       <td>13.86%</td>
#       <td>1.267</td>
#       <td>r_0962</td>
#       <td>s_0394 + s_0794 + s_1360 --&gt; s_0434 + s_1399</td>
#     </tr>
#     <tr>
#       <td>70.96%</td>
#       <td>6.487</td>
#       <td>r_1110</td>
#       <td>s_0394 + s_0437 &lt;=&gt; s_0397 + s_0434</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0005151</td>
#       <td>r_1704</td>
#       <td>s_0434 + s_0589 &lt;=&gt; s_0394 + s_0587</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.000309</td>
#       <td>r_1729</td>
#       <td>s_0434 + s_0584 &lt;=&gt; s_0394 + s_0582</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0005014</td>
#       <td>r_3543</td>
#       <td>s_0434 &lt;=&gt; s_2831</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.10%</td>
#       <td>-0.008791</td>
#       <td>r_0079</td>
#       <td>s_0301 + s_0434 + s_0803 + s_0999 --&gt; s_0302 + s_0394 + s_0794 + s_0991 + s_1322</td>
#     </tr>
#     <tr>
#       <td>1.11%</td>
#       <td>-0.1016</td>
#       <td>r_0109</td>
#       <td>s_0373 + s_0434 + s_0445 --&gt; s_0394 + s_0794 + s_1101 + s_1322</td>
#     </tr>
#     <tr>
#       <td>1.35%</td>
#       <td>-0.1234</td>
#       <td>r_0112</td>
#       <td>s_0362 + s_0434 + s_0529 --&gt; s_0373 + s_0423 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.13%</td>
#       <td>-0.01205</td>
#       <td>r_0142</td>
#       <td>s_0386 + s_0434 --&gt; s_0394 + s_0423 + s_0794</td>
#     </tr>
#     <tr>
#       <td>6.55%</td>
#       <td>-0.5985</td>
#       <td>r_0148</td>
#       <td>s_0423 + s_0434 --&gt; 2.0 s_0394</td>
#     </tr>
#     <tr>
#       <td>0.06%</td>
#       <td>-0.005667</td>
#       <td>r_0154</td>
#       <td>s_0298 + s_0434 --&gt; s_0201 + s_0394 + s_0794</td>
#     </tr>
#     <tr>
#       <td>0.49%</td>
#       <td>-0.04524</td>
#       <td>r_0157</td>
#       <td>s_0434 + s_0955 + s_1582 --&gt; s_0404 + s_0423 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.17%</td>
#       <td>-0.01585</td>
#       <td>r_0208</td>
#       <td>s_0434 + s_0973 + s_0979 &lt;=&gt; s_0015 + s_0423 + s_0633 + s_0794</td>
#     </tr>
#     <tr>
#       <td>0.17%</td>
#       <td>-0.01585</td>
#       <td>r_0209</td>
#       <td>s_0434 + s_0965 + s_1583 --&gt; s_0423 + s_0428 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.11%</td>
#       <td>-0.01003</td>
#       <td>r_0211</td>
#       <td>s_0434 + s_0803 + s_0973 + s_0999 --&gt; s_0423 + s_0633 + s_0794 + s_0969 + s_0991</td>
#     </tr>
#     <tr>
#       <td>0.11%</td>
#       <td>-0.01003</td>
#       <td>r_0212</td>
#       <td>s_0434 + s_0969 + s_1585 --&gt; s_0423 + s_0430 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.27%</td>
#       <td>-0.02454</td>
#       <td>r_0215</td>
#       <td>s_0434 + s_0973 --&gt; s_0295 + s_0394</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.02934</td>
#       <td>r_0220</td>
#       <td>s_0434 + s_0973 + s_1587 --&gt; s_0423 + s_0432 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.07%</td>
#       <td>-0.006538</td>
#       <td>r_0225</td>
#       <td>s_0434 + s_1386 --&gt; s_0326 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.55%</td>
#       <td>-0.05011</td>
#       <td>r_0250</td>
#       <td>2.0 s_0434 + s_0445 + s_0803 + s_0999 --&gt; 2.0 s_0394 + s_0455 + 2.0 s_0794 + s_0991 + s_1322</td>
#     </tr>
#     <tr>
#       <td>0.05%</td>
#       <td>-0.00423</td>
#       <td>r_0307</td>
#       <td>s_0419 + s_0434 + s_1559 --&gt; s_0394 + s_0539 + 2.0 s_0794 + s_1322</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0006508</td>
#       <td>r_0313</td>
#       <td>s_0434 + s_0981 + s_1589 --&gt; s_0423 + s_0542 + s_0633</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-5.443E-06</td>
#       <td>r_0346</td>
#       <td>s_0347 + s_0434 + s_0991 --&gt; s_0394 + s_0625 + s_0794 + s_1322</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-8.584E-07</td>
#       <td>r_0440</td>
#       <td>s_0434 + s_0714 + s_0794 --&gt; s_0633 + s_0687</td>
#     </tr>
#     <tr>
#       <td>0.18%</td>
#       <td>-0.01624</td>
#       <td>r_0468</td>
#       <td>s_0434 + s_0991 --&gt; s_0394 + s_0986</td>
#     </tr>
#     <tr>
#       <td>0.87%</td>
#       <td>-0.07959</td>
#       <td>r_0476</td>
#       <td>s_0419 + s_0434 + s_0991 --&gt; s_0394 + s_0794 + s_0999 + s_1322</td>
#     </tr>
#     <tr>
#       <td>0.11%</td>
#       <td>-0.01039</td>
#       <td>r_0478</td>
#       <td>s_0434 + s_0999 + s_1590 --&gt; s_0423 + s_0633 + s_0747</td>
#     </tr>
#     <tr>
#       <td>0.33%</td>
#       <td>-0.02976</td>
#       <td>r_0479</td>
#       <td>s_0434 + s_0991 + s_1591 --&gt; s_0423 + s_0633 + s_0748</td>
#     </tr>
#     <tr>
#       <td>0.31%</td>
#       <td>-0.02864</td>
#       <td>r_0512</td>
#       <td>s_0434 + s_1003 + s_1593 --&gt; s_0423 + s_0633 + s_0757</td>
#     </tr>
#     <tr>
#       <td>0.05%</td>
#       <td>-0.00412</td>
#       <td>r_0514</td>
#       <td>s_0434 + s_0803 + s_0999 + s_1565 --&gt; s_0423 + s_0633 + s_0782 + 2.0 s_0794 + s_0991</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002973</td>
#       <td>r_0528</td>
#       <td>s_0434 + s_0782 --&gt; s_0394 + s_0739</td>
#     </tr>
#     <tr>
#       <td>10.94%</td>
#       <td>-1</td>
#       <td>r_0534</td>
#       <td>s_0434 + s_0563 --&gt; s_0394 + s_0568 + s_0794</td>
#     </tr>
#     <tr>
#       <td>0.07%</td>
#       <td>-0.006538</td>
#       <td>r_0539</td>
#       <td>s_0434 + s_1006 + s_1594 --&gt; s_0423 + s_0633 + s_0832</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.01887</td>
#       <td>r_0548</td>
#       <td>s_0434 + s_1014 --&gt; s_0394 + s_0794 + s_1238</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-1.03E-07</td>
#       <td>r_0561</td>
#       <td>s_0270 + s_0434 --&gt; s_0268 + s_0394 + s_0794</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.019</td>
#       <td>r_0665</td>
#       <td>s_0434 + s_1016 + s_1596 --&gt; s_0423 + s_0633 + s_0847</td>
#     </tr>
#     <tr>
#       <td>0.31%</td>
#       <td>-0.02822</td>
#       <td>r_0678</td>
#       <td>s_0434 + s_0794 + s_0953 + s_1212 --&gt; s_0423 + s_0633 + s_0959 + s_1207</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.02923</td>
#       <td>r_0701</td>
#       <td>s_0434 + s_1021 + s_1598 --&gt; s_0423 + s_0633 + s_1077</td>
#     </tr>
#     <tr>
#       <td>0.31%</td>
#       <td>-0.02822</td>
#       <td>r_0711</td>
#       <td>s_0434 + s_1025 + s_1600 --&gt; s_0423 + s_0633 + s_1099</td>
#     </tr>
#     <tr>
#       <td>0.13%</td>
#       <td>-0.01205</td>
#       <td>r_0726</td>
#       <td>s_0434 + s_0803 + s_1029 --&gt; s_0633 + s_1322 + s_1416</td>
#     </tr>
#     <tr>
#       <td>0.05%</td>
#       <td>-0.004999</td>
#       <td>r_0729</td>
#       <td>s_0434 + s_1029 + s_1602 --&gt; s_0423 + s_0633 + s_1148</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.01899</td>
#       <td>r_0735</td>
#       <td>s_0028 + s_0434 --&gt; s_0019 + s_0394 + s_0794</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.01899</td>
#       <td>r_0739</td>
#       <td>s_0018 + s_0434 --&gt; s_0394 + s_0456 + s_0943 + s_1322</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0005211</td>
#       <td>r_0768</td>
#       <td>s_0434 + s_0591 + s_0803 + s_0999 --&gt; s_0423 + s_0633 + s_0794 + s_0991 + s_1198</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002807</td>
#       <td>r_0771</td>
#       <td>s_0434 + s_1203 --&gt; s_0394 + s_0794 + s_1212</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0005211</td>
#       <td>r_0785</td>
#       <td>s_0434 + s_0794 + s_1

# %% [markdown]
# ## Set Up Community Model
#
# Prepare compartments, exchange reactions, and initial setup for community simulation.

# %%
community_model = Model("microbial_community")

# TODO
