# %% [markdown]
# # FluxTransformer: A Neural Surrogate for Metabolic Flux Prediction
#
# This notebook implements *FluxTransformer*, a neural surrogate model designed to predict flux distributions in the *E. coli core* metabolic network. The model uses a Transformer-based architecture with multi-head attention and feedforward layers to approximate the results of Flux Balance Analysis (FBA) from extracellular metabolite uptake rates.
#
# The notebook includes:
#
# * Data preprocessing and preparation
#
# * Model architecture implemented in PyTorch
#
# * Training and evaluation on simulated flux datasets
#
# * Systematic testing of multiple Transformer model configurations to assess performance

# %%
import os
import random
import time
import gc

import numpy as np
import pandas as pd
from IPython.display import display
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', None)

# %%
DATA_PATH = "./data/2025-07-15_full_training_data_98066_samples.csv" # carbons log-uniform, others uniform

# %%
# Set all random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

#set_seed()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on device: {device}")

print(f"PyTorch version: {torch.__version__}")
# Out:
# Training on device: cuda
# PyTorch version: 2.5.1+cu121

# %%
def print_gpu_memory():
    """
    Displays the current GPU memory usage by PyTorch on the active CUDA device.
    Useful for monitoring GPU memory usage during training.
    """
    if torch.cuda.is_available():
        device = torch.cuda.current_device()
        allocated = torch.cuda.memory_allocated(device) / 1024**2
        reserved = torch.cuda.memory_reserved(device) / 1024**2
        print(f'Allocated memory: {allocated:.2f} MB')
        print(f'Reserved memory: {reserved:.2f} MB')
    else:
        print("CUDA is not available.")

# %%
class AttentionBlock(nn.Module):
    """Custom multi-head attention block for metabolic modeling"""
    def __init__(self, d_model=8, n_heads=2, dropout=0.1):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"

        self.d_model = d_model
        self.n_heads = n_heads
        self.layer_norm = nn.LayerNorm(d_model)

        self.mha = nn.MultiheadAttention(
            embed_dim=d_model,
            num_heads=n_heads,
            dropout=dropout,
            batch_first=True
        )

        self.head_scores = nn.Parameter(torch.zeros(n_heads))

    def forward(self, x, c):
        # x: (batch, seq_len, d_model)
        # c: (batch, seq_len, 1)
        x_norm = self.layer_norm(x) # pre-norm
        attn_out, attn_weights = self.mha(x_norm, x_norm, x_norm, need_weights=True, average_attn_weights=False)

        x_out = attn_out + x

        # Per-head diffusion of c:
        c_heads = torch.matmul(attn_weights, c.unsqueeze(1))
        alpha = F.softmax(self.head_scores, dim=0).view(1, self.n_heads, 1, 1)  # (1,H,1,1)
        c_att = (c_heads * alpha).sum(dim=1)  # (B, S, 1)

        c_out = c_att + c

        return x_out, c_out

# %%
# pre-norm

class FeedForwardBlock(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super().__init__()

        self.d_model = d_model + 1
        self.d_ff = d_ff

        self.layer_norm = nn.LayerNorm(self.d_model)
        self.linear1 = nn.Linear(self.d_model, self.d_ff)
        self.activation = nn.GELU()
        self.linear2 = nn.Linear(self.d_ff, self.d_model)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, c):
        y = torch.cat((x, c), dim=2)
        
        norm_y = self.layer_norm(y)
        hidden = self.linear1(norm_y)
        hidden = self.activation(hidden)
        hidden = self.dropout(hidden)
        output = self.linear2(hidden)

        return output + y

# %%
class FluxTransformerLayer(nn.Module):
    """Single transformer block without embedding layer"""
    def __init__(self, d_model=8, n_heads=2, d_ff=128, dropout=0.1):
        super().__init__()
        self.d_model = d_model
        
        self.attention_block = AttentionBlock(d_model, n_heads, dropout)
        self.feedforward_block = FeedForwardBlock(d_model, d_ff, dropout)
        
        self.apply(self._init_weights)
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
    
    def forward(self, x, c):
        attn_x, attn_c = self.attention_block(x, c)
        ff_output = self.feedforward_block(attn_x, attn_c)
        
        # Split the concatenated output
        updated_x = ff_output[:, :, :-1]
        updated_c = ff_output[:, :, -1:]
        
        return updated_x, updated_c

# %%
class FluxTransformer(nn.Module):
    def __init__(
        self,
        vocab_size=2742,
        d_model=128,
        n_heads=8,
        n_layers=3,
        d_ff=1024,
        dropout=0.2,
        input_length=30
    ):
        super().__init__()
        self.vocab_size = vocab_size
        self.d_model = d_model
        self.input_length = input_length

        self.input_embedding = nn.Embedding(vocab_size, d_model)

        self.layers = nn.ModuleList([
            FluxTransformerLayer(
                d_model=d_model,
                n_heads=n_heads,
                d_ff=d_ff,
                dropout=dropout
            )
            for _ in range(n_layers)
        ])

    def forward(self, c, output_subset=None, return_embedding=False):
        """
        Args:
            c: (batch, 1) or (batch, seq, 1) context tensor
            output_subset: 1D tensor of indices (subset of outputs) or None
            return_embedding: if True, return embeddings instead of c

        Returns:
            c: updated context
            selected_indices: indices of tokens used (always include inputs 0..29)
        """
        batch_size = c.size(0)

        # Always include input indices
        input_indices = torch.arange(self.input_length, device=c.device)

        if output_subset is None:
            selected_indices = torch.arange(self.vocab_size, device=c.device)
        else:
            # Concatenate inputs + sampled outputs
            selected_indices = torch.cat([input_indices, output_subset.to(c.device)])
            selected_indices = torch.unique(selected_indices, sorted=True)

        # Expand indices for batch
        y = selected_indices.unsqueeze(0).expand(batch_size, -1)  # (B, seq_subset)
        x = self.input_embedding(y)  # (B, seq_subset, d_model)

        # Slice c to selected indices
        c_subset = c[:, selected_indices, :]

        for layer in self.layers:
            x, c_subset = layer(x, c_subset)

        if return_embedding:
            return x, selected_indices  # embeddings + indices

        return c_subset, selected_indices

# %%
def load_data(filepath):
    """Load and preprocess the training data"""
    inputs = [
        'EX_glc__D_e', 'EX_fru_e', 'EX_lac__D_e', 'EX_pyr_e', 'EX_ac_e',
        'EX_akg_e', 'EX_succ_e', 'EX_fum_e', 'EX_mal__L_e', 'EX_etoh_e',
        'EX_acald_e', 'EX_for_e', 'EX_gln__L_e', 'EX_glu__L_e',
        'EX_co2_e', 'EX_h_e', 'EX_h2o_e', 'EX_nh4_e', 'EX_o2_e', 'EX_pi_e'
    ]

    outputs = [
        'ACALD_flux', 'ACALDt_flux', 'ACKr_flux', 'ACONTa_flux', 'ACONTb_flux',
        'ACt2r_flux', 'ADK1_flux', 'AKGDH_flux', 'AKGt2r_flux', 'ALCD2x_flux',
        'ATPM_flux', 'ATPS4r_flux', 'Biomass_Ecoli_core_flux', 'CO2t_flux', 'CS_flux',
        'CYTBD_flux', 'D_LACt2_flux', 'ENO_flux', 'ETOHt2r_flux', 'EX_ac_e_flux',
        'EX_acald_e_flux', 'EX_akg_e_flux', 'EX_co2_e_flux', 'EX_etoh_e_flux', 'EX_for_e_flux',
        'EX_fru_e_flux', 'EX_fum_e_flux', 'EX_glc__D_e_flux', 'EX_gln__L_e_flux', 'EX_glu__L_e_flux',
        'EX_h_e_flux', 'EX_h2o_e_flux', 'EX_lac__D_e_flux', 'EX_mal__L_e_flux', 'EX_nh4_e_flux',
        'EX_o2_e_flux', 'EX_pi_e_flux', 'EX_pyr_e_flux', 'EX_succ_e_flux', 'FBA_flux',
        'FBP_flux', 'FORt2_flux', 'FORti_flux', 'FRD7_flux', 'FRUpts2_flux',
        'FUM_flux', 'FUMt2_2_flux', 'G6PDH2r_flux', 'GAPD_flux', 'GLCpts_flux',
        'GLNS_flux', 'GLNabc_flux', 'GLUDy_flux', 'GLUN_flux', 'GLUSy_flux',
        'GLUt2r_flux', 'GND_flux', 'H2Ot_flux', 'ICDHyr_flux', 'ICL_flux',
        'LDH_D_flux', 'MALS_flux', 'MALt2_2_flux', 'MDH_flux', 'ME1_flux',
        'ME2_flux', 'NADH16_flux', 'NADTRHD_flux', 'NH4t_flux', 'O2t_flux',
        'PDH_flux', 'PFK_flux', 'PFL_flux', 'PGI_flux', 'PGK_flux',
        'PGL_flux', 'PGM_flux', 'PIt2r_flux', 'PPC_flux', 'PPCK_flux',
        'PPS_flux', 'PTAr_flux', 'PYK_flux', 'PYRt2_flux', 'RPE_flux',
        'RPI_flux', 'SUCCt2_2_flux', 'SUCCt3_flux', 'SUCDi_flux', 'SUCOAS_flux',
        'TALA_flux', 'THD2_flux', 'TKT1_flux', 'TKT2_flux', 'TPI_flux'
    ]
    
    df = pd.read_csv(filepath)

    # Fill missing inputs with 0 (i.e., not uptaken)
    df[inputs] = df[inputs].fillna(0)

    print(f"\nLoaded data with {len(df)} samples from {filepath}")
    print(f"Number of input features: {len(inputs)}")
    print(f"Number of output targets: {len(outputs)}")

    X = df[inputs].to_numpy(dtype=np.float32)
    y = df[outputs].to_numpy(dtype=np.float32)

    X_combined = np.hstack([X, np.zeros_like(y)])
    y_combined = np.hstack([np.zeros_like(X), y])

    return X_combined, y_combined, inputs, outputs

# %%
def prepare_tensors(X, y, test_size=0.4, device="cpu"):
    """
    Split data into train/test and convert to PyTorch tensors.
    
    Parameters:
        X (ndarray): Input features.
        y (ndarray): Output targets.
        test_size (float): Fraction of data to reserve for testing.
        device (str or torch.device): Device to move tensors to.
    
    Returns:
        X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor (torch.Tensor)
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    print(f"Training samples: {len(X_train)}")
    print(f"Test samples: {len(X_test)}")

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)

    return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor

# %%
def create_dataloaders(X_train, y_train, X_test, y_test, batch_size):
    """
    Create PyTorch DataLoaders for training and testing.

    Parameters:
        X_train, y_train (Tensor): Training data and labels.
        X_test, y_test (Tensor): Test data and labels.
        batch_size (int): Batch size for loading.

    Returns:
        train_loader, test_loader (DataLoader): PyTorch DataLoaders.
    """
    train_dataset = TensorDataset(X_train.unsqueeze(-1), y_train.unsqueeze(-1))
    test_dataset = TensorDataset(X_test.unsqueeze(-1), y_test.unsqueeze(-1))

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
# Load and preprocess data

X, y, input_cols, output_cols = load_data(DATA_PATH)
X_train, X_test, y_train, y_test = prepare_tensors(X, y, device=device)
train_loader, test_loader = create_dataloaders(X_train, y_train, X_test, y_test, batch_size=128)
# Out:
# Loaded data with 98066 samples from ./data/2025-07-15_full_training_data_98066_samples.csv
# Number of input features: 20
# Number of output targets: 95
# Training samples: 58839
# Test samples: 39227

# %%
X_train.size(), y_train.size()
# Out:
# (torch.Size([58839, 115]), torch.Size([58839, 115]))

# %%
def train_model(
    d_model=128,
    n_heads=8,
    n_layers=3,
    d_ff=640,
    num_epochs=100,
    learning_rate=0.001,
    dropout=0.02,
    output_sample_ratio=0.5
):
    start_time = time.time()

    model = FluxTransformer(
        vocab_size=115,
        d_model=d_model,
        n_heads=n_heads,
        n_layers=n_layers,
        d_ff=d_ff,
        dropout=dropout
    ).to(device)
    
    optimizer = optim.AdamW(
        model.parameters(),
        lr=learning_rate,
        betas=(0.9, 0.98),
        eps=1e-9,
        weight_decay=1e-4
    )
    criterion = nn.HuberLoss()

    best_test_loss = float('inf')
    best_epoch = -1

    train_losses = []
    test_losses = []

    total_outputs = 95
    output_start_idx = 20

    for epoch in range(num_epochs):
        model.train()
        epoch_train_loss = 0.0
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()

            # Randomly sample subset of outputs
            if output_sample_ratio >= 1.0:
                sampled_indices = None  # pass None to FluxTransformer.forward()
            else:
                n_sampled = max(1, int(total_outputs * output_sample_ratio))
                sampled_indices = torch.tensor(
                    random.sample(range(output_start_idx, output_start_idx + total_outputs), n_sampled),
                    device=device
                )

            predictions, selected_indices = model(batch_X, output_subset=sampled_indices)
            
            target = batch_y[:, selected_indices, :]

            loss = criterion(predictions, target)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            epoch_train_loss += loss.item() * batch_X.size(0)

            # Explicitly free tensors
            del predictions, loss
            torch.cuda.empty_cache()
        
        epoch_train_loss /= len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # Evaluation
        model.eval()
        epoch_test_loss = 0.0
        with torch.no_grad():
            for batch_X, batch_y in test_loader:
                n_sampled = max(1, int(total_outputs * output_sample_ratio))
                sampled_indices = torch.tensor(
                    random.sample(range(output_start_idx, output_start_idx + total_outputs), n_sampled),
                    device=device
                )

                predictions, selected_indices = model(batch_X, output_subset=sampled_indices)
                target = batch_y[:, selected_indices, :]
                loss = criterion(predictions, target)

                epoch_test_loss += loss.item() * batch_X.size(0)

                # Explicitly free tensors
                del predictions, loss
                torch.cuda.empty_cache()
        
        epoch_test_loss /= len(test_loader.dataset)
        test_losses.append(epoch_test_loss)

        if (epoch+1) % 2 == 0:
            print(f"Epoch {epoch+1}/{num_epochs} | "
                f"Train Loss: {epoch_train_loss:.6f} | "
                f"Test Loss: {epoch_test_loss:.6f}")
        
        if epoch_test_loss < best_test_loss:
            best_test_loss = epoch_test_loss
            best_epoch = epoch + 1
        
        # Additional memory cleanup after epoch
        torch.cuda.empty_cache()
        gc.collect()

    print('Training Completed.')
    end_time = time.time()
    elapsed_time = end_time - start_time
    mins, secs = divmod(elapsed_time, 60)
    print(f"Training took {int(mins)} min {secs:.1f} sec.")
    print(f"Best test loss: {best_test_loss:.6f} at epoch {best_epoch}")
    
    return train_losses, test_losses, model, optimizer

# %% [markdown]
# ### Plotting Functions

# %%
def plot_loss_curves(train_losses, test_losses, d_model, n_heads, n_layers, d_ff, save_path=None, log_scale=True):
    plt.figure(figsize=(14, 10))
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.plot(train_losses, label="Training Loss")
    plt.plot(test_losses, label="Test Loss")
    if log_scale:
        plt.yscale('log')
    plt.xlabel("Epoch", fontsize=18)
    plt.ylabel("Loss", fontsize=18)
    plt.title(f"Loss Curves (d={d_model}, h={n_heads}, l={n_layers}, ff={d_ff})", fontsize=20)
    plt.grid(True)
    plt.legend(fontsize=16)
    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path)
        plt.close()
        print(f"\nTraining curve saved to {save_path}")
    else:
        plt.show()

# %%
def plot_diagnostics_2x2(y_true, y_pred, label):
    """Creates a 2x2 matrix of plots: true vs predicted, residuals, error distribution, and histogram of samples"""
    residuals = y_true - y_pred

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    
    # True vs Predicted
    axs[0, 0].scatter(y_true, y_pred, alpha=0.2, s=5, color='royalblue')
    axs[0, 0].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=2)
    axs[0, 0].set_title(f'True vs Predicted: {label}')
    axs[0, 0].set_xlabel('True value')
    axs[0, 0].set_ylabel('Predicted')
    axs[0, 0].grid(True)

    # Residuals plot
    axs[0, 1].scatter(y_true, residuals, alpha=0.15, color='darkorange')
    axs[0, 1].axhline(y=0, color='r', linestyle='-')
    axs[0, 1].set_title(f'Residuals: {label}')
    axs[0, 1].set_xlabel('True value')
    axs[0, 1].set_ylabel('Residuals')
    axs[0, 1].grid(True)

    # Error distribution
    sns.histplot(residuals, kde=True, ax=axs[1, 0], legend=False, color='indianred')
    axs[1, 0].set_title(f'Prediction Error Distribution: {label}')
    axs[1, 0].set_xlabel('Prediction Error')
    axs[1, 0].set_ylabel('Frequency')
    axs[1, 0].grid(True)

    # Histogram of actual values
    sns.histplot(y_true, kde=True, bins=100, ax=axs[1, 1], legend=False, color='mediumseagreen')
    axs[1, 1].set_title(f'True Value Distribution: {label}')
    axs[1, 1].set_xlabel('True Value')
    axs[1, 1].set_ylabel('Frequency')
    axs[1, 1].grid(True)

    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def plot_prediction_sample(X_test, y_test, model):
    X_test_ = X_test.unsqueeze(-1)
    y_test_ = y_test.unsqueeze(-1)
    j = np.random.randint(0, X_test_.size(0), 1)[0]
    with torch.no_grad():
        pred, _ = model(X_test_[j].unsqueeze(0))
    true = y_test_[j].unsqueeze(0)
    plt.plot(pred[0,:,0].cpu().detach().numpy(), label='Predicted')
    plt.plot(true[0,:,0].cpu().detach().numpy(), label='True')

    # add a red vertical line at index 32 (biomass)
    plt.axvline(x=32, color='red', linestyle='--', linewidth=1)
    
    plt.legend()
    plt.title(f"Sample index {j}")
    plt.xlabel("Reaction ID")
    plt.ylabel("Rate")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def plot_flux(
    model,
    X_test,
    y_test,
    output_cols,
    flux_name: str,
):
    """ Displays a 2x2 diagnostic plot for the chosen flux."""

    #model.eval()
    model_cpu = model.to('cpu')  # move model to CPU
    model_cpu.eval()

    with torch.no_grad():
        y_pred_tensor, _ = model_cpu(X_test.unsqueeze(-1).to('cpu'))  # shape: [n_samples, 115, 1]
        #y_pred_tensor = model(X_test.unsqueeze(-1).to(device))  # shape: [n_samples, 115, 1]

    y_pred_full = y_pred_tensor.squeeze(-1).cpu().numpy()  # shape: [n_samples, 115]
    y_true_full = y_test.cpu().numpy()                     # shape: [n_samples, 115]

    # Extract only the output predictions (last 95 columns)
    y_pred_outputs = y_pred_full[:, 20:]
    y_true_outputs = y_true_full[:, 20:]
    print("y_pred_outputs.shape:", y_pred_outputs.shape,
            "min/max:", y_pred_outputs.min(), y_pred_outputs.max())
    print("y_true_outputs.shape:", y_true_outputs.shape,
            "min/max:", y_true_outputs.min(), y_true_outputs.max())

    try:
        idx = output_cols.index(flux_name)
    except ValueError:
        raise ValueError(f"Flux '{flux_name}' not found in output_cols")

    # Verify the correct column
    print(f"{flux_name} index in outputs: {idx}")
    print(f"y_true_outputs[:, idx] range:",
            y_true_outputs[:, idx].min(), "to", y_true_outputs[:, idx].max())
    print(f"y_pred_outputs[:, _idx] range:",
            y_pred_outputs[:, idx].min(), "to", y_pred_outputs[:, idx].max())

    # Plot diagnostics specifically for given flux
    plot_diagnostics_2x2(
        y_true=y_true_outputs[:, idx],
        y_pred=y_pred_outputs[:, idx],
        label=flux_name
    )

# %%
def plot_output_ratio_metric(ratios, r2_values, flux_name, metric_name='r2', save_path=None):
    """
    Plot R² performance vs. output subset ratio.
    """
    plt.figure(figsize=(14, 10))
    plt.plot(ratios, r2_values, marker='o', linewidth=2)
    plt.xlabel('Output Subset Ratio', fontsize=18)
    plt.ylabel(metric_name.upper(), fontsize=18)
    plt.title(f'Impact of Output Subset Ratio on {flux_name} Prediction', fontsize=20)
    plt.grid(True)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlim(0, 1)
    
    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        print(f"Saved output ratio plot to {save_path}")
        plt.close()
    else:
        plt.show()

# %% [markdown]
# ### Effect of Output Subset Ratio

# %%
d_model = 128
n_heads = 8
n_layers = 3
d_ff = 640
batch_size = 128
num_epochs = 200
learning_rate = 1e-4
dropout = 0.02

# %%
def evaluate_metrics(model, X_test, y_test, output_cols, device='cpu', batch_size=16):
    """
    Evaluate a trained FluxTransformer model on test data.

    Args:
        model (nn.Module): Trained PyTorch model.
        X_test (Tensor): Test inputs, shape [n_samples, input+output features].
        y_test (Tensor): Test outputs, shape [n_samples, input+output features].
        output_cols (list of str): Names of output flux columns.
        device (str or torch.device): Device to run evaluation on.

    Returns:
        pd.DataFrame: DataFrame with columns ['flux', 'r2', 'mae'].
    """
    model = model.to(device)
    model.eval()

    y_preds = []
    y_trues = []
    
    n_samples = X_test.size(0)
    
    with torch.no_grad():
        for start in range(0, n_samples, batch_size):
            end = min(start + batch_size, n_samples)
            x_batch = X_test[start:end].unsqueeze(-1).to(device)
            y_batch = y_test[start:end].to(device)
            
            y_pred_tensor, _ = model(x_batch)
            y_preds.append(y_pred_tensor.squeeze(-1).cpu())
            y_trues.append(y_batch.cpu())
    
    y_pred = torch.cat(y_preds, dim=0).numpy()[:, 20:]  # skip input indices
    y_true = torch.cat(y_trues, dim=0).numpy()[:, 20:]

    metrics = []
    for i, label in enumerate(output_cols):
        r2 = r2_score(y_true[:, i], y_pred[:, i])
        mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
        metrics.append({'flux': label.replace('_flux',''), 'r2': r2, 'mae': mae})

    df_metrics = pd.DataFrame(metrics)
    df_metrics['r2'] = df_metrics['r2'].map('{:.3f}'.format)
    df_metrics['mae'] = df_metrics['mae'].map('{:.4f}'.format)
    
    return df_metrics

# %%
biomass_col = 'Biomass_Ecoli_core'

ratios = np.arange(0.1, 1.1, 0.1)
biomass_r2 = []
biomass_mae = []

for ratio in ratios:
    print(f"\nTraining with output subset ratio = {ratio:.1f}")
    
    # Train model with given output_sample_ratio
    train_loss, test_loss, model, optimizer = train_model(
        d_model=d_model,
        n_heads=n_heads,
        n_layers=n_layers,
        d_ff=d_ff,
        num_epochs=num_epochs,
        learning_rate=learning_rate,
        dropout=dropout,
        output_sample_ratio=ratio
    )
    
    # Evaluate R² for biomass
    df_metrics = evaluate_metrics(model, X_test, y_test, output_cols, device=device, batch_size=batch_size)
    row = df_metrics.loc[df_metrics['flux'] == biomass_col.replace('_flux', '')].iloc[0]
    
    r2_value = float(row['r2'])
    mae_value = float(row['mae'])
    
    biomass_r2.append(r2_value)
    biomass_mae.append(mae_value)
    
    # Free GPU memory
    del model, optimizer, train_loss, test_loss
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# Training with output subset ratio = 0.1
# Epoch 2/200 | Train Loss: 1.636077 | Test Loss: 1.732194
# Epoch 4/200 | Train Loss: 1.212969 | Test Loss: 1.004034
# Epoch 6/200 | Train Loss: 0.821682 | Test Loss: 0.756717
# Epoch 8/200 | Train Loss: 0.664433 | Test Loss: 0.609013
# Epoch 10/200 | Train Loss: 0.545617 | Test Loss: 0.467986
# Epoch 12/200 | Train Loss: 0.465653 | Test Loss: 0.420303
# Epoch 14/200 | Train Loss: 0.408434 | Test Loss: 0.350768
# Epoch 16/200 | Train Loss: 0.368783 | Test Loss: 0.339016
# Epoch 18/200 | Train Loss: 0.345730 | Test Loss: 0.357040
# Epoch 20/200 | Train Loss: 0.331235 | Test Loss: 0.277343
# Epoch 22/200 | Train Loss: 0.310039 | Test Loss: 0.276651
# Epoch 24/200 | Train Loss: 0.288665 | Test Loss: 0.260451
# Epoch 26/200 | Train Loss: 0.276739 | Test Loss: 0.246295
# Epoch 28/200 | Train Loss: 0.268499 | Test Loss: 0.232039
# Epoch 30/200 | Train Loss: 0.249212 | Test Loss: 0.216991
# Epoch 32/200 | Train Loss: 0.244829 | Test Loss: 0.202971
# Epoch 34/200 | Train Loss: 0.243043 | Test Loss: 0.198716
# Epoch 36/200 | Train Loss: 0.225806 | Test Loss: 0.192782
# Epoch 38/200 | Train Loss: 0.224303 | Test Loss: 0.184613
# Epoch 40/200 | Train Loss: 0.215164 | Test Loss: 0.193437
# Epoch 42/200 | Train Loss: 0.207447 | Test Loss: 0.187562
# Epoch 44/200 | Train Loss: 0.194985 | Test Loss: 0.184246
# Epoch 46/200 | Train Loss: 0.198031 | Test Loss: 0.169670
# Epoch 48/200 | Train Loss: 0.190977 | Test Loss: 0.154266
# Epoch 50/200 | Train Loss: 0.186205 | Test Loss: 0.172012
# Epoch 52/200 | Train Loss: 0.182781 | Test Loss: 0.150420
# Epoch 54/200 | Train Loss: 0.177889 | Test Loss: 0.163947
# Epoch 56/200 | Train Loss: 0.176362 | Test Loss: 0.151038
# Epoch 58/200 | Train Loss: 0.172559 | Test Loss: 0.154188
# Epoch 60/200 | Train Loss: 0.166847 | Test Loss: 0.139203
# Epoch 62/200 | Train Loss: 0.162943 | Test Loss: 0.150574
# Epoch 64/200 | Train Loss: 0.161156 | Test Loss: 0.141193
# Epoch 66/200 | Train Loss: 0.162062 | Test Loss: 0.132610
# Epoch 68/200 | Train Loss: 0.155993 | Test Loss: 0.143384
# Epoch 70/200 | Train Loss: 0.153520 | Test Loss: 0.127041
# Epoch 72/200 | Train Loss: 0.158029 | Test Loss: 0.128444
# Epoch 74/200 | Train Loss: 0.148237 | Test Loss: 0.122671
# Epoch 76/200 | Train Loss: 0.150739 | Test Loss: 0.129792
# Epoch 78/200 | Train Loss: 0.147999 | Test Loss: 0.124465
# Epoch 80/200 | Train Loss: 0.145172 | Test Loss: 0.128067
# Epoch 82/200 | Train Loss: 0.144733 | Test Loss: 0.128423
# Epoch 84/200 | Train Loss: 0.140504 | Test Loss: 0.115630
# Epoch 86/200 | Train Loss: 0.139691 | Test Loss: 0.123657
# Epoch 88/200 | Train Loss: 0.141747 | Test Loss: 0.112921
# Epoch 90/200 | Train Loss: 0.139167 | Test Loss: 0.119093
# Epoch 92/200 | Train Loss: 0.139771 | Test Loss: 0.120752
# Epoch 94/200 | Train Loss: 0.138474 | Test Loss: 0.125516
# Epoch 96/200 | Train Loss: 0.131592 | Test Loss: 0.118587
# Epoch 98/200 | Train Loss: 0.134512 | Test Loss: 0.118034
# Epoch 100/200 | Train Loss: 0.134089 | Test Loss: 0.107636
# Epoch 102/200 | Train Loss: 0.132561 | Test Loss: 0.121468
# Epoch 104/200 | Train Loss: 0.132161 | Test Loss: 0.111866
# Epoch 106/200 | Train Loss: 0.129480 | Test Loss: 0.114749
# Epoch 108/200 | Train Loss: 0.130124 | Test Loss: 0.114213
# Epoch 110/200 | Train Loss: 0.127421 | Test Loss: 0.113828
# Epoch 112/200 | Train Loss: 0.125545 | Test Loss: 0.111793
# Epoch 114/200 | Train Loss: 0.127469 | Test Loss: 0.120979
# Epoch 116/200 | Train Loss: 0.124593 | Test Loss: 0.107253
# Epoch 118/200 | Train Loss: 0.124478 | Test Loss: 0.115253
# Epoch 120/200 | Train Loss: 0.124410 | Test Loss: 0.100918
# Epoch 122/200 | Train Loss: 0.121187 | Test Loss: 0.109908
# Epoch 124/200 | Train Loss: 0.121307 | Test Loss: 0.108441
# Epoch 126/200 | Train Loss: 0.120020 | Test Loss: 0.099448
# Epoch 128/200 | Train Loss: 0.119091 | Test Loss: 0.107764
# Epoch 130/200 | Train Loss: 0.121651 | Test Loss: 0.107047
# Epoch 132/200 | Train Loss: 0.117084 | Test Loss: 0.098508
# Epoch 134/200 | Train Loss: 0.121368 | Test Loss: 0.096880
# Epoch 136/200 | Train Loss: 0.117993 | Test Loss: 0.106293
# Epoch 138/200 | Train Loss: 0.114142 | Test Loss: 0.104512
# Epoch 140/200 | Train Loss: 0.115626 | Test Loss: 0.101138
# Epoch 142/200 | Train Loss: 0.113130 | Test Loss: 0.103109
# Epoch 144/200 | Train Loss: 0.113678 | Test Loss: 0.104549
# Epoch 146/200 | Train Loss: 0.113729 | Test Loss: 0.100253
# Epoch 148/200 | Train Loss: 0.116495 | Test Loss: 0.097302
# Epoch 150/200 | Train Loss: 0.112439 | Test Loss: 0.093722
# Epoch 152/200 | Train Loss: 0.112406 | Test Loss: 0.096309
# Epoch 154/200 | Train Loss: 0.112884 | Test Loss: 0.094714
# Epoch 156/200 | Train Loss: 0.109836 | Test Loss: 0.095290
# Epoch 158/200 | Train Loss: 0.110553 | Test Loss: 0.096172
# Epoch 160/200 | Train Loss: 0.109495 | Test Loss: 0.090328
# Epoch 162/200 | Train Loss: 0.107228 | Test Loss: 0.093604
# Epoch 164/200 | Train Loss: 0.108437 | Test Loss: 0.102276
# Epoch 166/200 | Train Loss: 0.102231 | Test Loss: 0.094906
# Epoch 168/200 | Train Loss: 0.100936 | Test Loss: 0.095225
# Epoch 170/200 | Train Loss: 0.106546 | Test Loss: 0.089060
# Epoch 172/200 | Train Loss: 0.106935 | Test Loss: 0.090357
# Epoch 174/200 | Train Loss: 0.104064 | Test Loss: 0.094116
# Epoch 176/200 | Train Loss: 0.106098 | Test Loss: 0.090126
# Epoch 178/200 | Train Loss: 0.101181 | Test Loss: 0.093095
# Epoch 180/200 | Train Loss: 0.101007 | Test Loss: 0.089829
# Epoch 182/200 | Train Loss: 0.101340 | Test Loss: 0.089233
# Epoch 184/200 | Train Loss: 0.103271 | Test Loss: 0.088722
# Epoch 186/200 | Train Loss: 0.101379 | Test Loss: 0.085048
# Epoch 188/200 | Train Loss: 0.100428 | Test Loss: 0.085755
# Epoch 190/200 | Train Loss: 0.099084 | Test Loss: 0.085644
# Epoch 192/200 | Train Loss: 0.098704 | Test Loss: 0.089528
# Epoch 194/200 | Train Loss: 0.101094 | Test Loss: 0.087668
# Epoch 196/200 | Train Loss: 0.106533 | Test Loss: 0.083761
# Epoch 198/200 | Train Loss: 0.098508 | Test Loss: 0.087367
# Epoch 200/200 | Train Loss: 0.097888 | Test Loss: 0.091085
# Training Completed.
# Training took 47 min 12.8 sec.
# Best test loss: 0.078672 at epoch 199
#
# Training with output subset ratio = 0.2
# Epoch 2/200 | Train Loss: 2.007027 | Test Loss: 1.710010
# Epoch 4/200 | Train Loss: 1.558249 | Test Loss: 1.364805
# Epoch 6/200 | Train Loss: 1.066578 | Test Loss: 0.949677
# Epoch 8/200 | Train Loss: 0.757489 | Test Loss: 0.653131
# Epoch 10/200 | Train Loss: 0.591879 | Test Loss: 0.516210
# Epoch 12/200 | Train Loss: 0.510154 | Test Loss: 0.452735
# Epoch 14/200 | Train Loss: 0.471375 | Test Loss: 0.416089
# Epoch 16/200 | Train Loss: 0.435317 | Test Loss: 0.370902
# Epoch 18/200 | Train Loss: 0.404299 | Test Loss: 0.346830
# Epoch 20/200 | Train Loss: 0.362331 | Test Loss: 0.320718
# Epoch 22/200 | Train Loss: 0.343379 | Test Loss: 0.310470
# Epoch 24/200 | Train Loss: 0.323459 | Test Loss: 0.289669
# Epoch 26/200 | Train Loss: 0.311186 | Test Loss: 0.267663
# Epoch 28/200 | Train Loss: 0.296067 | Test Loss: 0.248652
# Epoch 30/200 | Train Loss: 0.283485 | Test Loss: 0.237453
# Epoch 32/200 | Train Loss: 0.268883 | Test Loss: 0.225115
# Epoch 34/200 | Train Loss: 0.258802 | Test Loss: 0.217866
# Epoch 36/200 | Train Loss: 0.251868 | Test Loss: 0.209345
# Epoch 38/200 | Train Loss: 0.244335 | Test Loss: 0.216662
# Epoch 40/200 | Train Loss: 0.239879 | Test Loss: 0.199273
# Epoch 42/200 | Train Loss: 0.233411 | Test Loss: 0.210145
# Epoch 44/200 | Train Loss: 0.228591 | Test Loss: 0.201405
# Epoch 46/200 | Train Loss: 0.223334 | Test Loss: 0.195260
# Epoch 48/200 | Train Loss: 0.219988 | Test Loss: 0.185385
# Epoch 50/200 | Train Loss: 0.213428 | Test Loss: 0.184345
# Epoch 52/200 | Train Loss: 0.205962 | Test Loss: 0.170593
# Epoch 54/200 | Train Loss: 0.205016 | Test Loss: 0.175718
# Epoch 56/200 | Train Loss: 0.201815 | Test Loss: 0.166871
# Epoch 58/200 | Train Loss: 0.198704 | Test Loss: 0.169486
# Epoch 60/200 | Train Loss: 0.195284 | Test Loss: 0.171394
# Epoch 62/200 | Train Loss: 0.193196 | Test Loss: 0.163327
# Epoch 64/200 | Train Loss: 0.192799 | Test Loss: 0.165911
# Epoch 66/200 | Train Loss: 0.186426 | Test Loss: 0.165166
# Epoch 68/200 | Train Loss: 0.187600 | Test Loss: 0.154569
# Epoch 70/200 | Train Loss: 0.183031 | Test Loss: 0.149615
# Epoch 72/200 | Train Loss: 0.181761 | Test Loss: 0.165960
# Epoch 74/200 | Train Loss: 0.182307 | Test Loss: 0.153477
# Epoch 76/200 | Train Loss: 0.174287 | Test Loss: 0.148960
# Epoch 78/200 | Train Loss: 0.174751 | Test Loss: 0.143714
# Epoch 80/200 | Train Loss: 0.174218 | Test Loss: 0.150479
# Epoch 82/200 | Train Loss: 0.168813 | Test Loss: 0.149309
# Epoch 84/200 | Train Loss: 0.169735 | Test Loss: 0.143660
# Epoch 86/200 | Train Loss: 0.166104 | Test Loss: 0.151608
# Epoch 88/200 | Train Loss: 0.166155 | Test Loss: 0.148324
# Epoch 90/200 | Train Loss: 0.167960 | Test Loss: 0.140563
# Epoch 92/200 | Train Loss: 0.165168 | Test Loss: 0.143452
# Epoch 94/200 | Train Loss: 0.159523 | Test Loss: 0.145118
# Epoch 96/200 | Train Loss: 0.165175 | Test Loss: 0.142924
# Epoch 98/200 | Train Loss: 0.163062 | Test Loss: 0.137446
# Epoch 100/200 | Train Loss: 0.156035 | Test Loss: 0.138624
# Epoch 102/200 | Train Loss: 0.156770 | Test Loss: 0.139955
# Epoch 104/200 | Train Loss: 0.154462 | Test Loss: 0.139441
# Epoch 106/200 | Train Loss: 0.155114 | Test Loss: 0.135329
# Epoch 108/200 | Train Loss: 0.153873 | Test Loss: 0.134685
# Epoch 110/200 | Train Loss: 0.154607 | Test Loss: 0.126420
# Epoch 112/200 | Train Loss: 0.152292 | Test Loss: 0.132054
# Epoch 114/200 | Train Loss: 0.152915 | Test Loss: 0.122637
# Epoch 116/200 | Train Loss: 0.150935 | Test Loss: 0.130073
# Epoch 118/200 | Train Loss: 0.148593 | Test Loss: 0.122001
# Epoch 120/200 | Train Loss: 0.146055 | Test Loss: 0.123177
# Epoch 122/200 | Train Loss: 0.142201 | Test Loss: 0.119558
# Epoch 124/200 | Train Loss: 0.143963 | Test Loss: 0.128050
# Epoch 126/200 | Train Loss: 0.142707 | Test Loss: 0.122617
# Epoch 128/200 | Train Loss: 0.140021 | Test Loss: 0.128907
# Epoch 130/200 | Train Loss: 0.137449 | Test Loss: 0.118243
# Epoch 132/200 | Train Loss: 0.137281 | Test Loss: 0.116301
# Epoch 134/200 | Train Loss: 0.136890 | Test Loss: 0.119417
# Epoch 136/200 | Train Loss: 0.139139 | Test Loss: 0.116951
# Epoch 138/200 | Train Loss: 0.139237 | Test Loss: 0.128469
# Epoch 140/200 | Train Loss: 0.139124 | Test Loss: 0.127863
# Epoch 142/200 | Train Loss: 0.134385 | Test Loss: 0.116623
# Epoch 144/200 | Train Loss: 0.137382 | Test Loss: 0.117182
# Epoch 146/200 | Train Loss: 0.134081 | Test Loss: 0.117755
# Epoch 148/200 | Train Loss: 0.133541 | Test Loss: 0.125155
# Epoch 150/200 | Train Loss: 0.131704 | Test Loss: 0.113211
# Epoch 152/200 | Train Loss: 0.132391 | Test Loss: 0.112712
# Epoch 154/200 | Train Loss: 0.132041 | Test Loss: 0.117739
# Epoch 156/200 | Train Loss: 0.133449 | Test Loss: 0.117270
# Epoch 158/200 | Train Loss: 0.132221 | Test Loss: 0.114005
# Epoch 160/200 | Train Loss: 0.131650 | Test Loss: 0.114975
# Epoch 162/200 | Train Loss: 0.128174 | Test Loss: 0.111875
# Epoch 164/200 | Train Loss: 0.126291 | Test Loss: 0.116177
# Epoch 166/200 | Train Loss: 0.129529 | Test Loss: 0.117544
# Epoch 168/200 | Train Loss: 0.130425 | Test Loss: 0.115340
# Epoch 170/200 | Train Loss: 0.129066 | Test Loss: 0.114783
# Epoch 172/200 | Train Loss: 0.127824 | Test Loss: 0.118529
# Epoch 174/200 | Train Loss: 0.127273 | Test Loss: 0.115636
# Epoch 176/200 | Train Loss: 0.124211 | Test Loss: 0.112836
# Epoch 178/200 | Train Loss: 0.126199 | Test Loss: 0.113987
# Epoch 180/200 | Train Loss: 0.127766 | Test Loss: 0.111800
# Epoch 182/200 | Train Loss: 0.126418 | Test Loss: 0.111229
# Epoch 184/200 | Train Loss: 0.125914 | Test Loss: 0.110455
# Epoch 186/200 | Train Loss: 0.126560 | Test Loss: 0.113853
# Epoch 188/200 | Train Loss: 0.126297 | Test Loss: 0.107169
# Epoch 190/200 | Train Loss: 0.127214 | Test Loss: 0.112192
# Epoch 192/200 | Train Loss: 0.126641 | Test Loss: 0.108558
# Epoch 194/200 | Train Loss: 0.125513 | Test Loss: 0.110762
# Epoch 196/200 | Train Loss: 0.122924 | Test Loss: 0.105983
# Epoch 198/200 | Train Loss: 0.126187 | Test Loss: 0.105545
# Epoch 200/200 | Train Loss: 0.118512 | Test Loss: 0.111466
# Training Completed.
# Training took 57 min 49.4 sec.
# Best test loss: 0.105249 at epoch 183
#
# Training with output subset ratio = 0.3
# Epoch 2/200 | Train Loss: 2.065563 | Test Loss: 1.994062
# Epoch 4/200 | Train Loss: 1.530954 | Test Loss: 1.345711
# Epoch 6/200 | Train Loss: 0.942459 | Test Loss: 0.843286
# Epoch 8/200 | Train Loss: 0.809520 | Test Loss: 0.735990
# Epoch 10/200 | Train Loss: 0.702109 | Test Loss: 0.624748
# Epoch 12/200 | Train Loss: 0.627912 | Test Loss: 0.539782
# Epoch 14/200 | Train Loss: 0.567632 | Test Loss: 0.505328
# Epoch 16/200 | Train Loss: 0.521326 | Test Loss: 0.464752
# Epoch 18/200 | Train Loss: 0.487109 | Test Loss: 0.419751
# Epoch 20/200 | Train Loss: 0.456729 | Test Loss: 0.395982
# Epoch 22/200 | Train Loss: 0.422173 | Test Loss: 0.382964
# Epoch 24/200 | Train Loss: 0.397550 | Test Loss: 0.342704
# Epoch 26/200 | Train Loss: 0.374107 | Test Loss: 0.317760
# Epoch 28/200 | Train Loss: 0.359149 | Test Loss: 0.319425
# Epoch 30/200 | Train Loss: 0.345906 | Test Loss: 0.294005
# Epoch 32/200 | Train Loss: 0.338004 | Test Loss: 0.282160
# Epoch 34/200 | Train Loss: 0.311750 | Test Loss: 0.255223
# Epoch 36/200 | Train Loss: 0.300077 | Test Loss: 0.249665
# Epoch 38/200 | Train Loss: 0.294460 | Test Loss: 0.250679
# Epoch 40/200 | Train Loss: 0.284451 | Test Loss: 0.255707
# Epoch 42/200 | Train Loss: 0.280654 | Test Loss: 0.227047
# Epoch 44/200 | Train Loss: 0.275875 | Test Loss: 0.239485
# Epoch 46/200 | Train Loss: 0.265129 | Test Loss: 0.224210
# Epoch 48/200 | Train Loss: 0.260896 | Test Loss: 0.221930
# Epoch 50/200 | Train Loss: 0.253608 | Test Loss: 0.221643
# Epoch 52/200 | Train Loss: 0.249952 | Test Loss: 0.203561
# Epoch 54/200 | Train Loss: 0.243535 | Test Loss: 0.202420
# Epoch 56/200 | Train Loss: 0.237180 | Test Loss: 0.195688
# Epoch 58/200 | Train Loss: 0.235603 | Test Loss: 0.186657
# Epoch 60/200 | Train Loss: 0.230015 | Test Loss: 0.204537
# Epoch 62/200 | Train Loss: 0.229052 | Test Loss: 0.187031
# Epoch 64/200 | Train Loss: 0.224761 | Test Loss: 0.187315
# Epoch 66/200 | Train Loss: 0.219440 | Test Loss: 0.187292
# Epoch 68/200 | Train Loss: 0.218397 | Test Loss: 0.180879
# Epoch 70/200 | Train Loss: 0.217675 | Test Loss: 0.177919
# Epoch 72/200 | Train Loss: 0.214804 | Test Loss: 0.183501
# Epoch 74/200 | Train Loss: 0.213732 | Test Loss: 0.183142
# Epoch 76/200 | Train Loss: 0.209664 | Test Loss: 0.179733
# Epoch 78/200 | Train Loss: 0.208704 | Test Loss: 0.175360
# Epoch 80/200 | Train Loss: 0.206828 | Test Loss: 0.173734
# Epoch 82/200 | Train Loss: 0.203323 | Test Loss: 0.174944
# Epoch 84/200 | Train Loss: 0.200621 | Test Loss: 0.174502
# Epoch 86/200 | Train Loss: 0.201068 | Test Loss: 0.177294
# Epoch 88/200 | Train Loss: 0.196042 | Test Loss: 0.173079
# Epoch 90/200 | Train Loss: 0.197804 | Test Loss: 0.165487
# Epoch 92/200 | Train Loss: 0.192557 | Test Loss: 0.163515
# Epoch 94/200 | Train Loss: 0.193867 | Test Loss: 0.161703
# Epoch 96/200 | Train Loss: 0.190792 | Test Loss: 0.158742
# Epoch 98/200 | Train Loss: 0.185919 | Test Loss: 0.162056
# Epoch 100/200 | Train Loss: 0.190753 | Test Loss: 0.161447
# Epoch 102/200 | Train Loss: 0.188724 | Test Loss: 0.153870
# Epoch 104/200 | Train Loss: 0.188166 | Test Loss: 0.158921
# Epoch 106/200 | Train Loss: 0.183953 | Test Loss: 0.154378
# Epoch 108/200 | Train Loss: 0.182657 | Test Loss: 0.154851
# Epoch 110/200 | Train Loss: 0.182011 | Test Loss: 0.159874
# Epoch 112/200 | Train Loss: 0.180555 | Test Loss: 0.153144
# Epoch 114/200 | Train Loss: 0.176994 | Test Loss: 0.147535
# Epoch 116/200 | Train Loss: 0.170745 | Test Loss: 0.151126
# Epoch 118/200 | Train Loss: 0.172730 | Test Loss: 0.146864
# Epoch 120/200 | Train Loss: 0.173383 | Test Loss: 0.145512
# Epoch 122/200 | Train Loss: 0.168898 | Test Loss: 0.142394
# Epoch 124/200 | Train Loss: 0.171541 | Test Loss: 0.139287
# Epoch 126/200 | Train Loss: 0.171135 | Test Loss: 0.142617
# Epoch 128/200 | Train Loss: 0.166904 | Test Loss: 0.136329
# Epoch 130/200 | Train Loss: 0.165382 | Test Loss: 0.141991
# Epoch 132/200 | Train Loss: 0.168735 | Test Loss: 0.138580
# Epoch 134/200 | Train Loss: 0.163031 | Test Loss: 0.137747
# Epoch 136/200 | Train Loss: 0.164608 | Test Loss: 0.140382
# Epoch 138/200 | Train Loss: 0.159492 | Test Loss: 0.141961
# Epoch 140/200 | Train Loss: 0.162697 | Test Loss: 0.142100
# Epoch 142/200 | Train Loss: 0.161963 | Test Loss: 0.134477
# Epoch 144/200 | Train Loss: 0.163437 | Test Loss: 0.138956
# Epoch 146/200 | Train Loss: 0.159373 | Test Loss: 0.137385
# Epoch 148/200 | Train Loss: 0.159153 | Test Loss: 0.140147
# Epoch 150/200 | Train Loss: 0.157489 | Test Loss: 0.130311
# Epoch 152/200 | Train Loss: 0.157642 | Test Loss: 0.134065
# Epoch 154/200 | Train Loss: 0.157145 | Test Loss: 0.137844
# Epoch 156/200 | Train Loss: 0.157482 | Test Loss: 0.141767
# Epoch 158/200 | Train Loss: 0.154838 | Test Loss: 0.135124
# Epoch 160/200 | Train Loss: 0.153634 | Test Loss: 0.138147
# Epoch 162/200 | Train Loss: 0.152974 | Test Loss: 0.132471
# Epoch 164/200 | Train Loss: 0.155884 | Test Loss: 0.128461
# Epoch 166/200 | Train Loss: 0.150874 | Test Loss: 0.139417
# Epoch 168/200 | Train Loss: 0.158778 | Test Loss: 0.129546
# Epoch 170/200 | Train Loss: 0.149181 | Test Loss: 0.129667
# Epoch 172/200 | Train Loss: 0.152748 | Test Loss: 0.128881
# Epoch 174/200 | Train Loss: 0.148864 | Test Loss: 0.134755
# Epoch 176/200 | Train Loss: 0.151117 | Test Loss: 0.142177
# Epoch 178/200 | Train Loss: 0.147730 | Test Loss: 0.135316
# Epoch 180/200 | Train Loss: 0.148388 | Test Loss: 0.132914
# Epoch 182/200 | Train Loss: 0.145512 | Test Loss: 0.128270
# Epoch 184/200 | Train Loss: 0.147381 | Test Loss: 0.126277
# Epoch 186/200 | Train Loss: 0.144732 | Test Loss: 0.130191
# Epoch 188/200 | Train Loss: 0.147013 | Test Loss: 0.133942
# Epoch 190/200 | Train Loss: 0.147736 | Test Loss: 0.129183
# Epoch 192/200 | Train Loss: 0.147083 | Test Loss: 0.132048
# Epoch 194/200 | Train Loss: 0.145407 | Test Loss: 0.129358
# Epoch 196/200 | Train Loss: 0.146549 | Test Loss: 0.127156
# Epoch 198/200 | Train Loss: 0.144426 | Test Loss: 0.128710
# Epoch 200/200 | Train Loss: 0.144120 | Test Loss: 0.125331
# Training Completed.
# Training took 68 min 30.5 sec.
# Best test loss: 0.120543 at epoch 199
#
# Training with output subset ratio = 0.4
# Epoch 2/200 | Train Loss: 2.252228 | Test Loss: 1.967304
# Epoch 4/200 | Train Loss: 1.179558 | Test Loss: 1.038125
# Epoch 6/200 | Train Loss: 0.949824 | Test Loss: 0.860902
# Epoch 8/200 | Train Loss: 0.781187 | Test Loss: 0.702522
# Epoch 10/200 | Train Loss: 0.669285 | Test Loss: 0.614325
# Epoch 12/200 | Train Loss: 0.583287 | Test Loss: 0.536492
# Epoch 14/200 | Train Loss: 0.521457 | Test Loss: 0.456147
# Epoch 16/200 | Train Loss: 0.471634 | Test Loss: 0.415072
# Epoch 18/200 | Train Loss: 0.425371 | Test Loss: 0.377871
# Epoch 20/200 | Train Loss: 0.396268 | Test Loss: 0.330169
# Epoch 22/200 | Train Loss: 0.373309 | Test Loss: 0.312976
# Epoch 24/200 | Train Loss: 0.345300 | Test Loss: 0.295672
# Epoch 26/200 | Train Loss: 0.333236 | Test Loss: 0.277677
# Epoch 28/200 | Train Loss: 0.318403 | Test Loss: 0.263929
# Epoch 30/200 | Train Loss: 0.305240 | Test Loss: 0.251946
# Epoch 32/200 | Train Loss: 0.291420 | Test Loss: 0.240199
# Epoch 34/200 | Train Loss: 0.282395 | Test Loss: 0.238945
# Epoch 36/200 | Train Loss: 0.278012 | Test Loss: 0.233927
# Epoch 38/200 | Train Loss: 0.266003 | Test Loss: 0.220017
# Epoch 40/200 | Train Loss: 0.263949 | Test Loss: 0.223955
# Epoch 42/200 | Train Loss: 0.252427 | Test Loss: 0.215571
# Epoch 44/200 | Train Loss: 0.248800 | Test Loss: 0.217208
# Epoch 46/200 | Train Loss: 0.242293 | Test Loss: 0.202794
# Epoch 48/200 | Train Loss: 0.237885 | Test Loss: 0.205293
# Epoch 50/200 | Train Loss: 0.232548 | Test Loss: 0.194025
# Epoch 52/200 | Train Loss: 0.226342 | Test Loss: 0.188599
# Epoch 54/200 | Train Loss: 0.225520 | Test Loss: 0.191776
# Epoch 56/200 | Train Loss: 0.220197 | Test Loss: 0.184736
# Epoch 58/200 | Train Loss: 0.218652 | Test Loss: 0.182582
# Epoch 60/200 | Train Loss: 0.213458 | Test Loss: 0.177187
# Epoch 62/200 | Train Loss: 0.212827 | Test Loss: 0.178721
# Epoch 64/200 | Train Loss: 0.210850 | Test Loss: 0.172556
# Epoch 66/200 | Train Loss: 0.206361 | Test Loss: 0.172323
# Epoch 68/200 | Train Loss: 0.203989 | Test Loss: 0.170411
# Epoch 70/200 | Train Loss: 0.202176 | Test Loss: 0.168578
# Epoch 72/200 | Train Loss: 0.200794 | Test Loss: 0.167298
# Epoch 74/200 | Train Loss: 0.196195 | Test Loss: 0.172396
# Epoch 76/200 | Train Loss: 0.197587 | Test Loss: 0.168233
# Epoch 78/200 | Train Loss: 0.190277 | Test Loss: 0.162856
# Epoch 80/200 | Train Loss: 0.192483 | Test Loss: 0.162902
# Epoch 82/200 | Train Loss: 0.188403 | Test Loss: 0.161825
# Epoch 84/200 | Train Loss: 0.191133 | Test Loss: 0.169646
# Epoch 86/200 | Train Loss: 0.188562 | Test Loss: 0.167070
# Epoch 88/200 | Train Loss: 0.186841 | Test Loss: 0.160501
# Epoch 90/200 | Train Loss: 0.184320 | Test Loss: 0.158261
# Epoch 92/200 | Train Loss: 0.185744 | Test Loss: 0.165318
# Epoch 94/200 | Train Loss: 0.181383 | Test Loss: 0.156914
# Epoch 96/200 | Train Loss: 0.182374 | Test Loss: 0.151659
# Epoch 98/200 | Train Loss: 0.181269 | Test Loss: 0.149428
# Epoch 100/200 | Train Loss: 0.179698 | Test Loss: 0.160532
# Epoch 102/200 | Train Loss: 0.178421 | Test Loss: 0.159247
# Epoch 104/200 | Train Loss: 0.176209 | Test Loss: 0.155072
# Epoch 106/200 | Train Loss: 0.175613 | Test Loss: 0.149710
# Epoch 108/200 | Train Loss: 0.174045 | Test Loss: 0.147436
# Epoch 110/200 | Train Loss: 0.174755 | Test Loss: 0.146971
# Epoch 112/200 | Train Loss: 0.169151 | Test Loss: 0.148666
# Epoch 114/200 | Train Loss: 0.175363 | Test Loss: 0.148507
# Epoch 116/200 | Train Loss: 0.170721 | Test Loss: 0.155023
# Epoch 118/200 | Train Loss: 0.172540 | Test Loss: 0.141191
# Epoch 120/200 | Train Loss: 0.170677 | Test Loss: 0.144096
# Epoch 122/200 | Train Loss: 0.168435 | Test Loss: 0.144962
# Epoch 124/200 | Train Loss: 0.167716 | Test Loss: 0.149308
# Epoch 126/200 | Train Loss: 0.169396 | Test Loss: 0.144820
# Epoch 128/200 | Train Loss: 0.165166 | Test Loss: 0.147907
# Epoch 130/200 | Train Loss: 0.164773 | Test Loss: 0.139337
# Epoch 132/200 | Train Loss: 0.166732 | Test Loss: 0.145283
# Epoch 134/200 | Train Loss: 0.165597 | Test Loss: 0.145661
# Epoch 136/200 | Train Loss: 0.164211 | Test Loss: 0.141653
# Epoch 138/200 | Train Loss: 0.161636 | Test Loss: 0.146263
# Epoch 140/200 | Train Loss: 0.163110 | Test Loss: 0.142006
# Epoch 142/200 | Train Loss: 0.162646 | Test Loss: 0.141536
# Epoch 144/200 | Train Loss: 0.163822 | Test Loss: 0.142491
# Epoch 146/200 | Train Loss: 0.163895 | Test Loss: 0.143783
# Epoch 148/200 | Train Loss: 0.159222 | Test Loss: 0.140098
# Epoch 150/200 | Train Loss: 0.159678 | Test Loss: 0.140560
# Epoch 152/200 | Train Loss: 0.156707 | Test Loss: 0.142144
# Epoch 154/200 | Train Loss: 0.159486 | Test Loss: 0.141655
# Epoch 156/200 | Train Loss: 0.159825 | Test Loss: 0.138584
# Epoch 158/200 | Train Loss: 0.158426 | Test Loss: 0.140402
# Epoch 160/200 | Train Loss: 0.153147 | Test Loss: 0.140730
# Epoch 162/200 | Train Loss: 0.158648 | Test Loss: 0.139044
# Epoch 164/200 | Train Loss: 0.155185 | Test Loss: 0.136006
# Epoch 166/200 | Train Loss: 0.155035 | Test Loss: 0.138511
# Epoch 168/200 | Train Loss: 0.158757 | Test Loss: 0.143432
# Epoch 170/200 | Train Loss: 0.155815 | Test Loss: 0.140948
# Epoch 172/200 | Train Loss: 0.154707 | Test Loss: 0.140665
# Epoch 174/200 | Train Loss: 0.154863 | Test Loss: 0.141341
# Epoch 176/200 | Train Loss: 0.154864 | Test Loss: 0.137534
# Epoch 178/200 | Train Loss: 0.152485 | Test Loss: 0.137839
# Epoch 180/200 | Train Loss: 0.151287 | Test Loss: 0.136160
# Epoch 182/200 | Train Loss: 0.151124 | Test Loss: 0.136632
# Epoch 184/200 | Train Loss: 0.149797 | Test Loss: 0.137955
# Epoch 186/200 | Train Loss: 0.150424 | Test Loss: 0.131218
# Epoch 188/200 | Train Loss: 0.151952 | Test Loss: 0.134782
# Epoch 190/200 | Train Loss: 0.151775 | Test Loss: 0.136492
# Epoch 192/200 | Train Loss: 0.148716 | Test Loss: 0.136196
# Epoch 194/200 | Train Loss: 0.150389 | Test Loss: 0.133324
# Epoch 196/200 | Train Loss: 0.149233 | Test Loss: 0.137283
# Epoch 198/200 | Train Loss: 0.150468 | Test Loss: 0.131250
# Epoch 200/200 | Train Loss: 0.150066 | Test Loss: 0.130337
# Training Completed.
# Training took 78 min 53.7 sec.
# Best test loss: 0.130337 at epoch 200
#
# Training with output subset ratio = 0.5
# Epoch 2/200 | Train Loss: 2.144902 | Test Loss: 1.782131
# Epoch 4/200 | Train Loss: 1.436131 | Test Loss: 1.245808
# Epoch 6/200 | Train Loss: 1.080540 | Test Loss: 0.968356
# Epoch 8/200 | Train Loss: 0.833472 | Test Loss: 0.721474
# Epoch 10/200 | Train Loss: 0.685888 | Test Loss: 0.591372
# Epoch 12/200 | Train Loss: 0.597987 | Test Loss: 0.532604
# Epoch 14/200 | Train Loss: 0.547232 | Test Loss: 0.480608
# Epoch 16/200 | Train Loss: 0.499899 | Test Loss: 0.422872
# Epoch 18/200 | Train Loss: 0.465338 | Test Loss: 0.394900
# Epoch 20/200 | Train Loss: 0.431708 | Test Loss: 0.368929
# Epoch 22/200 | Train Loss: 0.406593 | Test Loss: 0.348160
# Epoch 24/200 | Train Loss: 0.384286 | Test Loss: 0.316470
# Epoch 26/200 | Train Loss: 0.365280 | Test Loss: 0.305073
# Epoch 28/200 | Train Loss: 0.344702 | Test Loss: 0.284754
# Epoch 30/200 | Train Loss: 0.327141 | Test Loss: 0.270930
# Epoch 32/200 | Train Loss: 0.321131 | Test Loss: 0.266222
# Epoch 34/200 | Train Loss: 0.306088 | Test Loss: 0.245110
# Epoch 36/200 | Train Loss: 0.297029 | Test Loss: 0.241898
# Epoch 38/200 | Train Loss: 0.289185 | Test Loss: 0.242972
# Epoch 40/200 | Train Loss: 0.279058 | Test Loss: 0.232918
# Epoch 42/200 | Train Loss: 0.276876 | Test Loss: 0.228714
# Epoch 44/200 | Train Loss: 0.271849 | Test Loss: 0.222685
# Epoch 46/200 | Train Loss: 0.263595 | Test Loss: 0.219027
# Epoch 48/200 | Train Loss: 0.260870 | Test Loss: 0.216493
# Epoch 50/200 | Train Loss: 0.252585 | Test Loss: 0.216466
# Epoch 52/200 | Train Loss: 0.249844 | Test Loss: 0.209397
# Epoch 54/200 | Train Loss: 0.243116 | Test Loss: 0.206302
# Epoch 56/200 | Train Loss: 0.243227 | Test Loss: 0.202460
# Epoch 58/200 | Train Loss: 0.236195 | Test Loss: 0.205651
# Epoch 60/200 | Train Loss: 0.233265 | Test Loss: 0.191411
# Epoch 62/200 | Train Loss: 0.230094 | Test Loss: 0.189514
# Epoch 64/200 | Train Loss: 0.228700 | Test Loss: 0.185028
# Epoch 66/200 | Train Loss: 0.225124 | Test Loss: 0.187228
# Epoch 68/200 | Train Loss: 0.221414 | Test Loss: 0.189089
# Epoch 70/200 | Train Loss: 0.219558 | Test Loss: 0.185764
# Epoch 72/200 | Train Loss: 0.216689 | Test Loss: 0.189198
# Epoch 74/200 | Train Loss: 0.218415 | Test Loss: 0.178856
# Epoch 76/200 | Train Loss: 0.213078 | Test Loss: 0.179023
# Epoch 78/200 | Train Loss: 0.209884 | Test Loss: 0.174887
# Epoch 80/200 | Train Loss: 0.208127 | Test Loss: 0.177308
# Epoch 82/200 | Train Loss: 0.208576 | Test Loss: 0.183011
# Epoch 84/200 | Train Loss: 0.206254 | Test Loss: 0.174895
# Epoch 86/200 | Train Loss: 0.205203 | Test Loss: 0.173330
# Epoch 88/200 | Train Loss: 0.206629 | Test Loss: 0.172651
# Epoch 90/200 | Train Loss: 0.201243 | Test Loss: 0.170773
# Epoch 92/200 | Train Loss: 0.198279 | Test Loss: 0.169013
# Epoch 94/200 | Train Loss: 0.198302 | Test Loss: 0.168735
# Epoch 96/200 | Train Loss: 0.198571 | Test Loss: 0.164472
# Epoch 98/200 | Train Loss: 0.192742 | Test Loss: 0.173237
# Epoch 100/200 | Train Loss: 0.195889 | Test Loss: 0.163411
# Epoch 102/200 | Train Loss: 0.192159 | Test Loss: 0.167844
# Epoch 104/200 | Train Loss: 0.189136 | Test Loss: 0.160442
# Epoch 106/200 | Train Loss: 0.191811 | Test Loss: 0.164063
# Epoch 108/200 | Train Loss: 0.187991 | Test Loss: 0.160073
# Epoch 110/200 | Train Loss: 0.188685 | Test Loss: 0.161788
# Epoch 112/200 | Train Loss: 0.188446 | Test Loss: 0.161703
# Epoch 114/200 | Train Loss: 0.186847 | Test Loss: 0.165178
# Epoch 116/200 | Train Loss: 0.188338 | Test Loss: 0.164894
# Epoch 118/200 | Train Loss: 0.184796 | Test Loss: 0.162771
# Epoch 120/200 | Train Loss: 0.184879 | Test Loss: 0.160566
# Epoch 122/200 | Train Loss: 0.183114 | Test Loss: 0.155918
# Epoch 124/200 | Train Loss: 0.184007 | Test Loss: 0.160810
# Epoch 126/200 | Train Loss: 0.177886 | Test Loss: 0.158418
# Epoch 128/200 | Train Loss: 0.183734 | Test Loss: 0.160321
# Epoch 130/200 | Train Loss: 0.183821 | Test Loss: 0.154350
# Epoch 132/200 | Train Loss: 0.178065 | Test Loss: 0.152220
# Epoch 134/200 | Train Loss: 0.177571 | Test Loss: 0.156677
# Epoch 136/200 | Train Loss: 0.179262 | Test Loss: 0.158790
# Epoch 138/200 | Train Loss: 0.175052 | Test Loss: 0.159731
# Epoch 140/200 | Train Loss: 0.176386 | Test Loss: 0.160285
# Epoch 142/200 | Train Loss: 0.176777 | Test Loss: 0.156138
# Epoch 144/200 | Train Loss: 0.175674 | Test Loss: 0.154776
# Epoch 146/200 | Train Loss: 0.175945 | Test Loss: 0.154675
# Epoch 148/200 | Train Loss: 0.176251 | Test Loss: 0.151164
# Epoch 150/200 | Train Loss: 0.173919 | Test Loss: 0.153940
# Epoch 152/200 | Train Loss: 0.173835 | Test Loss: 0.154462
# Epoch 154/200 | Train Loss: 0.173744 | Test Loss: 0.159009
# Epoch 156/200 | Train Loss: 0.171628 | Test Loss: 0.150319
# Epoch 158/200 | Train Loss: 0.169119 | Test Loss: 0.151417
# Epoch 160/200 | Train Loss: 0.171860 | Test Loss: 0.150659
# Epoch 162/200 | Train Loss: 0.170534 | Test Loss: 0.150268
# Epoch 164/200 | Train Loss: 0.170394 | Test Loss: 0.151460
# Epoch 166/200 | Train Loss: 0.167642 | Test Loss: 0.146193
# Epoch 168/200 | Train Loss: 0.169139 | Test Loss: 0.148261
# Epoch 170/200 | Train Loss: 0.171788 | Test Loss: 0.148515
# Epoch 172/200 | Train Loss: 0.167253 | Test Loss: 0.152872
# Epoch 174/200 | Train Loss: 0.165577 | Test Loss: 0.152263
# Epoch 176/200 | Train Loss: 0.169762 | Test Loss: 0.148605
# Epoch 178/200 | Train Loss: 0.165064 | Test Loss: 0.150281
# Epoch 180/200 | Train Loss: 0.168490 | Test Loss: 0.147932
# Epoch 182/200 | Train Loss: 0.165076 | Test Loss: 0.153665
# Epoch 184/200 | Train Loss: 0.166638 | Test Loss: 0.150499
# Epoch 186/200 | Train Loss: 0.163630 | Test Loss: 0.146960
# Epoch 188/200 | Train Loss: 0.162779 | Test Loss: 0.148536
# Epoch 190/200 | Train Loss: 0.164521 | Test Loss: 0.143248
# Epoch 192/200 | Train Loss: 0.165203 | Test Loss: 0.147544
# Epoch 194/200 | Train Loss: 0.163768 | Test Loss: 0.147275
# Epoch 196/200 | Train Loss: 0.162951 | Test Loss: 0.143774
# Epoch 198/200 | Train Loss: 0.161261 | Test Loss: 0.145495
# Epoch 200/200 | Train Loss: 0.159682 | Test Loss: 0.148457
# Training Completed.
# Training took 88 min 39.4 sec.
# Best test loss: 0.142393 at epoch 193
#
# Training with output subset ratio = 0.6
# Epoch 2/200 | Train Loss: 1.852875 | Test Loss: 1.613283
# Epoch 4/200 | Train Loss: 1.263064 | Test Loss: 1.152480
# Epoch 6/200 | Train Loss: 0.981010 | Test Loss: 0.898405
# Epoch 8/200 | Train Loss: 0.796679 | Test Loss: 0.713429
# Epoch 10/200 | Train Loss: 0.688526 | Test Loss: 0.623030
# Epoch 12/200 | Train Loss: 0.601870 | Test Loss: 0.535986
# Epoch 14/200 | Train Loss: 0.530905 | Test Loss: 0.472212
# Epoch 16/200 | Train Loss: 0.467973 | Test Loss: 0.409650
# Epoch 18/200 | Train Loss: 0.419284 | Test Loss: 0.351180
# Epoch 20/200 | Train Loss: 0.389971 | Test Loss: 0.329402
# Epoch 22/200 | Train Loss: 0.370008 | Test Loss: 0.325577
# Epoch 24/200 | Train Loss: 0.347167 | Test Loss: 0.292663
# Epoch 26/200 | Train Loss: 0.333931 | Test Loss: 0.290757
# Epoch 28/200 | Train Loss: 0.320255 | Test Loss: 0.278383
# Epoch 30/200 | Train Loss: 0.313277 | Test Loss: 0.268735
# Epoch 32/200 | Train Loss: 0.304114 | Test Loss: 0.259628
# Epoch 34/200 | Train Loss: 0.296770 | Test Loss: 0.268817
# Epoch 36/200 | Train Loss: 0.287352 | Test Loss: 0.251632
# Epoch 38/200 | Train Loss: 0.282115 | Test Loss: 0.249669
# Epoch 40/200 | Train Loss: 0.273579 | Test Loss: 0.239230
# Epoch 42/200 | Train Loss: 0.270214 | Test Loss: 0.233915
# Epoch 44/200 | Train Loss: 0.263526 | Test Loss: 0.232011
# Epoch 46/200 | Train Loss: 0.259960 | Test Loss: 0.224292
# Epoch 48/200 | Train Loss: 0.254975 | Test Loss: 0.229190
# Epoch 50/200 | Train Loss: 0.253491 | Test Loss: 0.218227
# Epoch 52/200 | Train Loss: 0.249736 | Test Loss: 0.220190
# Epoch 54/200 | Train Loss: 0.242448 | Test Loss: 0.213091
# Epoch 56/200 | Train Loss: 0.239978 | Test Loss: 0.212579
# Epoch 58/200 | Train Loss: 0.237018 | Test Loss: 0.211424
# Epoch 60/200 | Train Loss: 0.232701 | Test Loss: 0.200151
# Epoch 62/200 | Train Loss: 0.233654 | Test Loss: 0.208453
# Epoch 64/200 | Train Loss: 0.229650 | Test Loss: 0.200087
# Epoch 66/200 | Train Loss: 0.227374 | Test Loss: 0.201963
# Epoch 68/200 | Train Loss: 0.225225 | Test Loss: 0.195352
# Epoch 70/200 | Train Loss: 0.221474 | Test Loss: 0.194949
# Epoch 72/200 | Train Loss: 0.220249 | Test Loss: 0.198287
# Epoch 74/200 | Train Loss: 0.216977 | Test Loss: 0.191953
# Epoch 76/200 | Train Loss: 0.216805 | Test Loss: 0.183946
# Epoch 78/200 | Train Loss: 0.217272 | Test Loss: 0.190487
# Epoch 80/200 | Train Loss: 0.213694 | Test Loss: 0.189935
# Epoch 82/200 | Train Loss: 0.213740 | Test Loss: 0.185144
# Epoch 84/200 | Train Loss: 0.208464 | Test Loss: 0.183735
# Epoch 86/200 | Train Loss: 0.208034 | Test Loss: 0.180965
# Epoch 88/200 | Train Loss: 0.206704 | Test Loss: 0.184587
# Epoch 90/200 | Train Loss: 0.203274 | Test Loss: 0.174967
# Epoch 92/200 | Train Loss: 0.203219 | Test Loss: 0.177339
# Epoch 94/200 | Train Loss: 0.198774 | Test Loss: 0.178396
# Epoch 96/200 | Train Loss: 0.202573 | Test Loss: 0.176243
# Epoch 98/200 | Train Loss: 0.198291 | Test Loss: 0.170888
# Epoch 100/200 | Train Loss: 0.199457 | Test Loss: 0.172548
# Epoch 102/200 | Train Loss: 0.196110 | Test Loss: 0.168486
# Epoch 104/200 | Train Loss: 0.192670 | Test Loss: 0.173144
# Epoch 106/200 | Train Loss: 0.193281 | Test Loss: 0.169829
# Epoch 108/200 | Train Loss: 0.191091 | Test Loss: 0.175026
# Epoch 110/200 | Train Loss: 0.191399 | Test Loss: 0.172872
# Epoch 112/200 | Train Loss: 0.190104 | Test Loss: 0.168980
# Epoch 114/200 | Train Loss: 0.187435 | Test Loss: 0.174095
# Epoch 116/200 | Train Loss: 0.185621 | Test Loss: 0.167323
# Epoch 118/200 | Train Loss: 0.187347 | Test Loss: 0.171602
# Epoch 120/200 | Train Loss: 0.186170 | Test Loss: 0.168771
# Epoch 122/200 | Train Loss: 0.185529 | Test Loss: 0.167779
# Epoch 124/200 | Train Loss: 0.185803 | Test Loss: 0.162669
# Epoch 126/200 | Train Loss: 0.186412 | Test Loss: 0.165047
# Epoch 128/200 | Train Loss: 0.183317 | Test Loss: 0.158452
# Epoch 130/200 | Train Loss: 0.186219 | Test Loss: 0.160481
# Epoch 132/200 | Train Loss: 0.182106 | Test Loss: 0.170237
# Epoch 134/200 | Train Loss: 0.180758 | Test Loss: 0.163822
# Epoch 136/200 | Train Loss: 0.181189 | Test Loss: 0.161555
# Epoch 138/200 | Train Loss: 0.180415 | Test Loss: 0.161653
# Epoch 140/200 | Train Loss: 0.178559 | Test Loss: 0.166782
# Epoch 142/200 | Train Loss: 0.178218 | Test Loss: 0.164808
# Epoch 144/200 | Train Loss: 0.178757 | Test Loss: 0.161966
# Epoch 146/200 | Train Loss: 0.178993 | Test Loss: 0.164570
# Epoch 148/200 | Train Loss: 0.176529 | Test Loss: 0.156950
# Epoch 150/200 | Train Loss: 0.177016 | Test Loss: 0.160485
# Epoch 152/200 | Train Loss: 0.175676 | Test Loss: 0.158830
# Epoch 154/200 | Train Loss: 0.175089 | Test Loss: 0.158126
# Epoch 156/200 | Train Loss: 0.175588 | Test Loss: 0.158342
# Epoch 158/200 | Train Loss: 0.174934 | Test Loss: 0.154580
# Epoch 160/200 | Train Loss: 0.173619 | Test Loss: 0.157197
# Epoch 162/200 | Train Loss: 0.173559 | Test Loss: 0.158470
# Epoch 164/200 | Train Loss: 0.174570 | Test Loss: 0.157823
# Epoch 166/200 | Train Loss: 0.172226 | Test Loss: 0.154010
# Epoch 168/200 | Train Loss: 0.172352 | Test Loss: 0.154883
# Epoch 170/200 | Train Loss: 0.173291 | Test Loss: 0.156702
# Epoch 172/200 | Train Loss: 0.170921 | Test Loss: 0.152714
# Epoch 174/200 | Train Loss: 0.170336 | Test Loss: 0.155552
# Epoch 176/200 | Train Loss: 0.171988 | Test Loss: 0.152766
# Epoch 178/200 | Train Loss: 0.168897 | Test Loss: 0.154446
# Epoch 180/200 | Train Loss: 0.168779 | Test Loss: 0.154339
# Epoch 182/200 | Train Loss: 0.170833 | Test Loss: 0.150729
# Epoch 184/200 | Train Loss: 0.168649 | Test Loss: 0.157968
# Epoch 186/200 | Train Loss: 0.168615 | Test Loss: 0.152880
# Epoch 188/200 | Train Loss: 0.166215 | Test Loss: 0.150331
# Epoch 190/200 | Train Loss: 0.166359 | Test Loss: 0.152295
# Epoch 192/200 | Train Loss: 0.166718 | Test Loss: 0.155034
# Epoch 194/200 | Train Loss: 0.166601 | Test Loss: 0.151600
# Epoch 196/200 | Train Loss: 0.165057 | Test Loss: 0.155122
# Epoch 198/200 | Train Loss: 0.165718 | Test Loss: 0.151768
# Epoch 200/200 | Train Loss: 0.167879 | Test Loss: 0.152070
# Training Completed.
# Training took 101 min 56.1 sec.
# Best test loss: 0.149192 at epoch 197
#
# Training with output subset ratio = 0.7
# Epoch 2/200 | Train Loss: 1.910638 | Test Loss: 1.632519
# Epoch 4/200 | Train Loss: 1.261091 | Test Loss: 1.168123
# Epoch 6/200 | Train Loss: 1.028923 | Test Loss: 0.925874
# Epoch 8/200 | Train Loss: 0.820955 | Test Loss: 0.786693
# Epoch 10/200 | Train Loss: 0.710249 | Test Loss: 0.629049
# Epoch 12/200 | Train Loss: 0.618543 | Test Loss: 0.549291
# Epoch 14/200 | Train Loss: 0.551225 | Test Loss: 0.497486
# Epoch 16/200 | Train Loss: 0.505034 | Test Loss: 0.481826
# Epoch 18/200 | Train Loss: 0.467023 | Test Loss: 0.416125
# Epoch 20/200 | Train Loss: 0.437386 | Test Loss: 0.371893
# Epoch 22/200 | Train Loss: 0.415509 | Test Loss: 0.370253
# Epoch 24/200 | Train Loss: 0.398383 | Test Loss: 0.343413
# Epoch 26/200 | Train Loss: 0.383487 | Test Loss: 0.327802
# Epoch 28/200 | Train Loss: 0.371442 | Test Loss: 0.315440
# Epoch 30/200 | Train Loss: 0.358289 | Test Loss: 0.303008
# Epoch 32/200 | Train Loss: 0.349949 | Test Loss: 0.301793
# Epoch 34/200 | Train Loss: 0.340688 | Test Loss: 0.290628
# Epoch 36/200 | Train Loss: 0.332734 | Test Loss: 0.290781
# Epoch 38/200 | Train Loss: 0.323247 | Test Loss: 0.271454
# Epoch 40/200 | Train Loss: 0.317657 | Test Loss: 0.278813
# Epoch 42/200 | Train Loss: 0.312642 | Test Loss: 0.269537
# Epoch 44/200 | Train Loss: 0.307021 | Test Loss: 0.273133
# Epoch 46/200 | Train Loss: 0.301387 | Test Loss: 0.262172
# Epoch 48/200 | Train Loss: 0.292180 | Test Loss: 0.256148
# Epoch 50/200 | Train Loss: 0.291561 | Test Loss: 0.251150
# Epoch 52/200 | Train Loss: 0.288109 | Test Loss: 0.245989
# Epoch 54/200 | Train Loss: 0.282121 | Test Loss: 0.241996
# Epoch 56/200 | Train Loss: 0.277335 | Test Loss: 0.238558
# Epoch 58/200 | Train Loss: 0.272698 | Test Loss: 0.235509
# Epoch 60/200 | Train Loss: 0.270729 | Test Loss: 0.234538
# Epoch 62/200 | Train Loss: 0.266736 | Test Loss: 0.225733
# Epoch 64/200 | Train Loss: 0.264089 | Test Loss: 0.227920
# Epoch 66/200 | Train Loss: 0.261366 | Test Loss: 0.227822
# Epoch 68/200 | Train Loss: 0.256691 | Test Loss: 0.221420
# Epoch 70/200 | Train Loss: 0.253370 | Test Loss: 0.217767
# Epoch 72/200 | Train Loss: 0.251648 | Test Loss: 0.214392
# Epoch 74/200 | Train Loss: 0.245751 | Test Loss: 0.220875
# Epoch 76/200 | Train Loss: 0.245078 | Test Loss: 0.208912
# Epoch 78/200 | Train Loss: 0.242895 | Test Loss: 0.214834
# Epoch 80/200 | Train Loss: 0.239698 | Test Loss: 0.217075
# Epoch 82/200 | Train Loss: 0.239046 | Test Loss: 0.206880
# Epoch 84/200 | Train Loss: 0.233695 | Test Loss: 0.201255
# Epoch 86/200 | Train Loss: 0.231806 | Test Loss: 0.199548
# Epoch 88/200 | Train Loss: 0.228521 | Test Loss: 0.199728
# Epoch 90/200 | Train Loss: 0.227146 | Test Loss: 0.197732
# Epoch 92/200 | Train Loss: 0.224278 | Test Loss: 0.194930
# Epoch 94/200 | Train Loss: 0.221727 | Test Loss: 0.197465
# Epoch 96/200 | Train Loss: 0.220608 | Test Loss: 0.194539
# Epoch 98/200 | Train Loss: 0.219490 | Test Loss: 0.188958
# Epoch 100/200 | Train Loss: 0.217732 | Test Loss: 0.189990
# Epoch 102/200 | Train Loss: 0.215258 | Test Loss: 0.189384
# Epoch 104/200 | Train Loss: 0.214196 | Test Loss: 0.184014
# Epoch 106/200 | Train Loss: 0.214179 | Test Loss: 0.185103
# Epoch 108/200 | Train Loss: 0.211013 | Test Loss: 0.182753
# Epoch 110/200 | Train Loss: 0.209875 | Test Loss: 0.187011
# Epoch 112/200 | Train Loss: 0.207191 | Test Loss: 0.185156
# Epoch 114/200 | Train Loss: 0.208168 | Test Loss: 0.182881
# Epoch 116/200 | Train Loss: 0.205647 | Test Loss: 0.179173
# Epoch 118/200 | Train Loss: 0.204224 | Test Loss: 0.176778
# Epoch 120/200 | Train Loss: 0.203573 | Test Loss: 0.183500
# Epoch 122/200 | Train Loss: 0.203761 | Test Loss: 0.182091
# Epoch 124/200 | Train Loss: 0.201801 | Test Loss: 0.176101
# Epoch 126/200 | Train Loss: 0.201008 | Test Loss: 0.177147
# Epoch 128/200 | Train Loss: 0.200335 | Test Loss: 0.176174
# Epoch 130/200 | Train Loss: 0.200146 | Test Loss: 0.180998
# Epoch 132/200 | Train Loss: 0.196650 | Test Loss: 0.179079
# Epoch 134/200 | Train Loss: 0.196670 | Test Loss: 0.171048
# Epoch 136/200 | Train Loss: 0.194509 | Test Loss: 0.177105
# Epoch 138/200 | Train Loss: 0.195902 | Test Loss: 0.175372
# Epoch 140/200 | Train Loss: 0.194131 | Test Loss: 0.174094
# Epoch 142/200 | Train Loss: 0.194625 | Test Loss: 0.170615
# Epoch 144/200 | Train Loss: 0.193756 | Test Loss: 0.168378
# Epoch 146/200 | Train Loss: 0.191860 | Test Loss: 0.171862
# Epoch 148/200 | Train Loss: 0.193293 | Test Loss: 0.170952
# Epoch 150/200 | Train Loss: 0.192291 | Test Loss: 0.171278
# Epoch 152/200 | Train Loss: 0.190455 | Test Loss: 0.172037
# Epoch 154/200 | Train Loss: 0.188575 | Test Loss: 0.169760
# Epoch 156/200 | Train Loss: 0.186188 | Test Loss: 0.172039
# Epoch 158/200 | Train Loss: 0.187793 | Test Loss: 0.169260
# Epoch 160/200 | Train Loss: 0.187948 | Test Loss: 0.169585
# Epoch 162/200 | Train Loss: 0.187658 | Test Loss: 0.163755
# Epoch 164/200 | Train Loss: 0.186656 | Test Loss: 0.170315
# Epoch 166/200 | Train Loss: 0.184353 | Test Loss: 0.165864
# Epoch 168/200 | Train Loss: 0.185604 | Test Loss: 0.166994
# Epoch 170/200 | Train Loss: 0.182556 | Test Loss: 0.165553
# Epoch 172/200 | Train Loss: 0.185475 | Test Loss: 0.164206
# Epoch 174/200 | Train Loss: 0.182711 | Test Loss: 0.164708
# Epoch 176/200 | Train Loss: 0.181921 | Test Loss: 0.162400
# Epoch 178/200 | Train Loss: 0.180978 | Test Loss: 0.162689
# Epoch 180/200 | Train Loss: 0.180705 | Test Loss: 0.162871
# Epoch 182/200 | Train Loss: 0.180045 | Test Loss: 0.159362
# Epoch 184/200 | Train Loss: 0.181163 | Test Loss: 0.162921
# Epoch 186/200 | Train Loss: 0.179408 | Test Loss: 0.162912
# Epoch 188/200 | Train Loss: 0.177717 | Test Loss: 0.165039
# Epoch 190/200 | Train Loss: 0.175921 | Test Loss: 0.163555
# Epoch 192/200 | Train Loss: 0.179715 | Test Loss: 0.162052
# Epoch 194/200 | Train Loss: 0.177344 | Test Loss: 0.162641
# Epoch 196/200 | Train Loss: 0.175909 | Test Loss: 0.166156
# Epoch 198/200 | Train Loss: 0.178416 | Test Loss: 0.162375
# Epoch 200/200 | Train Loss: 0.175762 | Test Loss: 0.158571
# Training Completed.
# Training took 113 min 44.1 sec.
# Best test loss: 0.158571 at epoch 200
#
# Training with output subset ratio = 0.8
# Epoch 2/200 | Train Loss: 2.519744 | Test Loss: 2.156850
# Epoch 4/200 | Train Loss: 1.812387 | Test Loss: 1.711257
# Epoch 6/200 | Train Loss: 1.511773 | Test Loss: 1.409981
# Epoch 8/200 | Train Loss: 1.259653 | Test Loss: 1.156010
# Epoch 10/200 | Train Loss: 1.053471 | Test Loss: 0.948415
# Epoch 12/200 | Train Loss: 0.891689 | Test Loss: 0.798585
# Epoch 14/200 | Train Loss: 0.767555 | Test Loss: 0.677608
# Epoch 16/200 | Train Loss: 0.686316 | Test Loss: 0.586085
# Epoch 18/200 | Train Loss: 0.623257 | Test Loss: 0.551996
# Epoch 20/200 | Train Loss: 0.573906 | Test Loss: 0.501147
# Epoch 22/200 | Train Loss: 0.534813 | Test Loss: 0.464857
# Epoch 24/200 | Train Loss: 0.497593 | Test Loss: 0.423914
# Epoch 26/200 | Train Loss: 0.463116 | Test Loss: 0.395847
# Epoch 28/200 | Train Loss: 0.437992 | Test Loss: 0.375088
# Epoch 30/200 | Train Loss: 0.419649 | Test Loss: 0.351984
# Epoch 32/200 | Train Loss: 0.399031 | Test Loss: 0.339592
# Epoch 34/200 | Train Loss: 0.385704 | Test Loss: 0.330555
# Epoch 36/200 | Train Loss: 0.370765 | Test Loss: 0.321329
# Epoch 38/200 | Train Loss: 0.358782 | Test Loss: 0.309202
# Epoch 40/200 | Train Loss: 0.348305 | Test Loss: 0.292470
# Epoch 42/200 | Train Loss: 0.336931 | Test Loss: 0.284770
# Epoch 44/200 | Train Loss: 0.328347 | Test Loss: 0.280535
# Epoch 46/200 | Train Loss: 0.320145 | Test Loss: 0.274896
# Epoch 48/200 | Train Loss: 0.312071 | Test Loss: 0.267854
# Epoch 50/200 | Train Loss: 0.308454 | Test Loss: 0.263349
# Epoch 52/200 | Train Loss: 0.299638 | Test Loss: 0.257729
# Epoch 54/200 | Train Loss: 0.295116 | Test Loss: 0.249336
# Epoch 56/200 | Train Loss: 0.288063 | Test Loss: 0.248329
# Epoch 58/200 | Train Loss: 0.282996 | Test Loss: 0.245309
# Epoch 60/200 | Train Loss: 0.278704 | Test Loss: 0.244057
# Epoch 62/200 | Train Loss: 0.274240 | Test Loss: 0.237322
# Epoch 64/200 | Train Loss: 0.271688 | Test Loss: 0.230914
# Epoch 66/200 | Train Loss: 0.266727 | Test Loss: 0.232670
# Epoch 68/200 | Train Loss: 0.262356 | Test Loss: 0.233955
# Epoch 70/200 | Train Loss: 0.257135 | Test Loss: 0.224525
# Epoch 72/200 | Train Loss: 0.253750 | Test Loss: 0.220121
# Epoch 74/200 | Train Loss: 0.248190 | Test Loss: 0.218000
# Epoch 76/200 | Train Loss: 0.244884 | Test Loss: 0.209777
# Epoch 78/200 | Train Loss: 0.243147 | Test Loss: 0.214470
# Epoch 80/200 | Train Loss: 0.238835 | Test Loss: 0.207287
# Epoch 82/200 | Train Loss: 0.236828 | Test Loss: 0.212196
# Epoch 84/200 | Train Loss: 0.236426 | Test Loss: 0.200671
# Epoch 86/200 | Train Loss: 0.232100 | Test Loss: 0.202451
# Epoch 88/200 | Train Loss: 0.229888 | Test Loss: 0.198053
# Epoch 90/200 | Train Loss: 0.226619 | Test Loss: 0.200365
# Epoch 92/200 | Train Loss: 0.225089 | Test Loss: 0.217680
# Epoch 94/200 | Train Loss: 0.223847 | Test Loss: 0.193418
# Epoch 96/200 | Train Loss: 0.223936 | Test Loss: 0.194081
# Epoch 98/200 | Train Loss: 0.220363 | Test Loss: 0.188579
# Epoch 100/200 | Train Loss: 0.217939 | Test Loss: 0.188280
# Epoch 102/200 | Train Loss: 0.215181 | Test Loss: 0.190943
# Epoch 104/200 | Train Loss: 0.213541 | Test Loss: 0.183259
# Epoch 106/200 | Train Loss: 0.212952 | Test Loss: 0.187679
# Epoch 108/200 | Train Loss: 0.210498 | Test Loss: 0.181135
# Epoch 110/200 | Train Loss: 0.210612 | Test Loss: 0.184773
# Epoch 112/200 | Train Loss: 0.207477 | Test Loss: 0.189746
# Epoch 114/200 | Train Loss: 0.206956 | Test Loss: 0.184947
# Epoch 116/200 | Train Loss: 0.207928 | Test Loss: 0.182097
# Epoch 118/200 | Train Loss: 0.206234 | Test Loss: 0.183840
# Epoch 120/200 | Train Loss: 0.204501 | Test Loss: 0.181007
# Epoch 122/200 | Train Loss: 0.203100 | Test Loss: 0.183972
# Epoch 124/200 | Train Loss: 0.202755 | Test Loss: 0.178523
# Epoch 126/200 | Train Loss: 0.200026 | Test Loss: 0.181682
# Epoch 128/200 | Train Loss: 0.200407 | Test Loss: 0.180993
# Epoch 130/200 | Train Loss: 0.198980 | Test Loss: 0.181391
# Epoch 132/200 | Train Loss: 0.200110 | Test Loss: 0.175410
# Epoch 134/200 | Train Loss: 0.199663 | Test Loss: 0.172276
# Epoch 136/200 | Train Loss: 0.198686 | Test Loss: 0.177429
# Epoch 138/200 | Train Loss: 0.196394 | Test Loss: 0.180433
# Epoch 140/200 | Train Loss: 0.196553 | Test Loss: 0.178796
# Epoch 142/200 | Train Loss: 0.194503 | Test Loss: 0.174626
# Epoch 144/200 | Train Loss: 0.192180 | Test Loss: 0.175936
# Epoch 146/200 | Train Loss: 0.192623 | Test Loss: 0.172534
# Epoch 148/200 | Train Loss: 0.192132 | Test Loss: 0.172583
# Epoch 150/200 | Train Loss: 0.192903 | Test Loss: 0.173853
# Epoch 152/200 | Train Loss: 0.191594 | Test Loss: 0.171194
# Epoch 154/200 | Train Loss: 0.191029 | Test Loss: 0.173581
# Epoch 156/200 | Train Loss: 0.191187 | Test Loss: 0.168568
# Epoch 158/200 | Train Loss: 0.190145 | Test Loss: 0.168857
# Epoch 160/200 | Train Loss: 0.190162 | Test Loss: 0.172446
# Epoch 162/200 | Train Loss: 0.188624 | Test Loss: 0.167840
# Epoch 164/200 | Train Loss: 0.187498 | Test Loss: 0.168960
# Epoch 166/200 | Train Loss: 0.188325 | Test Loss: 0.169603
# Epoch 168/200 | Train Loss: 0.188297 | Test Loss: 0.169671
# Epoch 170/200 | Train Loss: 0.186984 | Test Loss: 0.173640
# Epoch 172/200 | Train Loss: 0.185667 | Test Loss: 0.168724
# Epoch 174/200 | Train Loss: 0.186826 | Test Loss: 0.170804
# Epoch 176/200 | Train Loss: 0.186161 | Test Loss: 0.169946
# Epoch 178/200 | Train Loss: 0.184119 | Test Loss: 0.167815
# Epoch 180/200 | Train Loss: 0.182978 | Test Loss: 0.167425
# Epoch 182/200 | Train Loss: 0.183932 | Test Loss: 0.170097
# Epoch 184/200 | Train Loss: 0.183677 | Test Loss: 0.170088
# Epoch 186/200 | Train Loss: 0.182665 | Test Loss: 0.164514
# Epoch 188/200 | Train Loss: 0.182456 | Test Loss: 0.172426
# Epoch 190/200 | Train Loss: 0.182629 | Test Loss: 0.164727
# Epoch 192/200 | Train Loss: 0.181671 | Test Loss: 0.167210
# Epoch 194/200 | Train Loss: 0.179969 | Test Loss: 0.165197
# Epoch 196/200 | Train Loss: 0.180448 | Test Loss: 0.165657
# Epoch 198/200 | Train Loss: 0.179172 | Test Loss: 0.161852
# Epoch 200/200 | Train Loss: 0.180788 | Test Loss: 0.165764
# Training Completed.
# Training took 130 min 18.4 sec.
# Best test loss: 0.161852 at epoch 198
#
# Training with output subset ratio = 0.9
# Epoch 2/200 | Train Loss: 2.520566 | Test Loss: 2.016534
# Epoch 4/200 | Train Loss: 1.616589 | Test Loss: 1.513263
# Epoch 6/200 | Train Loss: 1.227432 | Test Loss: 1.087796
# Epoch 8/200 | Train Loss: 1.005959 | Test Loss: 0.883869
# Epoch 10/200 | Train Loss: 0.840297 | Test Loss: 0.755502
# Epoch 12/200 | Train Loss: 0.742593 | Test Loss: 0.665586
# Epoch 14/200 | Train Loss: 0.666365 | Test Loss: 0.623989
# Epoch 16/200 | Train Loss: 0.604210 | Test Loss: 0.521809
# Epoch 18/200 | Train Loss: 0.555527 | Test Loss: 0.491467
# Epoch 20/200 | Train Loss: 0.503687 | Test Loss: 0.425852
# Epoch 22/200 | Train Loss: 0.467574 | Test Loss: 0.403650
# Epoch 24/200 | Train Loss: 0.447023 | Test Loss: 0.380559
# Epoch 26/200 | Train Loss: 0.418010 | Test Loss: 0.357385
# Epoch 28/200 | Train Loss: 0.401671 | Test Loss: 0.349209
# Epoch 30/200 | Train Loss: 0.385992 | Test Loss: 0.329108
# Epoch 32/200 | Train Loss: 0.375095 | Test Loss: 0.319580
# Epoch 34/200 | Train Loss: 0.358585 | Test Loss: 0.308644
# Epoch 36/200 | Train Loss: 0.347467 | Test Loss: 0.309387
# Epoch 38/200 | Train Loss: 0.338895 | Test Loss: 0.296774
# Epoch 40/200 | Train Loss: 0.331532 | Test Loss: 0.282044
# Epoch 42/200 | Train Loss: 0.320951 | Test Loss: 0.276190
# Epoch 44/200 | Train Loss: 0.317282 | Test Loss: 0.271872
# Epoch 46/200 | Train Loss: 0.312294 | Test Loss: 0.267237
# Epoch 48/200 | Train Loss: 0.306195 | Test Loss: 0.265133
# Epoch 50/200 | Train Loss: 0.300037 | Test Loss: 0.260931
# Epoch 52/200 | Train Loss: 0.296764 | Test Loss: 0.265196
# Epoch 54/200 | Train Loss: 0.292653 | Test Loss: 0.251042
# Epoch 56/200 | Train Loss: 0.285897 | Test Loss: 0.251789
# Epoch 58/200 | Train Loss: 0.284166 | Test Loss: 0.247986
# Epoch 60/200 | Train Loss: 0.279781 | Test Loss: 0.240817
# Epoch 62/200 | Train Loss: 0.274576 | Test Loss: 0.244851
# Epoch 64/200 | Train Loss: 0.270354 | Test Loss: 0.235372
# Epoch 66/200 | Train Loss: 0.266115 | Test Loss: 0.233897
# Epoch 68/200 | Train Loss: 0.263462 | Test Loss: 0.231108
# Epoch 70/200 | Train Loss: 0.260105 | Test Loss: 0.229935
# Epoch 72/200 | Train Loss: 0.257876 | Test Loss: 0.226514
# Epoch 74/200 | Train Loss: 0.254401 | Test Loss: 0.223378
# Epoch 76/200 | Train Loss: 0.251438 | Test Loss: 0.216012
# Epoch 78/200 | Train Loss: 0.249551 | Test Loss: 0.219468
# Epoch 80/200 | Train Loss: 0.246096 | Test Loss: 0.222099
# Epoch 82/200 | Train Loss: 0.242287 | Test Loss: 0.213432
# Epoch 84/200 | Train Loss: 0.239937 | Test Loss: 0.217284
# Epoch 86/200 | Train Loss: 0.238817 | Test Loss: 0.204440
# Epoch 88/200 | Train Loss: 0.235468 | Test Loss: 0.212912
# Epoch 90/200 | Train Loss: 0.233739 | Test Loss: 0.206579
# Epoch 92/200 | Train Loss: 0.230538 | Test Loss: 0.198460
# Epoch 94/200 | Train Loss: 0.228857 | Test Loss: 0.201580
# Epoch 96/200 | Train Loss: 0.225641 | Test Loss: 0.201285
# Epoch 98/200 | Train Loss: 0.224338 | Test Loss: 0.194992
# Epoch 100/200 | Train Loss: 0.220142 | Test Loss: 0.195634
# Epoch 102/200 | Train Loss: 0.218961 | Test Loss: 0.194662
# Epoch 104/200 | Train Loss: 0.217228 | Test Loss: 0.194365
# Epoch 106/200 | Train Loss: 0.216361 | Test Loss: 0.190119
# Epoch 108/200 | Train Loss: 0.214823 | Test Loss: 0.190656
# Epoch 110/200 | Train Loss: 0.213699 | Test Loss: 0.187626
# Epoch 112/200 | Train Loss: 0.211463 | Test Loss: 0.186628
# Epoch 114/200 | Train Loss: 0.210735 | Test Loss: 0.184659
# Epoch 116/200 | Train Loss: 0.209478 | Test Loss: 0.189762
# Epoch 118/200 | Train Loss: 0.209282 | Test Loss: 0.186196
# Epoch 120/200 | Train Loss: 0.207082 | Test Loss: 0.183335
# Epoch 122/200 | Train Loss: 0.204999 | Test Loss: 0.188095
# Epoch 124/200 | Train Loss: 0.204822 | Test Loss: 0.182308
# Epoch 126/200 | Train Loss: 0.203717 | Test Loss: 0.187329
# Epoch 128/200 | Train Loss: 0.203779 | Test Loss: 0.185680
# Epoch 130/200 | Train Loss: 0.201559 | Test Loss: 0.179105
# Epoch 132/200 | Train Loss: 0.201953 | Test Loss: 0.182647
# Epoch 134/200 | Train Loss: 0.201648 | Test Loss: 0.181127
# Epoch 136/200 | Train Loss: 0.199222 | Test Loss: 0.180256
# Epoch 138/200 | Train Loss: 0.199044 | Test Loss: 0.178644
# Epoch 140/200 | Train Loss: 0.198916 | Test Loss: 0.178102
# Epoch 142/200 | Train Loss: 0.197132 | Test Loss: 0.181887
# Epoch 144/200 | Train Loss: 0.196875 | Test Loss: 0.173993
# Epoch 146/200 | Train Loss: 0.195441 | Test Loss: 0.177217
# Epoch 148/200 | Train Loss: 0.196781 | Test Loss: 0.178398
# Epoch 150/200 | Train Loss: 0.194931 | Test Loss: 0.178532
# Epoch 152/200 | Train Loss: 0.193469 | Test Loss: 0.177287
# Epoch 154/200 | Train Loss: 0.191742 | Test Loss: 0.175848
# Epoch 156/200 | Train Loss: 0.192715 | Test Loss: 0.169614
# Epoch 158/200 | Train Loss: 0.191026 | Test Loss: 0.172472
# Epoch 160/200 | Train Loss: 0.191882 | Test Loss: 0.175669
# Epoch 162/200 | Train Loss: 0.191388 | Test Loss: 0.171588
# Epoch 164/200 | Train Loss: 0.189445 | Test Loss: 0.173745
# Epoch 166/200 | Train Loss: 0.190904 | Test Loss: 0.169098
# Epoch 168/200 | Train Loss: 0.187955 | Test Loss: 0.169271
# Epoch 170/200 | Train Loss: 0.188299 | Test Loss: 0.173688
# Epoch 172/200 | Train Loss: 0.187823 | Test Loss: 0.169981
# Epoch 174/200 | Train Loss: 0.187136 | Test Loss: 0.170185
# Epoch 176/200 | Train Loss: 0.186645 | Test Loss: 0.170531
# Epoch 178/200 | Train Loss: 0.186068 | Test Loss: 0.171197
# Epoch 180/200 | Train Loss: 0.185152 | Test Loss: 0.172551
# Epoch 182/200 | Train Loss: 0.184766 | Test Loss: 0.177765
# Epoch 184/200 | Train Loss: 0.184231 | Test Loss: 0.168896
# Epoch 186/200 | Train Loss: 0.185529 | Test Loss: 0.170323
# Epoch 188/200 | Train Loss: 0.183734 | Test Loss: 0.171026
# Epoch 190/200 | Train Loss: 0.182899 | Test Loss: 0.171027
# Epoch 192/200 | Train Loss: 0.182518 | Test Loss: 0.169476
# Epoch 194/200 | Train Loss: 0.182653 | Test Loss: 0.165858
# Epoch 196/200 | Train Loss: 0.183433 | Test Loss: 0.170391
# Epoch 198/200 | Train Loss: 0.181408 | Test Loss: 0.167605
# Epoch 200/200 | Train Loss: 0.181049 | Test Loss: 0.168033
# Training Completed.
# Training took 140 min 59.4 sec.
# Best test loss: 0.165858 at epoch 194
#
# Training with output subset ratio = 1.0
# Epoch 2/200 | Train Loss: 2.001669 | Test Loss: 1.685435
# Epoch 4/200 | Train Loss: 1.309597 | Test Loss: 1.189871
# Epoch 6/200 | Train Loss: 1.000588 | Test Loss: 0.872508
# Epoch 8/200 | Train Loss: 0.821884 | Test Loss: 0.723524
# Epoch 10/200 | Train Loss: 0.694257 | Test Loss: 0.591305
# Epoch 12/200 | Train Loss: 0.594917 | Test Loss: 0.499401
# Epoch 14/200 | Train Loss: 0.521801 | Test Loss: 0.428235
# Epoch 16/200 | Train Loss: 0.473721 | Test Loss: 0.393512
# Epoch 18/200 | Train Loss: 0.437687 | Test Loss: 0.359280
# Epoch 20/200 | Train Loss: 0.407403 | Test Loss: 0.331963
# Epoch 22/200 | Train Loss: 0.387909 | Test Loss: 0.329306
# Epoch 24/200 | Train Loss: 0.368986 | Test Loss: 0.298495
# Epoch 26/200 | Train Loss: 0.353847 | Test Loss: 0.296656
# Epoch 28/200 | Train Loss: 0.341185 | Test Loss: 0.286368
# Epoch 30/200 | Train Loss: 0.331254 | Test Loss: 0.275013
# Epoch 32/200 | Train Loss: 0.321833 | Test Loss: 0.266019
# Epoch 34/200 | Train Loss: 0.314713 | Test Loss: 0.271671
# Epoch 36/200 | Train Loss: 0.306752 | Test Loss: 0.257858
# Epoch 38/200 | Train Loss: 0.300437 | Test Loss: 0.248860
# Epoch 40/200 | Train Loss: 0.293984 | Test Loss: 0.244920
# Epoch 42/200 | Train Loss: 0.288225 | Test Loss: 0.242342
# Epoch 44/200 | Train Loss: 0.283596 | Test Loss: 0.235129
# Epoch 46/200 | Train Loss: 0.279261 | Test Loss: 0.237432
# Epoch 48/200 | Train Loss: 0.274555 | Test Loss: 0.235236
# Epoch 50/200 | Train Loss: 0.270114 | Test Loss: 0.232031
# Epoch 52/200 | Train Loss: 0.266252 | Test Loss: 0.232604
# Epoch 54/200 | Train Loss: 0.261688 | Test Loss: 0.222108
# Epoch 56/200 | Train Loss: 0.257830 | Test Loss: 0.221484
# Epoch 58/200 | Train Loss: 0.255545 | Test Loss: 0.217684
# Epoch 60/200 | Train Loss: 0.252567 | Test Loss: 0.215271
# Epoch 62/200 | Train Loss: 0.250090 | Test Loss: 0.215212
# Epoch 64/200 | Train Loss: 0.247453 | Test Loss: 0.216357
# Epoch 66/200 | Train Loss: 0.245211 | Test Loss: 0.213351
# Epoch 68/200 | Train Loss: 0.243236 | Test Loss: 0.207093
# Epoch 70/200 | Train Loss: 0.241082 | Test Loss: 0.209758
# Epoch 72/200 | Train Loss: 0.239389 | Test Loss: 0.211224
# Epoch 74/200 | Train Loss: 0.237040 | Test Loss: 0.215299
# Epoch 76/200 | Train Loss: 0.235313 | Test Loss: 0.209680
# Epoch 78/200 | Train Loss: 0.233930 | Test Loss: 0.201683
# Epoch 80/200 | Train Loss: 0.231599 | Test Loss: 0.205201
# Epoch 82/200 | Train Loss: 0.230090 | Test Loss: 0.198975
# Epoch 84/200 | Train Loss: 0.227982 | Test Loss: 0.196589
# Epoch 86/200 | Train Loss: 0.225190 | Test Loss: 0.197108
# Epoch 88/200 | Train Loss: 0.223300 | Test Loss: 0.194785
# Epoch 90/200 | Train Loss: 0.220200 | Test Loss: 0.191495
# Epoch 92/200 | Train Loss: 0.218357 | Test Loss: 0.190895
# Epoch 94/200 | Train Loss: 0.216838 | Test Loss: 0.190481
# Epoch 96/200 | Train Loss: 0.215332 | Test Loss: 0.187390
# Epoch 98/200 | Train Loss: 0.213600 | Test Loss: 0.187705
# Epoch 100/200 | Train Loss: 0.212240 | Test Loss: 0.186944
# Epoch 102/200 | Train Loss: 0.210480 | Test Loss: 0.189034
# Epoch 104/200 | Train Loss: 0.209439 | Test Loss: 0.183618
# Epoch 106/200 | Train Loss: 0.208538 | Test Loss: 0.184321
# Epoch 108/200 | Train Loss: 0.207183 | Test Loss: 0.184377
# Epoch 110/200 | Train Loss: 0.205733 | Test Loss: 0.179672
# Epoch 112/200 | Train Loss: 0.204950 | Test Loss: 0.179074
# Epoch 114/200 | Train Loss: 0.204239 | Test Loss: 0.181984
# Epoch 116/200 | Train Loss: 0.202773 | Test Loss: 0.178518
# Epoch 118/200 | Train Loss: 0.202246 | Test Loss: 0.179687
# Epoch 120/200 | Train Loss: 0.201098 | Test Loss: 0.178990
# Epoch 122/200 | Train Loss: 0.200783 | Test Loss: 0.180467
# Epoch 124/200 | Train Loss: 0.199520 | Test Loss: 0.180290
# Epoch 126/200 | Train Loss: 0.198273 | Test Loss: 0.180748
# Epoch 128/200 | Train Loss: 0.197560 | Test Loss: 0.176300
# Epoch 130/200 | Train Loss: 0.196784 | Test Loss: 0.176141
# Epoch 132/200 | Train Loss: 0.196102 | Test Loss: 0.175010
# Epoch 134/200 | Train Loss: 0.195076 | Test Loss: 0.174306
# Epoch 136/200 | Train Loss: 0.195134 | Test Loss: 0.174290
# Epoch 138/200 | Train Loss: 0.193490 | Test Loss: 0.171796
# Epoch 140/200 | Train Loss: 0.193435 | Test Loss: 0.172247
# Epoch 142/200 | Train Loss: 0.192223 | Test Loss: 0.172999
# Epoch 144/200 | Train Loss: 0.192003 | Test Loss: 0.172055
# Epoch 146/200 | Train Loss: 0.190479 | Test Loss: 0.171570
# Epoch 148/200 | Train Loss: 0.190547 | Test Loss: 0.171552
# Epoch 150/200 | Train Loss: 0.190334 | Test Loss: 0.171689
# Epoch 152/200 | Train Loss: 0.189470 | Test Loss: 0.171341
# Epoch 154/200 | Train Loss: 0.189058 | Test Loss: 0.170600
# Epoch 156/200 | Train Loss: 0.188382 | Test Loss: 0.171118
# Epoch 158/200 | Train Loss: 0.187604 | Test Loss: 0.170227
# Epoch 160/200 | Train Loss: 0.187776 | Test Loss: 0.170742
# Epoch 162/200 | Train Loss: 0.186641 | Test Loss: 0.169484
# Epoch 164/200 | Train Loss: 0.186503 | Test Loss: 0.168509
# Epoch 166/200 | Train Loss: 0.186009 | Test Loss: 0.169726
# Epoch 168/200 | Train Loss: 0.185250 | Test Loss: 0.169234
# Epoch 170/200 | Train Loss: 0.184886 | Test Loss: 0.168705
# Epoch 172/200 | Train Loss: 0.184289 | Test Loss: 0.166953
# Epoch 174/200 | Train Loss: 0.184201 | Test Loss: 0.167182
# Epoch 176/200 | Train Loss: 0.183717 | Test Loss: 0.166070
# Epoch 178/200 | Train Loss: 0.182721 | Test Loss: 0.166644
# Epoch 180/200 | Train Loss: 0.182732 | Test Loss: 0.169313
# Epoch 182/200 | Train Loss: 0.182272 | Test Loss: 0.168196
# Epoch 184/200 | Train Loss: 0.181687 | Test Loss: 0.166140
# Epoch 186/200 | Train Loss: 0.181880 | Test Loss: 0.166776
# Epoch 188/200 | Train Loss: 0.181391 | Test Loss: 0.166226
# Epoch 190/200 | Train Loss: 0.180752 | Test Loss: 0.164345
# Epoch 192/200 | Train Loss: 0.180462 | Test Loss: 0.170172
# Epoch 194/200 | Train Loss: 0.180253 | Test Loss: 0.166982
# Epoch 196/200 | Train Loss: 0.179816 | Test Loss: 0.168049
# Epoch 198/200 | Train Loss: 0.179229 | Test Loss: 0.164270
# Epoch 200/200 | Train Loss: 0.179237 | Test Loss: 0.163884
# Training Completed.
# Training took 147 min 44.3 sec.
# Best test loss: 0.163884 at epoch 200

# %%
plot_output_ratio_metric(ratios, biomass_r2, biomass_col, metric_name='r2')

# %%
plot_output_ratio_metric(ratios, biomass_mae, biomass_col, metric_name='mae')

# %% [markdown]
# ### Exploring Model Variants
#
# The following cells test multiple Transformer configurations with varying model sizes, attention heads, and feedforward dimensions. Each variant is trained, evaluated, and visualized to assess its performance and scalability.

# %%
output_sample_ratio = 1

diagnostics_to_plot = ['Biomass_Ecoli_core_flux', 'GLUDy_flux']

# %%
print_gpu_memory()
# Out:
# Allocated memory: 104.25 MB
# Reserved memory: 120.00 MB

# %%
train_losses, test_losses, model_822, optimizer = train_model(d_model=8, n_heads=2, n_layers=2, d_ff=128, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses, test_losses, d_model=8, n_heads=2, n_layers=2, d_ff=128)

plot_prediction_sample(X_test, y_test, model_822)

for flux_name in diagnostics_to_plot:
    plot_flux(model_822, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_822.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 2.819590 | Test Loss: 2.581487
# Epoch 4/200 | Train Loss: 2.259823 | Test Loss: 2.108305
# Epoch 6/200 | Train Loss: 1.935163 | Test Loss: 1.801831
# Epoch 8/200 | Train Loss: 1.793335 | Test Loss: 1.683177
# Epoch 10/200 | Train Loss: 1.684026 | Test Loss: 1.563196
# Epoch 12/200 | Train Loss: 1.581382 | Test Loss: 1.443084
# Epoch 14/200 | Train Loss: 1.537179 | Test Loss: 1.443097
# Epoch 16/200 | Train Loss: 1.478377 | Test Loss: 1.385792
# Epoch 18/200 | Train Loss: 1.455080 | Test Loss: 1.377169
# Epoch 20/200 | Train Loss: 1.427635 | Test Loss: 1.360002
# Epoch 22/200 | Train Loss: 1.404594 | Test Loss: 1.330170
# Epoch 24/200 | Train Loss: 1.371763 | Test Loss: 1.301834
# Epoch 26/200 | Train Loss: 1.339116 | Test Loss: 1.228462
# Epoch 28/200 | Train Loss: 1.259884 | Test Loss: 1.191179
# Epoch 30/200 | Train Loss: 1.231124 | Test Loss: 1.186078
# Epoch 32/200 | Train Loss: 1.229288 | Test Loss: 1.134909
# Epoch 34/200 | Train Loss: 1.193359 | Test Loss: 1.112196
# Epoch 36/200 | Train Loss: 1.184253 | Test Loss: 1.117863
# Epoch 38/200 | Train Loss: 1.168854 | Test Loss: 1.089186
# Epoch 40/200 | Train Loss: 1.151766 | Test Loss: 1.080144
# Epoch 42/200 | Train Loss: 1.123799 | Test Loss: 1.088426
# Epoch 44/200 | Train Loss: 1.112891 | Test Loss: 1.024009
# Epoch 46/200 | Train Loss: 1.089659 | Test Loss: 1.015112
# Epoch 48/200 | Train Loss: 1.082727 | Test Loss: 1.006215
# Epoch 50/200 | Train Loss: 1.068390 | Test Loss: 0.989635
# Epoch 52/200 | Train Loss: 1.043138 | Test Loss: 0.995888
# Epoch 54/200 | Train Loss: 1.039127 | Test Loss: 0.972975
# Epoch 56/200 | Train Loss: 1.017943 | Test Loss: 0.959182
# Epoch 58/200 | Train Loss: 0.994950 | Test Loss: 0.917282
# Epoch 60/200 | Train Loss: 0.974846 | Test Loss: 0.892982
# Epoch 62/200 | Train Loss: 0.970031 | Test Loss: 0.898927
# Epoch 64/200 | Train Loss: 0.952243 | Test Loss: 0.872210
# Epoch 66/200 | Train Loss: 0.948165 | Test Loss: 0.872933
# Epoch 68/200 | Train Loss: 0.936959 | Test Loss: 0.861700
# Epoch 70/200 | Train Loss: 0.939624 | Test Loss: 0.859619
# Epoch 72/200 | Train Loss: 0.921550 | Test Loss: 0.853744
# Epoch 74/200 | Train Loss: 0.917430 | Test Loss: 0.872029
# Epoch 76/200 | Train Loss: 0.916162 | Test Loss: 0.832817
# Epoch 78/200 | Train Loss: 0.907240 | Test Loss: 0.830230
# Epoch 80/200 | Train Loss: 0.900662 | Test Loss: 0.824312
# Epoch 82/200 | Train Loss: 0.896197 | Test Loss: 0.828238
# Epoch 84/200 | Train Loss: 0.901178 | Test Loss: 0.814817
# Epoch 86/200 | Train Loss: 0.885243 | Test Loss: 0.826745
# Epoch 88/200 | Train Loss: 0.882673 | Test Loss: 0.811173
# Epoch 90/200 | Train Loss: 0.881131 | Test Loss: 0.807886
# Epoch 92/200 | Train Loss: 0.886274 | Test Loss: 0.832636
# Epoch 94/200 | Train Loss: 0.875743 | Test Loss: 0.800917
# Epoch 96/200 | Train Loss: 0.872691 | Test Loss: 0.805662
# Epoch 98/200 | Train Loss: 0.877532 | Test Loss: 0.805417
# Epoch 100/200 | Train Loss: 0.863103 | Test Loss: 0.798327
# Epoch 102/200 | Train Loss: 0.864782 | Test Loss: 0.793996
# Epoch 104/200 | Train Loss: 0.860407 | Test Loss: 0.791101
# Epoch 106/200 | Train Loss: 0.859956 | Test Loss: 0.788116
# Epoch 108/200 | Train Loss: 0.857555 | Test Loss: 0.776533
# Epoch 110/200 | Train Loss: 0.847340 | Test Loss: 0.790291
# Epoch 112/200 | Train Loss: 0.843213 | Test Loss: 0.771104
# Epoch 114/200 | Train Loss: 0.846230 | Test Loss: 0.766471
# Epoch 116/200 | Train Loss: 0.840249 | Test Loss: 0.765849
# Epoch 118/200 | Train Loss: 0.833919 | Test Loss: 0.763566
# Epoch 120/200 | Train Loss: 0.832280 | Test Loss: 0.766410
# Epoch 122/200 | Train Loss: 0.822992 | Test Loss: 0.757654
# Epoch 124/200 | Train Loss: 0.825160 | Test Loss: 0.754511
# Epoch 126/200 | Train Loss: 0.812598 | Test Loss: 0.743119
# Epoch 128/200 | Train Loss: 0.808304 | Test Loss: 0.756024
# Epoch 130/200 | Train Loss: 0.806974 | Test Loss: 0.742726
# Epoch 132/200 | Train Loss: 0.805129 | Test Loss: 0.732277
# Epoch 134/200 | Train Loss: 0.805265 | Test Loss: 0.740018
# Epoch 136/200 | Train Loss: 0.803401 | Test Loss: 0.734702
# Epoch 138/200 | Train Loss: 0.800480 | Test Loss: 0.738233
# Epoch 140/200 | Train Loss: 0.797704 | Test Loss: 0.733526
# Epoch 142/200 | Train Loss: 0.794302 | Test Loss: 0.737379
# Epoch 144/200 | Train Loss: 0.792385 | Test Loss: 0.717615
# Epoch 146/200 | Train Loss: 0.792919 | Test Loss: 0.719626
# Epoch 148/200 | Train Loss: 0.787547 | Test Loss: 0.715505
# Epoch 150/200 | Train Loss: 0.785589 | Test Loss: 0.725653
# Epoch 152/200 | Train Loss: 0.781337 | Test Loss: 0.715833
# Epoch 154/200 | Train Loss: 0.785279 | Test Loss: 0.709553
# Epoch 156/200 | Train Loss: 0.782843 | Test Loss: 0.707521
# Epoch 158/200 | Train Loss: 0.773293 | Test Loss: 0.706531
# Epoch 160/200 | Train Loss: 0.778524 | Test Loss: 0.735211
# Epoch 162/200 | Train Loss: 0.774869 | Test Loss: 0.704143
# Epoch 164/200 | Train Loss: 0.774670 | Test Loss: 0.720882
# Epoch 166/200 | Train Loss: 0.782399 | Test Loss: 0.714612
# Epoch 168/200 | Train Loss: 0.776268 | Test Loss: 0.699960
# Epoch 170/200 | Train Loss: 0.764586 | Test Loss: 0.705534
# Epoch 172/200 | Train Loss: 0.772779 | Test Loss: 0.705404
# Epoch 174/200 | Train Loss: 0.769292 | Test Loss: 0.696117
# Epoch 176/200 | Train Loss: 0.762705 | Test Loss: 0.703078
# Epoch 178/200 | Train Loss: 0.765657 | Test Loss: 0.691116
# Epoch 180/200 | Train Loss: 0.760074 | Test Loss: 0.686042
# Epoch 182/200 | Train Loss: 0.755489 | Test Loss: 0.692077
# Epoch 184/200 | Train Loss: 0.758618 | Test Loss: 0.683302
# Epoch 186/200 | Train Loss: 0.750904 | Test Loss: 0.680320
# Epoch 188/200 | Train Loss: 0.751938 | Test Loss: 0.689418
# Epoch 190/200 | Train Loss: 0.751351 | Test Loss: 0.681284
# Epoch 192/200 | Train Loss: 0.745050 | Test Loss: 0.684279
# Epoch 194/200 | Train Loss: 0.750479 | Test Loss: 0.670170
# Epoch 196/200 | Train Loss: 0.741302 | Test Loss: 0.683418
# Epoch 198/200 | Train Loss: 0.744466 | Test Loss: 0.669748
# Epoch 200/200 | Train Loss: 0.747220 | Test Loss: 0.684945
# Training Completed.
# Training took 22 min 42.8 sec.
# Best test loss: 0.666361 at epoch 199
# y_pred_outputs.shape: (39227, 95) min/max: -73.670784 103.54369
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -1.025579 to 2.3382084
# y_pred_outputs.shape: (39227, 95) min/max: -73.670784 103.54369
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -4.222247 to 24.988914
# Number of parameters:
# 6450

# %%
train_losses_1622, test_losses_1622, model_1622, optimizer = train_model(d_model=16, n_heads=2, n_layers=2, d_ff=128, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_1622, test_losses_1622, d_model=16, n_heads=2, n_layers=2, d_ff=128)

plot_prediction_sample(X_test, y_test, model_1622)

for flux_name in diagnostics_to_plot:
    plot_flux(model_1622, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_1622.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 2.368182 | Test Loss: 2.123955
# Epoch 4/200 | Train Loss: 1.942664 | Test Loss: 1.820164
# Epoch 6/200 | Train Loss: 1.745679 | Test Loss: 1.622405
# Epoch 8/200 | Train Loss: 1.624645 | Test Loss: 1.501104
# Epoch 10/200 | Train Loss: 1.513337 | Test Loss: 1.430330
# Epoch 12/200 | Train Loss: 1.462086 | Test Loss: 1.372794
# Epoch 14/200 | Train Loss: 1.401343 | Test Loss: 1.304824
# Epoch 16/200 | Train Loss: 1.338927 | Test Loss: 1.253918
# Epoch 18/200 | Train Loss: 1.302771 | Test Loss: 1.214268
# Epoch 20/200 | Train Loss: 1.263980 | Test Loss: 1.181940
# Epoch 22/200 | Train Loss: 1.216811 | Test Loss: 1.123756
# Epoch 24/200 | Train Loss: 1.161061 | Test Loss: 1.049813
# Epoch 26/200 | Train Loss: 1.102693 | Test Loss: 1.003822
# Epoch 28/200 | Train Loss: 1.060719 | Test Loss: 0.958557
# Epoch 30/200 | Train Loss: 1.024734 | Test Loss: 0.925920
# Epoch 32/200 | Train Loss: 0.990434 | Test Loss: 0.912607
# Epoch 34/200 | Train Loss: 0.955347 | Test Loss: 0.880188
# Epoch 36/200 | Train Loss: 0.936328 | Test Loss: 0.856964
# Epoch 38/200 | Train Loss: 0.920491 | Test Loss: 0.836467
# Epoch 40/200 | Train Loss: 0.900583 | Test Loss: 0.809971
# Epoch 42/200 | Train Loss: 0.883988 | Test Loss: 0.806534
# Epoch 44/200 | Train Loss: 0.865089 | Test Loss: 0.788039
# Epoch 46/200 | Train Loss: 0.860773 | Test Loss: 0.782583
# Epoch 48/200 | Train Loss: 0.844731 | Test Loss: 0.760136
# Epoch 50/200 | Train Loss: 0.837531 | Test Loss: 0.758741
# Epoch 52/200 | Train Loss: 0.832812 | Test Loss: 0.759164
# Epoch 54/200 | Train Loss: 0.825856 | Test Loss: 0.764856
# Epoch 56/200 | Train Loss: 0.816136 | Test Loss: 0.733216
# Epoch 58/200 | Train Loss: 0.806946 | Test Loss: 0.738483
# Epoch 60/200 | Train Loss: 0.798098 | Test Loss: 0.736506
# Epoch 62/200 | Train Loss: 0.794989 | Test Loss: 0.729101
# Epoch 64/200 | Train Loss: 0.783763 | Test Loss: 0.716520
# Epoch 66/200 | Train Loss: 0.779145 | Test Loss: 0.704711
# Epoch 68/200 | Train Loss: 0.776076 | Test Loss: 0.695820
# Epoch 70/200 | Train Loss: 0.767550 | Test Loss: 0.683036
# Epoch 72/200 | Train Loss: 0.754588 | Test Loss: 0.692706
# Epoch 74/200 | Train Loss: 0.746662 | Test Loss: 0.671939
# Epoch 76/200 | Train Loss: 0.738962 | Test Loss: 0.672926
# Epoch 78/200 | Train Loss: 0.732281 | Test Loss: 0.648546
# Epoch 80/200 | Train Loss: 0.722184 | Test Loss: 0.646682
# Epoch 82/200 | Train Loss: 0.718271 | Test Loss: 0.647943
# Epoch 84/200 | Train Loss: 0.708531 | Test Loss: 0.621141
# Epoch 86/200 | Train Loss: 0.705076 | Test Loss: 0.626506
# Epoch 88/200 | Train Loss: 0.702476 | Test Loss: 0.621798
# Epoch 90/200 | Train Loss: 0.691656 | Test Loss: 0.606770
# Epoch 92/200 | Train Loss: 0.686178 | Test Loss: 0.605295
# Epoch 94/200 | Train Loss: 0.680206 | Test Loss: 0.601020
# Epoch 96/200 | Train Loss: 0.675130 | Test Loss: 0.592912
# Epoch 98/200 | Train Loss: 0.664085 | Test Loss: 0.590847
# Epoch 100/200 | Train Loss: 0.664340 | Test Loss: 0.589862
# Epoch 102/200 | Train Loss: 0.661965 | Test Loss: 0.573562
# Epoch 104/200 | Train Loss: 0.652669 | Test Loss: 0.573206
# Epoch 106/200 | Train Loss: 0.654074 | Test Loss: 0.567363
# Epoch 108/200 | Train Loss: 0.642933 | Test Loss: 0.566586
# Epoch 110/200 | Train Loss: 0.640467 | Test Loss: 0.557900
# Epoch 112/200 | Train Loss: 0.632883 | Test Loss: 0.565773
# Epoch 114/200 | Train Loss: 0.631950 | Test Loss: 0.550940
# Epoch 116/200 | Train Loss: 0.623794 | Test Loss: 0.533934
# Epoch 118/200 | Train Loss: 0.615243 | Test Loss: 0.534317
# Epoch 120/200 | Train Loss: 0.618523 | Test Loss: 0.532453
# Epoch 122/200 | Train Loss: 0.612592 | Test Loss: 0.529830
# Epoch 124/200 | Train Loss: 0.613139 | Test Loss: 0.538168
# Epoch 126/200 | Train Loss: 0.610658 | Test Loss: 0.526389
# Epoch 128/200 | Train Loss: 0.604907 | Test Loss: 0.519531
# Epoch 130/200 | Train Loss: 0.598215 | Test Loss: 0.520158
# Epoch 132/200 | Train Loss: 0.601349 | Test Loss: 0.528388
# Epoch 134/200 | Train Loss: 0.595042 | Test Loss: 0.511853
# Epoch 136/200 | Train Loss: 0.588421 | Test Loss: 0.506959
# Epoch 138/200 | Train Loss: 0.590757 | Test Loss: 0.494913
# Epoch 140/200 | Train Loss: 0.577864 | Test Loss: 0.496768
# Epoch 142/200 | Train Loss: 0.575925 | Test Loss: 0.501740
# Epoch 144/200 | Train Loss: 0.578852 | Test Loss: 0.497787
# Epoch 146/200 | Train Loss: 0.573549 | Test Loss: 0.489448
# Epoch 148/200 | Train Loss: 0.568822 | Test Loss: 0.488822
# Epoch 150/200 | Train Loss: 0.564068 | Test Loss: 0.482079
# Epoch 152/200 | Train Loss: 0.560766 | Test Loss: 0.479939
# Epoch 154/200 | Train Loss: 0.557379 | Test Loss: 0.474263
# Epoch 156/200 | Train Loss: 0.555488 | Test Loss: 0.486408
# Epoch 158/200 | Train Loss: 0.556872 | Test Loss: 0.466118
# Epoch 160/200 | Train Loss: 0.550094 | Test Loss: 0.466274
# Epoch 162/200 | Train Loss: 0.555792 | Test Loss: 0.464441
# Epoch 164/200 | Train Loss: 0.546754 | Test Loss: 0.481084
# Epoch 166/200 | Train Loss: 0.546156 | Test Loss: 0.467576
# Epoch 168/200 | Train Loss: 0.545528 | Test Loss: 0.466592
# Epoch 170/200 | Train Loss: 0.542223 | Test Loss: 0.447622
# Epoch 172/200 | Train Loss: 0.539660 | Test Loss: 0.449689
# Epoch 174/200 | Train Loss: 0.536800 | Test Loss: 0.443510
# Epoch 176/200 | Train Loss: 0.532638 | Test Loss: 0.438352
# Epoch 178/200 | Train Loss: 0.525784 | Test Loss: 0.438235
# Epoch 180/200 | Train Loss: 0.522874 | Test Loss: 0.438003
# Epoch 182/200 | Train Loss: 0.525501 | Test Loss: 0.450757
# Epoch 184/200 | Train Loss: 0.523486 | Test Loss: 0.432682
# Epoch 186/200 | Train Loss: 0.521163 | Test Loss: 0.434086
# Epoch 188/200 | Train Loss: 0.519276 | Test Loss: 0.441861
# Epoch 190/200 | Train Loss: 0.517021 | Test Loss: 0.435587
# Epoch 192/200 | Train Loss: 0.515155 | Test Loss: 0.438175
# Epoch 194/200 | Train Loss: 0.515970 | Test Loss: 0.428392
# Epoch 196/200 | Train Loss: 0.515506 | Test Loss: 0.433733
# Epoch 198/200 | Train Loss: 0.507427 | Test Loss: 0.427689
# Epoch 200/200 | Train Loss: 0.510329 | Test Loss: 0.425643
# Training Completed.
# Training took 24 min 43.8 sec.
# Best test loss: 0.425643 at epoch 200
# y_pred_outputs.shape: (39227, 95) min/max: -69.084305 103.360725
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: 0.09491825 to 2.0314548
# y_pred_outputs.shape: (39227, 95) min/max: -69.084305 103.360725
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -7.3517637 to 22.598703
# Number of parameters:
# 13146

# %%
train_losses_3242, test_losses_3242, model_3242, optimizer = train_model(d_model=32, n_heads=4, n_layers=2, d_ff=128, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_3242, test_losses_3242, d_model=32, n_heads=4, n_layers=2, d_ff=128)

plot_prediction_sample(X_test, y_test, model_3242)

for flux_name in diagnostics_to_plot:
    plot_flux(model_3242, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_3242.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 1.908289 | Test Loss: 1.644826
# Epoch 4/200 | Train Loss: 1.366512 | Test Loss: 1.225828
# Epoch 6/200 | Train Loss: 1.071135 | Test Loss: 0.979355
# Epoch 8/200 | Train Loss: 0.917187 | Test Loss: 0.806661
# Epoch 10/200 | Train Loss: 0.821149 | Test Loss: 0.705798
# Epoch 12/200 | Train Loss: 0.730488 | Test Loss: 0.635541
# Epoch 14/200 | Train Loss: 0.687022 | Test Loss: 0.596342
# Epoch 16/200 | Train Loss: 0.645179 | Test Loss: 0.537761
# Epoch 18/200 | Train Loss: 0.600285 | Test Loss: 0.526859
# Epoch 20/200 | Train Loss: 0.574821 | Test Loss: 0.491674
# Epoch 22/200 | Train Loss: 0.545870 | Test Loss: 0.454780
# Epoch 24/200 | Train Loss: 0.529600 | Test Loss: 0.442764
# Epoch 26/200 | Train Loss: 0.513795 | Test Loss: 0.430318
# Epoch 28/200 | Train Loss: 0.497663 | Test Loss: 0.425804
# Epoch 30/200 | Train Loss: 0.488050 | Test Loss: 0.416002
# Epoch 32/200 | Train Loss: 0.481060 | Test Loss: 0.411186
# Epoch 34/200 | Train Loss: 0.468744 | Test Loss: 0.406986
# Epoch 36/200 | Train Loss: 0.458596 | Test Loss: 0.388649
# Epoch 38/200 | Train Loss: 0.447797 | Test Loss: 0.381228
# Epoch 40/200 | Train Loss: 0.443615 | Test Loss: 0.360160
# Epoch 42/200 | Train Loss: 0.437066 | Test Loss: 0.363067
# Epoch 44/200 | Train Loss: 0.429915 | Test Loss: 0.366086
# Epoch 46/200 | Train Loss: 0.419783 | Test Loss: 0.352558
# Epoch 48/200 | Train Loss: 0.418306 | Test Loss: 0.356567
# Epoch 50/200 | Train Loss: 0.409510 | Test Loss: 0.347120
# Epoch 52/200 | Train Loss: 0.405437 | Test Loss: 0.333258
# Epoch 54/200 | Train Loss: 0.402345 | Test Loss: 0.328807
# Epoch 56/200 | Train Loss: 0.393336 | Test Loss: 0.327996
# Epoch 58/200 | Train Loss: 0.390959 | Test Loss: 0.337941
# Epoch 60/200 | Train Loss: 0.387841 | Test Loss: 0.326604
# Epoch 62/200 | Train Loss: 0.383141 | Test Loss: 0.313951
# Epoch 64/200 | Train Loss: 0.378934 | Test Loss: 0.319225
# Epoch 66/200 | Train Loss: 0.373482 | Test Loss: 0.311106
# Epoch 68/200 | Train Loss: 0.375613 | Test Loss: 0.307919
# Epoch 70/200 | Train Loss: 0.374042 | Test Loss: 0.301947
# Epoch 72/200 | Train Loss: 0.368104 | Test Loss: 0.305202
# Epoch 74/200 | Train Loss: 0.367905 | Test Loss: 0.318474
# Epoch 76/200 | Train Loss: 0.364629 | Test Loss: 0.303238
# Epoch 78/200 | Train Loss: 0.361947 | Test Loss: 0.294525
# Epoch 80/200 | Train Loss: 0.358463 | Test Loss: 0.306624
# Epoch 82/200 | Train Loss: 0.352278 | Test Loss: 0.291306
# Epoch 84/200 | Train Loss: 0.356535 | Test Loss: 0.303721
# Epoch 86/200 | Train Loss: 0.353487 | Test Loss: 0.288955
# Epoch 88/200 | Train Loss: 0.349235 | Test Loss: 0.290234
# Epoch 90/200 | Train Loss: 0.348209 | Test Loss: 0.288405
# Epoch 92/200 | Train Loss: 0.346361 | Test Loss: 0.288305
# Epoch 94/200 | Train Loss: 0.348231 | Test Loss: 0.284267
# Epoch 96/200 | Train Loss: 0.349353 | Test Loss: 0.285150
# Epoch 98/200 | Train Loss: 0.340781 | Test Loss: 0.294734
# Epoch 100/200 | Train Loss: 0.339949 | Test Loss: 0.292768
# Epoch 102/200 | Train Loss: 0.339996 | Test Loss: 0.285905
# Epoch 104/200 | Train Loss: 0.340824 | Test Loss: 0.299066
# Epoch 106/200 | Train Loss: 0.335862 | Test Loss: 0.286066
# Epoch 108/200 | Train Loss: 0.337008 | Test Loss: 0.284595
# Epoch 110/200 | Train Loss: 0.336762 | Test Loss: 0.285584
# Epoch 112/200 | Train Loss: 0.331728 | Test Loss: 0.284371
# Epoch 114/200 | Train Loss: 0.332786 | Test Loss: 0.273869
# Epoch 116/200 | Train Loss: 0.333370 | Test Loss: 0.275001
# Epoch 118/200 | Train Loss: 0.330660 | Test Loss: 0.281796
# Epoch 120/200 | Train Loss: 0.331116 | Test Loss: 0.288103
# Epoch 122/200 | Train Loss: 0.330222 | Test Loss: 0.276585
# Epoch 124/200 | Train Loss: 0.325094 | Test Loss: 0.273989
# Epoch 126/200 | Train Loss: 0.325045 | Test Loss: 0.271078
# Epoch 128/200 | Train Loss: 0.324249 | Test Loss: 0.275555
# Epoch 130/200 | Train Loss: 0.321662 | Test Loss: 0.286300
# Epoch 132/200 | Train Loss: 0.322583 | Test Loss: 0.266480
# Epoch 134/200 | Train Loss: 0.322585 | Test Loss: 0.263326
# Epoch 136/200 | Train Loss: 0.321700 | Test Loss: 0.275970
# Epoch 138/200 | Train Loss: 0.316692 | Test Loss: 0.269944
# Epoch 140/200 | Train Loss: 0.320983 | Test Loss: 0.272045
# Epoch 142/200 | Train Loss: 0.321814 | Test Loss: 0.272466
# Epoch 144/200 | Train Loss: 0.314798 | Test Loss: 0.259896
# Epoch 146/200 | Train Loss: 0.318350 | Test Loss: 0.264641
# Epoch 148/200 | Train Loss: 0.315795 | Test Loss: 0.257435
# Epoch 150/200 | Train Loss: 0.311970 | Test Loss: 0.261978
# Epoch 152/200 | Train Loss: 0.312258 | Test Loss: 0.270351
# Epoch 154/200 | Train Loss: 0.313849 | Test Loss: 0.263762
# Epoch 156/200 | Train Loss: 0.314988 | Test Loss: 0.258887
# Epoch 158/200 | Train Loss: 0.309089 | Test Loss: 0.255380
# Epoch 160/200 | Train Loss: 0.313499 | Test Loss: 0.264066
# Epoch 162/200 | Train Loss: 0.308240 | Test Loss: 0.252470
# Epoch 164/200 | Train Loss: 0.308680 | Test Loss: 0.255035
# Epoch 166/200 | Train Loss: 0.307244 | Test Loss: 0.265492
# Epoch 168/200 | Train Loss: 0.308488 | Test Loss: 0.251935
# Epoch 170/200 | Train Loss: 0.309303 | Test Loss: 0.256049
# Epoch 172/200 | Train Loss: 0.302990 | Test Loss: 0.252766
# Epoch 174/200 | Train Loss: 0.307212 | Test Loss: 0.266579
# Epoch 176/200 | Train Loss: 0.302498 | Test Loss: 0.267302
# Epoch 178/200 | Train Loss: 0.307371 | Test Loss: 0.250318
# Epoch 180/200 | Train Loss: 0.302660 | Test Loss: 0.250443
# Epoch 182/200 | Train Loss: 0.303840 | Test Loss: 0.249257
# Epoch 184/200 | Train Loss: 0.302398 | Test Loss: 0.254873
# Epoch 186/200 | Train Loss: 0.304210 | Test Loss: 0.254191
# Epoch 188/200 | Train Loss: 0.299176 | Test Loss: 0.253314
# Epoch 190/200 | Train Loss: 0.297837 | Test Loss: 0.251812
# Epoch 192/200 | Train Loss: 0.298280 | Test Loss: 0.252510
# Epoch 194/200 | Train Loss: 0.299455 | Test Loss: 0.252209
# Epoch 196/200 | Train Loss: 0.296723 | Test Loss: 0.255055
# Epoch 198/200 | Train Loss: 0.298527 | Test Loss: 0.248775
# Epoch 200/200 | Train Loss: 0.298063 | Test Loss: 0.249505
# Training Completed.
# Training took 26 min 47.0 sec.
# Best test loss: 0.245062 at epoch 197
# y_pred_outputs.shape: (39227, 95) min/max: -73.75759 107.18997
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.27005243 to 2.1991773
# y_pred_outputs.shape: (39227, 95) min/max: -73.75759 107.18997
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -9.631284 to 24.000196
# Number of parameters:
# 29614

# %%
train_losses_3243_256, test_losses_3243_256, model_3243_256, optimizer = train_model(d_model=32, n_heads=4, n_layers=3, d_ff=256, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_3243_256, test_losses_3243_256, d_model=32, n_heads=4, n_layers=3, d_ff=256)

plot_prediction_sample(X_test, y_test, model_3243_256)

for flux_name in diagnostics_to_plot:
    plot_flux(model_3243_256, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_3243_256.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 1.893736 | Test Loss: 1.633858
# Epoch 4/200 | Train Loss: 1.259913 | Test Loss: 1.178745
# Epoch 6/200 | Train Loss: 1.076609 | Test Loss: 0.977560
# Epoch 8/200 | Train Loss: 0.944790 | Test Loss: 0.862912
# Epoch 10/200 | Train Loss: 0.728956 | Test Loss: 0.651530
# Epoch 12/200 | Train Loss: 0.627268 | Test Loss: 0.533827
# Epoch 14/200 | Train Loss: 0.567716 | Test Loss: 0.481164
# Epoch 16/200 | Train Loss: 0.521864 | Test Loss: 0.456629
# Epoch 18/200 | Train Loss: 0.490646 | Test Loss: 0.418910
# Epoch 20/200 | Train Loss: 0.450309 | Test Loss: 0.381234
# Epoch 22/200 | Train Loss: 0.423060 | Test Loss: 0.359154
# Epoch 24/200 | Train Loss: 0.392941 | Test Loss: 0.338503
# Epoch 26/200 | Train Loss: 0.382958 | Test Loss: 0.317935
# Epoch 28/200 | Train Loss: 0.367856 | Test Loss: 0.300731
# Epoch 30/200 | Train Loss: 0.352239 | Test Loss: 0.297240
# Epoch 32/200 | Train Loss: 0.342554 | Test Loss: 0.273526
# Epoch 34/200 | Train Loss: 0.333909 | Test Loss: 0.290335
# Epoch 36/200 | Train Loss: 0.323970 | Test Loss: 0.264735
# Epoch 38/200 | Train Loss: 0.314730 | Test Loss: 0.257256
# Epoch 40/200 | Train Loss: 0.308108 | Test Loss: 0.262871
# Epoch 42/200 | Train Loss: 0.303707 | Test Loss: 0.254312
# Epoch 44/200 | Train Loss: 0.294995 | Test Loss: 0.264118
# Epoch 46/200 | Train Loss: 0.288889 | Test Loss: 0.247548
# Epoch 48/200 | Train Loss: 0.287512 | Test Loss: 0.225345
# Epoch 50/200 | Train Loss: 0.285699 | Test Loss: 0.266667
# Epoch 52/200 | Train Loss: 0.283186 | Test Loss: 0.230914
# Epoch 54/200 | Train Loss: 0.276104 | Test Loss: 0.217237
# Epoch 56/200 | Train Loss: 0.270959 | Test Loss: 0.248347
# Epoch 58/200 | Train Loss: 0.269158 | Test Loss: 0.238121
# Epoch 60/200 | Train Loss: 0.265918 | Test Loss: 0.240544
# Epoch 62/200 | Train Loss: 0.264176 | Test Loss: 0.226271
# Epoch 64/200 | Train Loss: 0.261568 | Test Loss: 0.223706
# Epoch 66/200 | Train Loss: 0.256922 | Test Loss: 0.212290
# Epoch 68/200 | Train Loss: 0.253016 | Test Loss: 0.222682
# Epoch 70/200 | Train Loss: 0.253259 | Test Loss: 0.225802
# Epoch 72/200 | Train Loss: 0.251333 | Test Loss: 0.212269
# Epoch 74/200 | Train Loss: 0.247680 | Test Loss: 0.213502
# Epoch 76/200 | Train Loss: 0.247868 | Test Loss: 0.204663
# Epoch 78/200 | Train Loss: 0.246265 | Test Loss: 0.196431
# Epoch 80/200 | Train Loss: 0.246400 | Test Loss: 0.218527
# Epoch 82/200 | Train Loss: 0.243944 | Test Loss: 0.195191
# Epoch 84/200 | Train Loss: 0.245811 | Test Loss: 0.239774
# Epoch 86/200 | Train Loss: 0.240093 | Test Loss: 0.216212
# Epoch 88/200 | Train Loss: 0.236157 | Test Loss: 0.201765
# Epoch 90/200 | Train Loss: 0.236714 | Test Loss: 0.206638
# Epoch 92/200 | Train Loss: 0.233923 | Test Loss: 0.201326
# Epoch 94/200 | Train Loss: 0.231895 | Test Loss: 0.191615
# Epoch 96/200 | Train Loss: 0.234188 | Test Loss: 0.210620
# Epoch 98/200 | Train Loss: 0.232037 | Test Loss: 0.183919
# Epoch 100/200 | Train Loss: 0.229794 | Test Loss: 0.190364
# Epoch 102/200 | Train Loss: 0.225120 | Test Loss: 0.187558
# Epoch 104/200 | Train Loss: 0.226287 | Test Loss: 0.182616
# Epoch 106/200 | Train Loss: 0.224887 | Test Loss: 0.185893
# Epoch 108/200 | Train Loss: 0.224791 | Test Loss: 0.183817
# Epoch 110/200 | Train Loss: 0.223258 | Test Loss: 0.199355
# Epoch 112/200 | Train Loss: 0.223977 | Test Loss: 0.190703
# Epoch 114/200 | Train Loss: 0.215001 | Test Loss: 0.189533
# Epoch 116/200 | Train Loss: 0.219380 | Test Loss: 0.187333
# Epoch 118/200 | Train Loss: 0.216323 | Test Loss: 0.183543
# Epoch 120/200 | Train Loss: 0.216776 | Test Loss: 0.189600
# Epoch 122/200 | Train Loss: 0.214825 | Test Loss: 0.199616
# Epoch 124/200 | Train Loss: 0.214840 | Test Loss: 0.186409
# Epoch 126/200 | Train Loss: 0.213654 | Test Loss: 0.170881
# Epoch 128/200 | Train Loss: 0.215139 | Test Loss: 0.175074
# Epoch 130/200 | Train Loss: 0.210628 | Test Loss: 0.177396
# Epoch 132/200 | Train Loss: 0.210567 | Test Loss: 0.178631
# Epoch 134/200 | Train Loss: 0.208156 | Test Loss: 0.177296
# Epoch 136/200 | Train Loss: 0.208656 | Test Loss: 0.177598
# Epoch 138/200 | Train Loss: 0.207474 | Test Loss: 0.175290
# Epoch 140/200 | Train Loss: 0.207943 | Test Loss: 0.177961
# Epoch 142/200 | Train Loss: 0.208084 | Test Loss: 0.174196
# Epoch 144/200 | Train Loss: 0.209749 | Test Loss: 0.177949
# Epoch 146/200 | Train Loss: 0.204935 | Test Loss: 0.172554
# Epoch 148/200 | Train Loss: 0.205947 | Test Loss: 0.169217
# Epoch 150/200 | Train Loss: 0.207628 | Test Loss: 0.173984
# Epoch 152/200 | Train Loss: 0.204929 | Test Loss: 0.180215
# Epoch 154/200 | Train Loss: 0.204399 | Test Loss: 0.167674
# Epoch 156/200 | Train Loss: 0.203524 | Test Loss: 0.181928
# Epoch 158/200 | Train Loss: 0.201462 | Test Loss: 0.173862
# Epoch 160/200 | Train Loss: 0.199267 | Test Loss: 0.163984
# Epoch 162/200 | Train Loss: 0.202300 | Test Loss: 0.180962
# Epoch 164/200 | Train Loss: 0.200380 | Test Loss: 0.176388
# Epoch 166/200 | Train Loss: 0.200501 | Test Loss: 0.170848
# Epoch 168/200 | Train Loss: 0.198674 | Test Loss: 0.166388
# Epoch 170/200 | Train Loss: 0.198167 | Test Loss: 0.165277
# Epoch 172/200 | Train Loss: 0.200165 | Test Loss: 0.168614
# Epoch 174/200 | Train Loss: 0.199803 | Test Loss: 0.164255
# Epoch 176/200 | Train Loss: 0.197756 | Test Loss: 0.173210
# Epoch 178/200 | Train Loss: 0.198538 | Test Loss: 0.169967
# Epoch 180/200 | Train Loss: 0.196160 | Test Loss: 0.166894
# Epoch 182/200 | Train Loss: 0.198589 | Test Loss: 0.161846
# Epoch 184/200 | Train Loss: 0.198206 | Test Loss: 0.161599
# Epoch 186/200 | Train Loss: 0.194628 | Test Loss: 0.165261
# Epoch 188/200 | Train Loss: 0.194041 | Test Loss: 0.171151
# Epoch 190/200 | Train Loss: 0.193909 | Test Loss: 0.162058
# Epoch 192/200 | Train Loss: 0.196274 | Test Loss: 0.180599
# Epoch 194/200 | Train Loss: 0.197327 | Test Loss: 0.168441
# Epoch 196/200 | Train Loss: 0.192428 | Test Loss: 0.173082
# Epoch 198/200 | Train Loss: 0.194488 | Test Loss: 0.171535
# Epoch 200/200 | Train Loss: 0.194947 | Test Loss: 0.160943
# Training Completed.
# Training took 38 min 31.4 sec.
# Best test loss: 0.158673 at epoch 189
# y_pred_outputs.shape: (39227, 95) min/max: -75.484184 108.74066
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.23854256 to 2.3481827
# y_pred_outputs.shape: (39227, 95) min/max: -75.484184 108.74066
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -8.703229 to 23.913944
# Number of parameters:
# 68309

# %%
train_losses_6443_256, test_losses_6443_256, model_6443_256, optimizer = train_model(d_model=64, n_heads=4, n_layers=3, d_ff=256, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_6443_256, test_losses_6443_256, d_model=64, n_heads=4, n_layers=3, d_ff=256)

plot_prediction_sample(X_test, y_test, model_6443_256)

for flux_name in diagnostics_to_plot:
    plot_flux(model_6443_256, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_6443_256.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 1.478640 | Test Loss: 1.192719
# Epoch 4/200 | Train Loss: 0.895347 | Test Loss: 0.741669
# Epoch 6/200 | Train Loss: 0.637512 | Test Loss: 0.572703
# Epoch 8/200 | Train Loss: 0.510256 | Test Loss: 0.486411
# Epoch 10/200 | Train Loss: 0.441129 | Test Loss: 0.347039
# Epoch 12/200 | Train Loss: 0.387136 | Test Loss: 0.339573
# Epoch 14/200 | Train Loss: 0.350974 | Test Loss: 0.294631
# Epoch 16/200 | Train Loss: 0.323530 | Test Loss: 0.281105
# Epoch 18/200 | Train Loss: 0.304284 | Test Loss: 0.314286
# Epoch 20/200 | Train Loss: 0.292725 | Test Loss: 0.249412
# Epoch 22/200 | Train Loss: 0.283447 | Test Loss: 0.237614
# Epoch 24/200 | Train Loss: 0.270377 | Test Loss: 0.216840
# Epoch 26/200 | Train Loss: 0.265607 | Test Loss: 0.225192
# Epoch 28/200 | Train Loss: 0.257128 | Test Loss: 0.223863
# Epoch 30/200 | Train Loss: 0.249680 | Test Loss: 0.208639
# Epoch 32/200 | Train Loss: 0.247461 | Test Loss: 0.209326
# Epoch 34/200 | Train Loss: 0.242381 | Test Loss: 0.214759
# Epoch 36/200 | Train Loss: 0.237922 | Test Loss: 0.208085
# Epoch 38/200 | Train Loss: 0.232048 | Test Loss: 0.196443
# Epoch 40/200 | Train Loss: 0.226985 | Test Loss: 0.212322
# Epoch 42/200 | Train Loss: 0.223844 | Test Loss: 0.189206
# Epoch 44/200 | Train Loss: 0.222368 | Test Loss: 0.198730
# Epoch 46/200 | Train Loss: 0.220752 | Test Loss: 0.202409
# Epoch 48/200 | Train Loss: 0.217200 | Test Loss: 0.193026
# Epoch 50/200 | Train Loss: 0.215749 | Test Loss: 0.190587
# Epoch 52/200 | Train Loss: 0.210166 | Test Loss: 0.188155
# Epoch 54/200 | Train Loss: 0.211966 | Test Loss: 0.184689
# Epoch 56/200 | Train Loss: 0.206050 | Test Loss: 0.185284
# Epoch 58/200 | Train Loss: 0.203908 | Test Loss: 0.186897
# Epoch 60/200 | Train Loss: 0.202512 | Test Loss: 0.179054
# Epoch 62/200 | Train Loss: 0.202618 | Test Loss: 0.176505
# Epoch 64/200 | Train Loss: 0.198910 | Test Loss: 0.172662
# Epoch 66/200 | Train Loss: 0.198415 | Test Loss: 0.173188
# Epoch 68/200 | Train Loss: 0.196147 | Test Loss: 0.173640
# Epoch 70/200 | Train Loss: 0.196899 | Test Loss: 0.171438
# Epoch 72/200 | Train Loss: 0.196025 | Test Loss: 0.178828
# Epoch 74/200 | Train Loss: 0.195146 | Test Loss: 0.171699
# Epoch 76/200 | Train Loss: 0.192631 | Test Loss: 0.181428
# Epoch 78/200 | Train Loss: 0.191047 | Test Loss: 0.166514
# Epoch 80/200 | Train Loss: 0.194123 | Test Loss: 0.183543
# Epoch 82/200 | Train Loss: 0.190059 | Test Loss: 0.170119
# Epoch 84/200 | Train Loss: 0.193292 | Test Loss: 0.185158
# Epoch 86/200 | Train Loss: 0.187435 | Test Loss: 0.167701
# Epoch 88/200 | Train Loss: 0.191817 | Test Loss: 0.166828
# Epoch 90/200 | Train Loss: 0.185705 | Test Loss: 0.187910
# Epoch 92/200 | Train Loss: 0.184545 | Test Loss: 0.161376
# Epoch 94/200 | Train Loss: 0.185643 | Test Loss: 0.181684
# Epoch 96/200 | Train Loss: 0.185462 | Test Loss: 0.169446
# Epoch 98/200 | Train Loss: 0.186764 | Test Loss: 0.174285
# Epoch 100/200 | Train Loss: 0.182167 | Test Loss: 0.168813
# Epoch 102/200 | Train Loss: 0.184145 | Test Loss: 0.161378
# Epoch 104/200 | Train Loss: 0.180566 | Test Loss: 0.169025
# Epoch 106/200 | Train Loss: 0.179784 | Test Loss: 0.151571
# Epoch 108/200 | Train Loss: 0.181689 | Test Loss: 0.153365
# Epoch 110/200 | Train Loss: 0.180769 | Test Loss: 0.160042
# Epoch 112/200 | Train Loss: 0.182386 | Test Loss: 0.159171
# Epoch 114/200 | Train Loss: 0.178343 | Test Loss: 0.157868
# Epoch 116/200 | Train Loss: 0.176978 | Test Loss: 0.172006
# Epoch 118/200 | Train Loss: 0.179413 | Test Loss: 0.163809
# Epoch 120/200 | Train Loss: 0.180248 | Test Loss: 0.161746
# Epoch 122/200 | Train Loss: 0.179354 | Test Loss: 0.158191
# Epoch 124/200 | Train Loss: 0.175286 | Test Loss: 0.155685
# Epoch 126/200 | Train Loss: 0.173872 | Test Loss: 0.160398
# Epoch 128/200 | Train Loss: 0.175307 | Test Loss: 0.158505
# Epoch 130/200 | Train Loss: 0.176037 | Test Loss: 0.171942
# Epoch 132/200 | Train Loss: 0.176940 | Test Loss: 0.155518
# Epoch 134/200 | Train Loss: 0.175967 | Test Loss: 0.160064
# Epoch 136/200 | Train Loss: 0.174589 | Test Loss: 0.164425
# Epoch 138/200 | Train Loss: 0.175373 | Test Loss: 0.154838
# Epoch 140/200 | Train Loss: 0.174755 | Test Loss: 0.159806
# Epoch 142/200 | Train Loss: 0.174409 | Test Loss: 0.156825
# Epoch 144/200 | Train Loss: 0.171583 | Test Loss: 0.149462
# Epoch 146/200 | Train Loss: 0.174569 | Test Loss: 0.156350
# Epoch 148/200 | Train Loss: 0.172155 | Test Loss: 0.155207
# Epoch 150/200 | Train Loss: 0.170080 | Test Loss: 0.154133
# Epoch 152/200 | Train Loss: 0.168568 | Test Loss: 0.159993
# Epoch 154/200 | Train Loss: 0.172604 | Test Loss: 0.165493
# Epoch 156/200 | Train Loss: 0.169940 | Test Loss: 0.148862
# Epoch 158/200 | Train Loss: 0.169921 | Test Loss: 0.150221
# Epoch 160/200 | Train Loss: 0.169165 | Test Loss: 0.162424
# Epoch 162/200 | Train Loss: 0.169316 | Test Loss: 0.176051
# Epoch 164/200 | Train Loss: 0.166234 | Test Loss: 0.154600
# Epoch 166/200 | Train Loss: 0.171945 | Test Loss: 0.150894
# Epoch 168/200 | Train Loss: 0.170388 | Test Loss: 0.148184
# Epoch 170/200 | Train Loss: 0.166017 | Test Loss: 0.157335
# Epoch 172/200 | Train Loss: 0.167615 | Test Loss: 0.159643
# Epoch 174/200 | Train Loss: 0.165706 | Test Loss: 0.150445
# Epoch 176/200 | Train Loss: 0.168557 | Test Loss: 0.164555
# Epoch 178/200 | Train Loss: 0.166280 | Test Loss: 0.146901
# Epoch 180/200 | Train Loss: 0.168559 | Test Loss: 0.150070
# Epoch 182/200 | Train Loss: 0.167782 | Test Loss: 0.153711
# Epoch 184/200 | Train Loss: 0.165180 | Test Loss: 0.159412
# Epoch 186/200 | Train Loss: 0.165579 | Test Loss: 0.156582
# Epoch 188/200 | Train Loss: 0.163566 | Test Loss: 0.157656
# Epoch 190/200 | Train Loss: 0.164133 | Test Loss: 0.147783
# Epoch 192/200 | Train Loss: 0.165322 | Test Loss: 0.159522
# Epoch 194/200 | Train Loss: 0.163532 | Test Loss: 0.151810
# Epoch 196/200 | Train Loss: 0.164631 | Test Loss: 0.149279
# Epoch 198/200 | Train Loss: 0.161175 | Test Loss: 0.156574
# Epoch 200/200 | Train Loss: 0.163408 | Test Loss: 0.159194
# Training Completed.
# Training took 45 min 48.7 sec.
# Best test loss: 0.146901 at epoch 178
# y_pred_outputs.shape: (39227, 95) min/max: -75.81722 105.577194
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.39305592 to 3.0296574
# y_pred_outputs.shape: (39227, 95) min/max: -75.81722 105.577194
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -8.712194 to 23.715815
# Number of parameters:
# 158869

# %%
train_losses_6483_256, test_losses_6483_256, model_6483_256, optimizer = train_model(d_model=64, n_heads=8, n_layers=3, d_ff=256, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_6483_256, test_losses_6483_256, d_model=64, n_heads=8, n_layers=3, d_ff=256)

plot_prediction_sample(X_test, y_test, model_6483_256)

for flux_name in diagnostics_to_plot:
    plot_flux(model_6483_256, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_6483_256.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 1.630283 | Test Loss: 1.389902
# Epoch 4/200 | Train Loss: 0.932673 | Test Loss: 0.781359
# Epoch 6/200 | Train Loss: 0.636665 | Test Loss: 0.539327
# Epoch 8/200 | Train Loss: 0.480716 | Test Loss: 0.393169
# Epoch 10/200 | Train Loss: 0.408423 | Test Loss: 0.334888
# Epoch 12/200 | Train Loss: 0.361826 | Test Loss: 0.327626
# Epoch 14/200 | Train Loss: 0.335058 | Test Loss: 0.309032
# Epoch 16/200 | Train Loss: 0.315872 | Test Loss: 0.254826
# Epoch 18/200 | Train Loss: 0.298706 | Test Loss: 0.254478
# Epoch 20/200 | Train Loss: 0.284452 | Test Loss: 0.251145
# Epoch 22/200 | Train Loss: 0.274139 | Test Loss: 0.236444
# Epoch 24/200 | Train Loss: 0.264536 | Test Loss: 0.233704
# Epoch 26/200 | Train Loss: 0.258933 | Test Loss: 0.232190
# Epoch 28/200 | Train Loss: 0.251791 | Test Loss: 0.207506
# Epoch 30/200 | Train Loss: 0.243353 | Test Loss: 0.219218
# Epoch 32/200 | Train Loss: 0.240797 | Test Loss: 0.210635
# Epoch 34/200 | Train Loss: 0.234704 | Test Loss: 0.212833
# Epoch 36/200 | Train Loss: 0.227966 | Test Loss: 0.201111
# Epoch 38/200 | Train Loss: 0.219564 | Test Loss: 0.192226
# Epoch 40/200 | Train Loss: 0.219637 | Test Loss: 0.187937
# Epoch 42/200 | Train Loss: 0.215532 | Test Loss: 0.180568
# Epoch 44/200 | Train Loss: 0.210904 | Test Loss: 0.178983
# Epoch 46/200 | Train Loss: 0.208971 | Test Loss: 0.180018
# Epoch 48/200 | Train Loss: 0.203748 | Test Loss: 0.184068
# Epoch 50/200 | Train Loss: 0.203261 | Test Loss: 0.176416
# Epoch 52/200 | Train Loss: 0.199541 | Test Loss: 0.169835
# Epoch 54/200 | Train Loss: 0.196600 | Test Loss: 0.182043
# Epoch 56/200 | Train Loss: 0.194750 | Test Loss: 0.168338
# Epoch 58/200 | Train Loss: 0.195742 | Test Loss: 0.169851
# Epoch 60/200 | Train Loss: 0.193789 | Test Loss: 0.170356
# Epoch 62/200 | Train Loss: 0.192262 | Test Loss: 0.167838
# Epoch 64/200 | Train Loss: 0.191454 | Test Loss: 0.161167
# Epoch 66/200 | Train Loss: 0.185582 | Test Loss: 0.157790
# Epoch 68/200 | Train Loss: 0.189601 | Test Loss: 0.166692
# Epoch 70/200 | Train Loss: 0.185957 | Test Loss: 0.173570
# Epoch 72/200 | Train Loss: 0.186850 | Test Loss: 0.177459
# Epoch 74/200 | Train Loss: 0.184223 | Test Loss: 0.163691
# Epoch 76/200 | Train Loss: 0.185120 | Test Loss: 0.162989
# Epoch 78/200 | Train Loss: 0.181470 | Test Loss: 0.179395
# Epoch 80/200 | Train Loss: 0.182726 | Test Loss: 0.158113
# Epoch 82/200 | Train Loss: 0.181283 | Test Loss: 0.155726
# Epoch 84/200 | Train Loss: 0.177949 | Test Loss: 0.158114
# Epoch 86/200 | Train Loss: 0.179919 | Test Loss: 0.151638
# Epoch 88/200 | Train Loss: 0.179045 | Test Loss: 0.160505
# Epoch 90/200 | Train Loss: 0.178785 | Test Loss: 0.156099
# Epoch 92/200 | Train Loss: 0.177010 | Test Loss: 0.153460
# Epoch 94/200 | Train Loss: 0.176773 | Test Loss: 0.159936
# Epoch 96/200 | Train Loss: 0.176010 | Test Loss: 0.170436
# Epoch 98/200 | Train Loss: 0.175761 | Test Loss: 0.154117
# Epoch 100/200 | Train Loss: 0.172411 | Test Loss: 0.160271
# Epoch 102/200 | Train Loss: 0.172272 | Test Loss: 0.158370
# Epoch 104/200 | Train Loss: 0.172722 | Test Loss: 0.156022
# Epoch 106/200 | Train Loss: 0.171161 | Test Loss: 0.153135
# Epoch 108/200 | Train Loss: 0.170334 | Test Loss: 0.145589
# Epoch 110/200 | Train Loss: 0.174551 | Test Loss: 0.162459
# Epoch 112/200 | Train Loss: 0.171770 | Test Loss: 0.166493
# Epoch 114/200 | Train Loss: 0.170271 | Test Loss: 0.147770
# Epoch 116/200 | Train Loss: 0.172900 | Test Loss: 0.155053
# Epoch 118/200 | Train Loss: 0.170783 | Test Loss: 0.156566
# Epoch 120/200 | Train Loss: 0.169275 | Test Loss: 0.157503
# Epoch 122/200 | Train Loss: 0.166538 | Test Loss: 0.157659
# Epoch 124/200 | Train Loss: 0.168782 | Test Loss: 0.156326
# Epoch 126/200 | Train Loss: 0.166765 | Test Loss: 0.154271
# Epoch 128/200 | Train Loss: 0.169486 | Test Loss: 0.149970
# Epoch 130/200 | Train Loss: 0.166821 | Test Loss: 0.148811
# Epoch 132/200 | Train Loss: 0.166796 | Test Loss: 0.152032
# Epoch 134/200 | Train Loss: 0.167840 | Test Loss: 0.151623
# Epoch 136/200 | Train Loss: 0.165401 | Test Loss: 0.145722
# Epoch 138/200 | Train Loss: 0.167510 | Test Loss: 0.153186
# Epoch 140/200 | Train Loss: 0.166615 | Test Loss: 0.151514
# Epoch 142/200 | Train Loss: 0.165066 | Test Loss: 0.146322
# Epoch 144/200 | Train Loss: 0.163541 | Test Loss: 0.145266
# Epoch 146/200 | Train Loss: 0.165075 | Test Loss: 0.148599
# Epoch 148/200 | Train Loss: 0.161720 | Test Loss: 0.142799
# Epoch 150/200 | Train Loss: 0.159631 | Test Loss: 0.150180
# Epoch 152/200 | Train Loss: 0.161694 | Test Loss: 0.169291
# Epoch 154/200 | Train Loss: 0.163915 | Test Loss: 0.153669
# Epoch 156/200 | Train Loss: 0.164385 | Test Loss: 0.145661
# Epoch 158/200 | Train Loss: 0.161801 | Test Loss: 0.145736
# Epoch 160/200 | Train Loss: 0.164990 | Test Loss: 0.148364
# Epoch 162/200 | Train Loss: 0.163246 | Test Loss: 0.146735
# Epoch 164/200 | Train Loss: 0.163418 | Test Loss: 0.144235
# Epoch 166/200 | Train Loss: 0.159339 | Test Loss: 0.148933
# Epoch 168/200 | Train Loss: 0.164062 | Test Loss: 0.147023
# Epoch 170/200 | Train Loss: 0.163260 | Test Loss: 0.145410
# Epoch 172/200 | Train Loss: 0.163225 | Test Loss: 0.144029
# Epoch 174/200 | Train Loss: 0.160113 | Test Loss: 0.144771
# Epoch 176/200 | Train Loss: 0.157565 | Test Loss: 0.148128
# Epoch 178/200 | Train Loss: 0.159765 | Test Loss: 0.157586
# Epoch 180/200 | Train Loss: 0.159120 | Test Loss: 0.141530
# Epoch 182/200 | Train Loss: 0.157304 | Test Loss: 0.144468
# Epoch 184/200 | Train Loss: 0.160890 | Test Loss: 0.149404
# Epoch 186/200 | Train Loss: 0.159347 | Test Loss: 0.143793
# Epoch 188/200 | Train Loss: 0.160803 | Test Loss: 0.149315
# Epoch 190/200 | Train Loss: 0.158607 | Test Loss: 0.144890
# Epoch 192/200 | Train Loss: 0.156113 | Test Loss: 0.139066
# Epoch 194/200 | Train Loss: 0.158535 | Test Loss: 0.142034
# Epoch 196/200 | Train Loss: 0.159446 | Test Loss: 0.143182
# Epoch 198/200 | Train Loss: 0.158933 | Test Loss: 0.140461
# Epoch 200/200 | Train Loss: 0.156411 | Test Loss: 0.143532
# Training Completed.
# Training took 58 min 50.7 sec.
# Best test loss: 0.137687 at epoch 195
# y_pred_outputs.shape: (39227, 95) min/max: -77.897964 107.84478
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.024005577 to 2.3562827
# y_pred_outputs.shape: (39227, 95) min/max: -77.897964 107.84478
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -9.568654 to 24.075912
# Number of parameters:
# 158881

# %%
train_losses_6483_512, test_losses_6483_512, model_6483_512, optimizer = train_model(d_model=64, n_heads=8, n_layers=3, d_ff=512, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_6483_512, test_losses_6483_512, d_model=64, n_heads=8, n_layers=3, d_ff=512)

plot_prediction_sample(X_test, y_test, model_6483_512)

for flux_name in diagnostics_to_plot:
    plot_flux(model_6483_512, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_6483_512.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 1.255972 | Test Loss: 1.041370
# Epoch 4/200 | Train Loss: 0.734520 | Test Loss: 0.617238
# Epoch 6/200 | Train Loss: 0.564100 | Test Loss: 0.467028
# Epoch 8/200 | Train Loss: 0.460718 | Test Loss: 0.386354
# Epoch 10/200 | Train Loss: 0.394205 | Test Loss: 0.378887
# Epoch 12/200 | Train Loss: 0.360638 | Test Loss: 0.321266
# Epoch 14/200 | Train Loss: 0.333667 | Test Loss: 0.277896
# Epoch 16/200 | Train Loss: 0.307097 | Test Loss: 0.261452
# Epoch 18/200 | Train Loss: 0.296294 | Test Loss: 0.245312
# Epoch 20/200 | Train Loss: 0.286238 | Test Loss: 0.265062
# Epoch 22/200 | Train Loss: 0.271873 | Test Loss: 0.247149
# Epoch 24/200 | Train Loss: 0.262219 | Test Loss: 0.218462
# Epoch 26/200 | Train Loss: 0.253209 | Test Loss: 0.247727
# Epoch 28/200 | Train Loss: 0.243462 | Test Loss: 0.226006
# Epoch 30/200 | Train Loss: 0.239478 | Test Loss: 0.222978
# Epoch 32/200 | Train Loss: 0.232193 | Test Loss: 0.196601
# Epoch 34/200 | Train Loss: 0.227858 | Test Loss: 0.197506
# Epoch 36/200 | Train Loss: 0.223345 | Test Loss: 0.207098
# Epoch 38/200 | Train Loss: 0.217560 | Test Loss: 0.203270
# Epoch 40/200 | Train Loss: 0.214996 | Test Loss: 0.203214
# Epoch 42/200 | Train Loss: 0.209797 | Test Loss: 0.179376
# Epoch 44/200 | Train Loss: 0.208718 | Test Loss: 0.184943
# Epoch 46/200 | Train Loss: 0.205060 | Test Loss: 0.193155
# Epoch 48/200 | Train Loss: 0.202339 | Test Loss: 0.180833
# Epoch 50/200 | Train Loss: 0.203675 | Test Loss: 0.192370
# Epoch 52/200 | Train Loss: 0.199322 | Test Loss: 0.191231
# Epoch 54/200 | Train Loss: 0.193962 | Test Loss: 0.166407
# Epoch 56/200 | Train Loss: 0.194519 | Test Loss: 0.174864
# Epoch 58/200 | Train Loss: 0.193723 | Test Loss: 0.179634
# Epoch 60/200 | Train Loss: 0.191353 | Test Loss: 0.183159
# Epoch 62/200 | Train Loss: 0.189684 | Test Loss: 0.160051
# Epoch 64/200 | Train Loss: 0.191697 | Test Loss: 0.169916
# Epoch 66/200 | Train Loss: 0.190508 | Test Loss: 0.164866
# Epoch 68/200 | Train Loss: 0.183346 | Test Loss: 0.164632
# Epoch 70/200 | Train Loss: 0.181750 | Test Loss: 0.165373
# Epoch 72/200 | Train Loss: 0.180919 | Test Loss: 0.167220
# Epoch 74/200 | Train Loss: 0.180027 | Test Loss: 0.154355
# Epoch 76/200 | Train Loss: 0.178951 | Test Loss: 0.167265
# Epoch 78/200 | Train Loss: 0.181652 | Test Loss: 0.155847
# Epoch 80/200 | Train Loss: 0.183649 | Test Loss: 0.155380
# Epoch 82/200 | Train Loss: 0.177676 | Test Loss: 0.156813
# Epoch 84/200 | Train Loss: 0.176942 | Test Loss: 0.159050
# Epoch 86/200 | Train Loss: 0.176357 | Test Loss: 0.163236
# Epoch 88/200 | Train Loss: 0.177167 | Test Loss: 0.175729
# Epoch 90/200 | Train Loss: 0.173198 | Test Loss: 0.158611
# Epoch 92/200 | Train Loss: 0.171434 | Test Loss: 0.168394
# Epoch 94/200 | Train Loss: 0.175881 | Test Loss: 0.161478
# Epoch 96/200 | Train Loss: 0.174753 | Test Loss: 0.151919
# Epoch 98/200 | Train Loss: 0.171947 | Test Loss: 0.153776
# Epoch 100/200 | Train Loss: 0.173082 | Test Loss: 0.158191
# Epoch 102/200 | Train Loss: 0.173700 | Test Loss: 0.155351
# Epoch 104/200 | Train Loss: 0.171117 | Test Loss: 0.152351
# Epoch 106/200 | Train Loss: 0.172100 | Test Loss: 0.163689
# Epoch 108/200 | Train Loss: 0.172305 | Test Loss: 0.154646
# Epoch 110/200 | Train Loss: 0.169179 | Test Loss: 0.151163
# Epoch 112/200 | Train Loss: 0.167594 | Test Loss: 0.159087
# Epoch 114/200 | Train Loss: 0.166417 | Test Loss: 0.152235
# Epoch 116/200 | Train Loss: 0.165183 | Test Loss: 0.145680
# Epoch 118/200 | Train Loss: 0.164868 | Test Loss: 0.164045
# Epoch 120/200 | Train Loss: 0.163850 | Test Loss: 0.154680
# Epoch 122/200 | Train Loss: 0.164545 | Test Loss: 0.154105
# Epoch 124/200 | Train Loss: 0.163325 | Test Loss: 0.153846
# Epoch 126/200 | Train Loss: 0.163846 | Test Loss: 0.149287
# Epoch 128/200 | Train Loss: 0.161586 | Test Loss: 0.145699
# Epoch 130/200 | Train Loss: 0.164916 | Test Loss: 0.149655
# Epoch 132/200 | Train Loss: 0.164887 | Test Loss: 0.158789
# Epoch 134/200 | Train Loss: 0.160935 | Test Loss: 0.144258
# Epoch 136/200 | Train Loss: 0.164579 | Test Loss: 0.148672
# Epoch 138/200 | Train Loss: 0.160934 | Test Loss: 0.146359
# Epoch 140/200 | Train Loss: 0.162271 | Test Loss: 0.153857
# Epoch 142/200 | Train Loss: 0.160500 | Test Loss: 0.156157
# Epoch 144/200 | Train Loss: 0.162479 | Test Loss: 0.148803
# Epoch 146/200 | Train Loss: 0.162455 | Test Loss: 0.153552
# Epoch 148/200 | Train Loss: 0.162916 | Test Loss: 0.160369
# Epoch 150/200 | Train Loss: 0.161812 | Test Loss: 0.152440
# Epoch 152/200 | Train Loss: 0.157606 | Test Loss: 0.144219
# Epoch 154/200 | Train Loss: 0.158869 | Test Loss: 0.149450
# Epoch 156/200 | Train Loss: 0.157578 | Test Loss: 0.160072
# Epoch 158/200 | Train Loss: 0.157647 | Test Loss: 0.145783
# Epoch 160/200 | Train Loss: 0.160991 | Test Loss: 0.149569
# Epoch 162/200 | Train Loss: 0.158028 | Test Loss: 0.155171
# Epoch 164/200 | Train Loss: 0.155781 | Test Loss: 0.148705
# Epoch 166/200 | Train Loss: 0.155185 | Test Loss: 0.151840
# Epoch 168/200 | Train Loss: 0.155978 | Test Loss: 0.145475
# Epoch 170/200 | Train Loss: 0.155151 | Test Loss: 0.156072
# Epoch 172/200 | Train Loss: 0.157140 | Test Loss: 0.148121
# Epoch 174/200 | Train Loss: 0.156525 | Test Loss: 0.150643
# Epoch 176/200 | Train Loss: 0.157515 | Test Loss: 0.168198
# Epoch 178/200 | Train Loss: 0.156581 | Test Loss: 0.147783
# Epoch 180/200 | Train Loss: 0.152960 | Test Loss: 0.146598
# Epoch 182/200 | Train Loss: 0.155711 | Test Loss: 0.146045
# Epoch 184/200 | Train Loss: 0.152262 | Test Loss: 0.143996
# Epoch 186/200 | Train Loss: 0.150805 | Test Loss: 0.144037
# Epoch 188/200 | Train Loss: 0.156947 | Test Loss: 0.146038
# Epoch 190/200 | Train Loss: 0.154802 | Test Loss: 0.149077
# Epoch 192/200 | Train Loss: 0.155114 | Test Loss: 0.141636
# Epoch 194/200 | Train Loss: 0.152017 | Test Loss: 0.151429
# Epoch 196/200 | Train Loss: 0.152528 | Test Loss: 0.148087
# Epoch 198/200 | Train Loss: 0.152790 | Test Loss: 0.145203
# Epoch 200/200 | Train Loss: 0.152628 | Test Loss: 0.145634
# Training Completed.
# Training took 66 min 25.8 sec.
# Best test loss: 0.136393 at epoch 185
# y_pred_outputs.shape: (39227, 95) min/max: -76.20813 107.79582
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.18251562 to 2.4683032
# y_pred_outputs.shape: (39227, 95) min/max: -76.20813 107.79582
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -10.289657 to 24.153513
# Number of parameters:
# 259489

# %%
train_losses_12842_512, test_losses_12842_512, model_12842_512, optimizer = train_model(d_model=128, n_heads=4, n_layers=2, d_ff=512, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_12842_512, test_losses_12842_512, d_model=128, n_heads=4, n_layers=2, d_ff=512)

plot_prediction_sample(X_test, y_test, model_12842_512)

for flux_name in diagnostics_to_plot:
    plot_flux(model_12842_512, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_12842_512.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 0.920391 | Test Loss: 0.773724
# Epoch 4/200 | Train Loss: 0.594626 | Test Loss: 0.496883
# Epoch 6/200 | Train Loss: 0.503182 | Test Loss: 0.441715
# Epoch 8/200 | Train Loss: 0.457559 | Test Loss: 0.423089
# Epoch 10/200 | Train Loss: 0.409934 | Test Loss: 0.365165
# Epoch 12/200 | Train Loss: 0.379381 | Test Loss: 0.338448
# Epoch 14/200 | Train Loss: 0.355359 | Test Loss: 0.301311
# Epoch 16/200 | Train Loss: 0.340051 | Test Loss: 0.305504
# Epoch 18/200 | Train Loss: 0.331992 | Test Loss: 0.322694
# Epoch 20/200 | Train Loss: 0.315872 | Test Loss: 0.282506
# Epoch 22/200 | Train Loss: 0.313173 | Test Loss: 0.273741
# Epoch 24/200 | Train Loss: 0.307353 | Test Loss: 0.264449
# Epoch 26/200 | Train Loss: 0.296990 | Test Loss: 0.257174
# Epoch 28/200 | Train Loss: 0.290427 | Test Loss: 0.252923
# Epoch 30/200 | Train Loss: 0.281494 | Test Loss: 0.249818
# Epoch 32/200 | Train Loss: 0.277957 | Test Loss: 0.239518
# Epoch 34/200 | Train Loss: 0.272211 | Test Loss: 0.251896
# Epoch 36/200 | Train Loss: 0.266013 | Test Loss: 0.238305
# Epoch 38/200 | Train Loss: 0.265500 | Test Loss: 0.236042
# Epoch 40/200 | Train Loss: 0.260426 | Test Loss: 0.231118
# Epoch 42/200 | Train Loss: 0.254877 | Test Loss: 0.232035
# Epoch 44/200 | Train Loss: 0.255441 | Test Loss: 0.229097
# Epoch 46/200 | Train Loss: 0.250458 | Test Loss: 0.233121
# Epoch 48/200 | Train Loss: 0.253809 | Test Loss: 0.207464
# Epoch 50/200 | Train Loss: 0.247000 | Test Loss: 0.214563
# Epoch 52/200 | Train Loss: 0.245387 | Test Loss: 0.228791
# Epoch 54/200 | Train Loss: 0.241806 | Test Loss: 0.207669
# Epoch 56/200 | Train Loss: 0.244466 | Test Loss: 0.225839
# Epoch 58/200 | Train Loss: 0.237581 | Test Loss: 0.213249
# Epoch 60/200 | Train Loss: 0.238293 | Test Loss: 0.211136
# Epoch 62/200 | Train Loss: 0.235499 | Test Loss: 0.216511
# Epoch 64/200 | Train Loss: 0.233056 | Test Loss: 0.210608
# Epoch 66/200 | Train Loss: 0.235040 | Test Loss: 0.204094
# Epoch 68/200 | Train Loss: 0.231031 | Test Loss: 0.200910
# Epoch 70/200 | Train Loss: 0.230497 | Test Loss: 0.204592
# Epoch 72/200 | Train Loss: 0.227624 | Test Loss: 0.202451
# Epoch 74/200 | Train Loss: 0.229866 | Test Loss: 0.197543
# Epoch 76/200 | Train Loss: 0.227231 | Test Loss: 0.202031
# Epoch 78/200 | Train Loss: 0.225076 | Test Loss: 0.197614
# Epoch 80/200 | Train Loss: 0.225291 | Test Loss: 0.193714
# Epoch 82/200 | Train Loss: 0.222542 | Test Loss: 0.201934
# Epoch 84/200 | Train Loss: 0.221920 | Test Loss: 0.188069
# Epoch 86/200 | Train Loss: 0.216220 | Test Loss: 0.201116
# Epoch 88/200 | Train Loss: 0.220600 | Test Loss: 0.204758
# Epoch 90/200 | Train Loss: 0.217338 | Test Loss: 0.196908
# Epoch 92/200 | Train Loss: 0.213796 | Test Loss: 0.189716
# Epoch 94/200 | Train Loss: 0.214650 | Test Loss: 0.186732
# Epoch 96/200 | Train Loss: 0.210178 | Test Loss: 0.189936
# Epoch 98/200 | Train Loss: 0.211194 | Test Loss: 0.184874
# Epoch 100/200 | Train Loss: 0.214531 | Test Loss: 0.185411
# Epoch 102/200 | Train Loss: 0.213288 | Test Loss: 0.199458
# Epoch 104/200 | Train Loss: 0.209394 | Test Loss: 0.186485
# Epoch 106/200 | Train Loss: 0.205303 | Test Loss: 0.185333
# Epoch 108/200 | Train Loss: 0.208247 | Test Loss: 0.183398
# Epoch 110/200 | Train Loss: 0.205941 | Test Loss: 0.183464
# Epoch 112/200 | Train Loss: 0.209242 | Test Loss: 0.189286
# Epoch 114/200 | Train Loss: 0.207367 | Test Loss: 0.193111
# Epoch 116/200 | Train Loss: 0.204653 | Test Loss: 0.178436
# Epoch 118/200 | Train Loss: 0.204033 | Test Loss: 0.187193
# Epoch 120/200 | Train Loss: 0.204042 | Test Loss: 0.182847
# Epoch 122/200 | Train Loss: 0.202550 | Test Loss: 0.176737
# Epoch 124/200 | Train Loss: 0.203360 | Test Loss: 0.192546
# Epoch 126/200 | Train Loss: 0.200395 | Test Loss: 0.181072
# Epoch 128/200 | Train Loss: 0.197545 | Test Loss: 0.180183
# Epoch 130/200 | Train Loss: 0.202571 | Test Loss: 0.181460
# Epoch 132/200 | Train Loss: 0.203404 | Test Loss: 0.175725
# Epoch 134/200 | Train Loss: 0.201854 | Test Loss: 0.180139
# Epoch 136/200 | Train Loss: 0.198571 | Test Loss: 0.177109
# Epoch 138/200 | Train Loss: 0.197455 | Test Loss: 0.174062
# Epoch 140/200 | Train Loss: 0.197396 | Test Loss: 0.172569
# Epoch 142/200 | Train Loss: 0.195092 | Test Loss: 0.170779
# Epoch 144/200 | Train Loss: 0.195223 | Test Loss: 0.172682
# Epoch 146/200 | Train Loss: 0.192541 | Test Loss: 0.176789
# Epoch 148/200 | Train Loss: 0.193738 | Test Loss: 0.168984
# Epoch 150/200 | Train Loss: 0.191596 | Test Loss: 0.170473
# Epoch 152/200 | Train Loss: 0.194326 | Test Loss: 0.173293
# Epoch 154/200 | Train Loss: 0.191145 | Test Loss: 0.176603
# Epoch 156/200 | Train Loss: 0.194167 | Test Loss: 0.175061
# Epoch 158/200 | Train Loss: 0.191397 | Test Loss: 0.168129
# Epoch 160/200 | Train Loss: 0.192338 | Test Loss: 0.178175
# Epoch 162/200 | Train Loss: 0.190461 | Test Loss: 0.169998
# Epoch 164/200 | Train Loss: 0.188192 | Test Loss: 0.176254
# Epoch 166/200 | Train Loss: 0.190254 | Test Loss: 0.171468
# Epoch 168/200 | Train Loss: 0.188017 | Test Loss: 0.169717
# Epoch 170/200 | Train Loss: 0.188240 | Test Loss: 0.169729
# Epoch 172/200 | Train Loss: 0.188566 | Test Loss: 0.174451
# Epoch 174/200 | Train Loss: 0.186921 | Test Loss: 0.171798
# Epoch 176/200 | Train Loss: 0.189122 | Test Loss: 0.167189
# Epoch 178/200 | Train Loss: 0.185845 | Test Loss: 0.171641
# Epoch 180/200 | Train Loss: 0.183805 | Test Loss: 0.167053
# Epoch 182/200 | Train Loss: 0.185773 | Test Loss: 0.168862
# Epoch 184/200 | Train Loss: 0.187008 | Test Loss: 0.170068
# Epoch 186/200 | Train Loss: 0.183091 | Test Loss: 0.166045
# Epoch 188/200 | Train Loss: 0.187315 | Test Loss: 0.167293
# Epoch 190/200 | Train Loss: 0.183904 | Test Loss: 0.165422
# Epoch 192/200 | Train Loss: 0.184122 | Test Loss: 0.173033
# Epoch 194/200 | Train Loss: 0.185740 | Test Loss: 0.161916
# Epoch 196/200 | Train Loss: 0.183088 | Test Loss: 0.166090
# Epoch 198/200 | Train Loss: 0.187170 | Test Loss: 0.168205
# Epoch 200/200 | Train Loss: 0.185769 | Test Loss: 0.169178
# Training Completed.
# Training took 49 min 39.1 sec.
# Best test loss: 0.161916 at epoch 194
# y_pred_outputs.shape: (39227, 95) min/max: -75.780365 109.90796
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.113545835 to 2.4035203
# y_pred_outputs.shape: (39227, 95) min/max: -75.780365 109.90796
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -7.7539487 to 24.330032
# Number of parameters:
# 413326

# %%
train_losses_12843_512, test_losses_12843_512, model_12843_512, optimizer = train_model(d_model=128, n_heads=4, n_layers=3, d_ff=512, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_12843_512, test_losses_12843_512, d_model=128, n_heads=4, n_layers=3, d_ff=512)

plot_prediction_sample(X_test, y_test, model_12843_512)

for flux_name in diagnostics_to_plot:
    plot_flux(model_12843_512, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_12843_512.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 0.809743 | Test Loss: 0.582395
# Epoch 4/200 | Train Loss: 0.435811 | Test Loss: 0.391957
# Epoch 6/200 | Train Loss: 0.361699 | Test Loss: 0.298738
# Epoch 8/200 | Train Loss: 0.314277 | Test Loss: 0.252358
# Epoch 10/200 | Train Loss: 0.289112 | Test Loss: 0.250879
# Epoch 12/200 | Train Loss: 0.270998 | Test Loss: 0.241845
# Epoch 14/200 | Train Loss: 0.255914 | Test Loss: 0.225796
# Epoch 16/200 | Train Loss: 0.246251 | Test Loss: 0.256077
# Epoch 18/200 | Train Loss: 0.235720 | Test Loss: 0.202519
# Epoch 20/200 | Train Loss: 0.230249 | Test Loss: 0.211433
# Epoch 22/200 | Train Loss: 0.224379 | Test Loss: 0.199826
# Epoch 24/200 | Train Loss: 0.218254 | Test Loss: 0.196097
# Epoch 26/200 | Train Loss: 0.211907 | Test Loss: 0.183709
# Epoch 28/200 | Train Loss: 0.208046 | Test Loss: 0.189000
# Epoch 30/200 | Train Loss: 0.205963 | Test Loss: 0.193035
# Epoch 32/200 | Train Loss: 0.201359 | Test Loss: 0.195794
# Epoch 34/200 | Train Loss: 0.195792 | Test Loss: 0.177975
# Epoch 36/200 | Train Loss: 0.193703 | Test Loss: 0.188244
# Epoch 38/200 | Train Loss: 0.188748 | Test Loss: 0.172958
# Epoch 40/200 | Train Loss: 0.191470 | Test Loss: 0.176030
# Epoch 42/200 | Train Loss: 0.188298 | Test Loss: 0.171240
# Epoch 44/200 | Train Loss: 0.185993 | Test Loss: 0.163961
# Epoch 46/200 | Train Loss: 0.182447 | Test Loss: 0.166530
# Epoch 48/200 | Train Loss: 0.184912 | Test Loss: 0.162028
# Epoch 50/200 | Train Loss: 0.181867 | Test Loss: 0.164053
# Epoch 52/200 | Train Loss: 0.178891 | Test Loss: 0.163442
# Epoch 54/200 | Train Loss: 0.178806 | Test Loss: 0.166981
# Epoch 56/200 | Train Loss: 0.175784 | Test Loss: 0.158844
# Epoch 58/200 | Train Loss: 0.176947 | Test Loss: 0.162904
# Epoch 60/200 | Train Loss: 0.173842 | Test Loss: 0.162610
# Epoch 62/200 | Train Loss: 0.172523 | Test Loss: 0.149809
# Epoch 64/200 | Train Loss: 0.171566 | Test Loss: 0.162254
# Epoch 66/200 | Train Loss: 0.172785 | Test Loss: 0.159058
# Epoch 68/200 | Train Loss: 0.170591 | Test Loss: 0.163100
# Epoch 70/200 | Train Loss: 0.171396 | Test Loss: 0.155486
# Epoch 72/200 | Train Loss: 0.170347 | Test Loss: 0.166594
# Epoch 74/200 | Train Loss: 0.166172 | Test Loss: 0.171938
# Epoch 76/200 | Train Loss: 0.171056 | Test Loss: 0.172164
# Epoch 78/200 | Train Loss: 0.168377 | Test Loss: 0.155427
# Epoch 80/200 | Train Loss: 0.166941 | Test Loss: 0.153237
# Epoch 82/200 | Train Loss: 0.164609 | Test Loss: 0.153367
# Epoch 84/200 | Train Loss: 0.163729 | Test Loss: 0.158941
# Epoch 86/200 | Train Loss: 0.163014 | Test Loss: 0.161660
# Epoch 88/200 | Train Loss: 0.164093 | Test Loss: 0.154352
# Epoch 90/200 | Train Loss: 0.162154 | Test Loss: 0.153534
# Epoch 92/200 | Train Loss: 0.160796 | Test Loss: 0.151427
# Epoch 94/200 | Train Loss: 0.162364 | Test Loss: 0.155965
# Epoch 96/200 | Train Loss: 0.165163 | Test Loss: 0.159953
# Epoch 98/200 | Train Loss: 0.160954 | Test Loss: 0.152114
# Epoch 100/200 | Train Loss: 0.159356 | Test Loss: 0.150878
# Epoch 102/200 | Train Loss: 0.159723 | Test Loss: 0.159529
# Epoch 104/200 | Train Loss: 0.158278 | Test Loss: 0.176118
# Epoch 106/200 | Train Loss: 0.159046 | Test Loss: 0.146107
# Epoch 108/200 | Train Loss: 0.162259 | Test Loss: 0.146399
# Epoch 110/200 | Train Loss: 0.157641 | Test Loss: 0.148048
# Epoch 112/200 | Train Loss: 0.157815 | Test Loss: 0.147736
# Epoch 114/200 | Train Loss: 0.156533 | Test Loss: 0.149062
# Epoch 116/200 | Train Loss: 0.154603 | Test Loss: 0.155034
# Epoch 118/200 | Train Loss: 0.160139 | Test Loss: 0.152259
# Epoch 120/200 | Train Loss: 0.153766 | Test Loss: 0.146583
# Epoch 122/200 | Train Loss: 0.154351 | Test Loss: 0.154949
# Epoch 124/200 | Train Loss: 0.153461 | Test Loss: 0.158830
# Epoch 126/200 | Train Loss: 0.153080 | Test Loss: 0.150447
# Epoch 128/200 | Train Loss: 0.153488 | Test Loss: 0.145852
# Epoch 130/200 | Train Loss: 0.155007 | Test Loss: 0.148970
# Epoch 132/200 | Train Loss: 0.153328 | Test Loss: 0.152044
# Epoch 134/200 | Train Loss: 0.151757 | Test Loss: 0.147639
# Epoch 136/200 | Train Loss: 0.152528 | Test Loss: 0.148387
# Epoch 138/200 | Train Loss: 0.153717 | Test Loss: 0.152407
# Epoch 140/200 | Train Loss: 0.151200 | Test Loss: 0.150621
# Epoch 142/200 | Train Loss: 0.152821 | Test Loss: 0.147365
# Epoch 144/200 | Train Loss: 0.151283 | Test Loss: 0.144099
# Epoch 146/200 | Train Loss: 0.148655 | Test Loss: 0.143744
# Epoch 148/200 | Train Loss: 0.150453 | Test Loss: 0.143304
# Epoch 150/200 | Train Loss: 0.148690 | Test Loss: 0.150181
# Epoch 152/200 | Train Loss: 0.152761 | Test Loss: 0.143385
# Epoch 154/200 | Train Loss: 0.150539 | Test Loss: 0.144997
# Epoch 156/200 | Train Loss: 0.151366 | Test Loss: 0.149098
# Epoch 158/200 | Train Loss: 0.146859 | Test Loss: 0.148622
# Epoch 160/200 | Train Loss: 0.148705 | Test Loss: 0.144613
# Epoch 162/200 | Train Loss: 0.148174 | Test Loss: 0.149888
# Epoch 164/200 | Train Loss: 0.145747 | Test Loss: 0.151404
# Epoch 166/200 | Train Loss: 0.148380 | Test Loss: 0.151192
# Epoch 168/200 | Train Loss: 0.147526 | Test Loss: 0.142436
# Epoch 170/200 | Train Loss: 0.145169 | Test Loss: 0.143012
# Epoch 172/200 | Train Loss: 0.147944 | Test Loss: 0.147089
# Epoch 174/200 | Train Loss: 0.147775 | Test Loss: 0.144943
# Epoch 176/200 | Train Loss: 0.146509 | Test Loss: 0.145782
# Epoch 178/200 | Train Loss: 0.145288 | Test Loss: 0.146175
# Epoch 180/200 | Train Loss: 0.146152 | Test Loss: 0.143480
# Epoch 182/200 | Train Loss: 0.144442 | Test Loss: 0.151083
# Epoch 184/200 | Train Loss: 0.142147 | Test Loss: 0.147535
# Epoch 186/200 | Train Loss: 0.144028 | Test Loss: 0.144089
# Epoch 188/200 | Train Loss: 0.145429 | Test Loss: 0.149171
# Epoch 190/200 | Train Loss: 0.145898 | Test Loss: 0.145671
# Epoch 192/200 | Train Loss: 0.142102 | Test Loss: 0.142328
# Epoch 194/200 | Train Loss: 0.144639 | Test Loss: 0.144284
# Epoch 196/200 | Train Loss: 0.146636 | Test Loss: 0.146815
# Epoch 198/200 | Train Loss: 0.143778 | Test Loss: 0.146996
# Epoch 200/200 | Train Loss: 0.147192 | Test Loss: 0.143153
# Training Completed.
# Training took 70 min 29.3 sec.
# Best test loss: 0.140832 at epoch 181
# y_pred_outputs.shape: (39227, 95) min/max: -77.58652 108.84718
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# Biomass_Ecoli_core_flux index in outputs: 12
# y_true_outputs[:, idx] range: 4.0233743e-05 to 2.649993
# y_pred_outputs[:, _idx] range: -0.110735595 to 2.5151885
# y_pred_outputs.shape: (39227, 95) min/max: -77.58652 108.84718
# y_true_outputs.shape: (39227, 95) min/max: -80.44448 109.14731
# GLUDy_flux index in outputs: 52
# y_true_outputs[:, idx] range: -10.018521 to 49.970127
# y_pred_outputs[:, _idx] range: -10.18199 to 24.880785
# Number of parameters:
# 612629

# %%
train_losses_12883_512, test_losses_12883_512, model_12883_512, optimizer = train_model(d_model=128, n_heads=8, n_layers=3, d_ff=512, num_epochs=num_epochs, dropout=dropout)

plot_loss_curves(train_losses_12883_512, test_losses_12883_512, d_model=128, n_heads=8, n_layers=3, d_ff=512)

plot_prediction_sample(X_test, y_test, model_12883_512)

for flux_name in diagnostics_to_plot:
    plot_flux(model_12883_512, X_test, y_test, output_cols, flux_name)

print('Number of parameters:')
print(sum( p.numel() for p in model_12883_512.parameters() if p.requires_grad ))
# Out:
# Epoch 2/200 | Train Loss: 0.868964 | Test Loss: 0.639275
# Epoch 4/200 | Train Loss: 0.413566 | Test Loss: 0.350637
# Epoch 6/200 | Train Loss: 0.330754 | Test Loss: 0.267428
# Epoch 8/200 | Train Loss: 0.290138 | Test Loss: 0.244037
# Epoch 10/200 | Train Loss: 0.259770 | Test Loss: 0.227251
# Epoch 12/200 | Train Loss: 0.245131 | Test Loss: 0.226367
# Epoch 14/200 | Train Loss: 0.233087 | Test Loss: 0.226378
# Epoch 16/200 | Train Loss: 0.221615 | Test Loss: 0.216180
# Epoch 18/200 | Train Loss: 0.214612 | Test Loss: 0.200180
# Epoch 20/200 | Train Loss: 0.212365 | Test Loss: 0.190732
# Epoch 22/200 | Train Loss: 0.204763 | Test Loss: 0.180165
# Epoch 24/200 | Train Loss: 0.199359 | Test Loss: 0.173949
# Epoch 26/200 | Train Loss: 0.193062 | Test Loss: 0.169869
# Epoch 28/200 | Train Loss: 0.194628 | Test Loss: 0.187904
# Epoch 30/200 | Train Loss: 0.189256 | Test Loss: 0.179377
# Epoch 32/200 | Train Loss: 0.188947 | Test Loss: 0.171027
# Epoch 34/200 | Train Loss: 0.183309 | Test Loss: 0.169889
# Epoch 36/200 | Train Loss: 0.182667 | Test Loss: 0.191466
# Epoch 38/200 | Train Loss: 0.183699 | Test Loss: 0.168690
# Epoch 40/200 | Train Loss: 0.177086 | Test Loss: 0.158475
# Epoch 42/200 | Train Loss: 0.175980 | Test Loss: 0.155758
# Epoch 44/200 | Train Loss: 0.172948 | Test Loss: 0.154883
# Epoch 46/200 | Train Loss: 0.172456 | Test Loss: 0.156220
# Epoch 48/200 | Train Loss: 0.172920 | Test Loss: 0.160050
# Epoch 50/200 | Train Loss: 0.173992 | Test Loss: 0.159815
# Epoch 52/200 | Train Loss: 0.170556 | Test Loss: 0.153554
# Epoch 54/200 | Train Loss: 0.170984 | Test Loss: 0.155142
# Epoch 56/200 | Train Loss: 0.169354 | Test Loss: 0.160532
# Epoch 58/200 | Train Loss: 0.164647 | Test Loss: 0.150133
# Epoch 60/200 | Train Loss: 0.166923 | Test Loss: 0.159803
# Epoch 62/200 | Train Loss: 0.166397 | Test Loss: 0.150841
# Epoch 64/200 | Train Loss: 0.164062 | Test Loss: 0.156471
# Epoch 66/200 | Train Loss: 0.163278 | Test Loss: 0.151926
# Epoch 68/200 | Train Loss: 0.162542 | Test Loss: 0.152184
# Epoch 70/200 | Train Loss: 0.159524 | Test Loss: 0.152548
# Epoch 72/200 | Train Loss: 0.157152 | Test Loss: 0.156909
# Epoch 74/200 | Train Loss: 0.158539 | Test Loss: 0.155969
# Epoch 76/200 | Train Loss: 0.161760 | Test Loss: 0.150151
# Epoch 78/200 | Train Loss: 0.156615 | Test Loss: 0.148263
# Epoch 80/200 | Train Loss: 0.158717 | Test Loss: 0.148907
# Epoch 82/200 | Train Loss: 0.157349 | Test Loss: 0.147445
# Epoch 84/200 | Train Loss: 0.155508 | Test Loss: 0.144546
# Epoch 86/200 | Train Loss: 0.155656 | Test Loss: 0.143993
# Epoch 88/200 | Train Loss: 0.154504 | Test Loss: 0.144371
# Epoch 90/200 | Train Loss: 0.155522 | Test Loss: 0.145715
# Epoch 92/200 | Train Loss: 0.153595 | Test Loss: 0.177035
# Epoch 94/200 | Train Loss: 0.155886 | Test Loss: 0.149212
# Epoch 96/200 | Train Loss: 0.153180 | Test Loss: 0.143086
# Epoch 98/200 | Train Loss: 0.152578 | Test Loss: 0.147605
# Epoch 100/200 | Train Loss: 0.153316 | Test Loss: 0.145696
# Epoch 102/200 | Train Loss: 0.149960 | Test Loss: 0.145976
# Epoch 104/200 | Train Loss: 0.149017 | Test Loss: 0.145011
# Epoch 106/200 | Train Loss: 0.151137 | Test Loss: 0.138384
# Epoch 108/200 | Train Loss: 0.148417 | Test Loss: 0.141604
# Epoch 110/200 | Train Loss: 0.146994 | Test Loss: 0.150151
# Epoch 112/200 | Train Loss: 0.148830 | Test Loss: 0.143179
# Epoch 114/200 | Train Loss: 0.149952 | Test Loss: 0.144788
# Epoch 116/200 | Train Loss: 0.148111 | Test Loss: 0.145462
# Epoch 118/200 | Train Loss: 0.150239 | Test Loss: 0.140356
# Epoch 120/200 | Train Loss: 0.146640 | Test Loss: 0.142638
# Epoch 122/200 | Train Loss: 0.148037 | Test Loss: 0.141484
# Epoch 124/200 | Train Loss: 0.148786 | Test Loss: 0.141228
# Epoch 126/200 | Train Loss: 0.145833 | Test Loss: 0.140256
# Epoch 128/200 | Train Loss: 0.145343 | Test Loss: 0.140781
# Epoch 130/200 | Train Loss: 0.145833 | Test Loss: 0.149910
# Epoch 132/200 | Train Loss: 0.143890 | Test Loss: 0.142786
# Epoch 134/200 | Train Loss: 0.141075 | Test Loss: 0.143664
# Epoch 136/200 | Train Loss: 0.143801 | Test Loss: 0.147618
# Epoch 138/200 | Train Loss: 0.143781 | Test Loss: 0.143838
# Epoch 140/200 | Train Loss: 0.144600 | Test Loss: 0.142548
# Epoch 142/200 | Train Loss: 0.146125 | Test Loss: 0.140500
# Epoch 144/200 | Train Loss: 0.143255 | Test Loss: 0.139423
# Epoch 146/200 | Train Loss: 0.142340 | Test Loss: 0.143410
# Epoch 148/200 | Train Loss: 0.143868 | Test Loss: 0.153307
# Epoch 150/200 | Train Loss: 0.142680 | Test Loss: 0.145999
# Epoch 152/200 | Train Loss: 0.143399 | Test Loss: 0.142900
# Epoch 154/200 | Train Loss: 0.141076 | Test Loss: 0.141305
# Epoch 156/200 | Train Loss: 0.142776 | Test Loss: 0.140597
# Epoch 158/200 | Train Loss: 0.141127 | Test Loss: 0.144527
# Epoch 160/200 | Train Loss: 0.144232 | Test Loss: 0.136559
# Epoch 162/200 | Train Loss: 0.144216 | Test Loss: 0.143924
# Epoch 164/200 | Train Loss: 0.142528 | Test Loss: 0.147803
# Epoch 166/200 | Train Loss: 0.141572 | Test Loss: 0.142672
# Epoch 168/200 | Train Loss: 0.139904 | Test Loss: 0.141561
# Epoch 170/200 | Train Loss: 0.141478 | Test Loss: 0.141960
# Epoch 172/200 | Train Loss: 0.140308 | Test Loss: 0.143285
# Epoch 174/200 | Train Loss: 0.138499 | Test Loss: 0.161195
# Epoch 176/200 | Train Loss: 0.140139 | Test Loss: 0.143200
# Epoch 178/200 | Train Loss: 0.139657 | Test Loss: 0.139277
# Epoch 180/200 | Train Loss: 0.137440 | Test Loss: 0.140760
# Epoch 182/200 | Train Loss: 0.139756 | Test Loss: 0.143307
# Epoch 184/200 | Train Loss: 0.138496 | Test Loss: 0.144904
# Epoch 186/200 | Train Loss: 0.136660 | Test Loss: 0.140547
# Epoch 188/200 | Train Loss: 0.138712 | Test Loss: 0.138174
# Epoch 190/200 | Train Loss: 0.138777 | Test Loss: 0.143690
# Epoch 192/200 | Train Loss: 0.139266 | Test Loss: 0.148718
# Epoch 194/200 | Train Loss: 0.135967 | Test Loss: 0.144366
# Epoch 196/200 | Train Loss: 0.137177 | Test Loss: 0.142171
# Epoch 198/200 | Train Loss: 0.138514 | Test Loss: 0.144852
# Epoch 200/200 | Train Loss: 0.135573 | Test Loss: 0.142301
# Training Completed.
# Training took 82 min 50.0 sec.
# Best test loss: 0.136559 at epoch 160
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 8
#       5 plot_prediction_sample(X_test, y_test, model_12883_512)
#       7 for flux_name in diagnostics_to_plot:
# ----> 8     plot_flux(model_12883_512, X_test, y_test, output_cols, flux_name)
#      10 print('Number of parameters:')
#      11 print(sum( p.numel() for p in model_12883_512.parameters() if p.requires_grad ))
#
# Cell In[19], line 15, in plot_flux(model, X_test, y_test, output_cols, flux_name)
#      12 model_cpu.eval()
#      14 with torch.no_grad():
# ---> 15     y_pred_tensor, _ = model_cpu(X_test.unsqueeze(-1).to('cpu'))  # shape: [n_samples, 115, 1]
#      16     #y_pred_tensor = model(X_test.unsqueeze(-1).to(device))  # shape: [n_samples, 115, 1]
#      18 y_pred_full = y_pred_tensor.squeeze(-1).cpu().numpy()  # shape: [n_samples, 115]
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[9], line 60, in FluxTransformer.forward(self, c, output_subset, return_embedding)
#      57 c_subset = c[:, selected_indices, :]
#      59 for layer in self.layers:
# ---> 60     x, c_subset = layer(x, c_subset)
#      62 if return_embedding:
#      63     return x, selected_indices  # embeddings + indices
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[8], line 19, in FluxTransformerLayer.forward(self, x, c)
#      18 def forward(self, x, c):
# ---> 19     attn_x, attn_c = self.attention_block(x, c)
#      20     ff_output = self.feedforward_block(attn_x, attn_c)
#      22     # Split the concatenated output
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[6], line 24, in AttentionBlock.forward(self, x, c)
#      20 def forward(self, x, c):
#      21     # x: (batch, seq_len, d_model)
#      22     # c: (batch, seq_len, 1)
#      23     x_norm = self.layer_norm(x) # pre-norm
# ---> 24     attn_out, attn_weights = self.mha(x_norm, x_norm, x_norm, need_weights=True, average_attn_weights=False)
#      26     x_out = attn_out + x
#      28     # Per-head diffusion of c:
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\truok\Documents\metabolic-NN\venv\Lib\site-packages\torch\nn\modules\activation.py:1308, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1303         merged_mask, mask_type = self.merge_masks(
#    1304             attn_mask, key_padding_mask, query
#    1305         )
#    1307         if self.in_proj_bias is not None and self.in_proj_weight is not None:
# -> 1308             return torch._native_multi_head_attention(
#    1309                 query,
#    1310                 key,
#    1311                 value,
#    1312                 self.embed_dim,
#    1313                 self.num_heads,
#    1314                 self.in_proj_weight,
#    1315                 self.in_proj_bias,
#    1316                 self.out_proj.weight,
#    1317                 self.out_proj.bias,
#    1318                 merged_mask,
#    1319                 need_weights,
#    1320                 average_attn_weights,
#    1321                 mask_type,
#    1322             )
#    1324 any_nested = query.is_nested or key.is_nested or value.is_nested
#    1325 assert not any_nested, (
#    1326     "MultiheadAttention does not support NestedTensor outside of its fast path. "
#    1327     + f"The fast path was not hit because {why_not_fast_path}"
#    1328 )
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 16600866400 bytes.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
